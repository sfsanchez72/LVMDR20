# %% [markdown]
# # LVM DAP DR20 Tutorial
#
# This notebook provides a guided tutorial on how to use LVM DAP DR20 files, following the DR19 tutorial structure and updated with DR20 features.

# %% [markdown]
# ## 1. Introduction
#
# This tutorial explains how to explore LVM DAP outputs, including emission-line analysis, stellar population modeling, and map reconstruction.

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load DAP file

# %%
hdul = fits.open('your_dap_file.fits')
hdul.info()

# %% [markdown]
# ## 3. Access Extensions

# %%
pt = hdul['PT'].data
rsp = hdul['RSP'].data

# %% [markdown]
# ## 4. Example Plot

# %%
plt.hist(rsp['log_Mass'])
plt.xlabel('log Mass')
plt.show()
