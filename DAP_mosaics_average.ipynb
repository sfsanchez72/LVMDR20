# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from astropy.table import Table
from astropy.table import vstack as tab_vstack

from lvmdap.dap_tools import list_columns,read_DAP_file,map_plot_DAP,scatter
from matplotlib import use as mpl_use
#mpl_use('Agg')
from lvmdap.dap_tools import plot_spectra, read_coeffs_RSP, read_elines_RSP, read_tab_EL

# %matplotlib inline
from matplotlib import rcParams as rc
rc.update({'font.size': 19,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 19,\
           'ytick.labelsize' : 19,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })
import math
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as mpl_colors

# %%
import os
import fnmatch

def find_files(directory, pattern):
    matches = []
    for root, dirnames, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
            matches.append(os.path.join(root, filename))
    return matches

def Table_mean_rows(input_table):
    mean_values = {}
    for col in input_table.colnames:
        if np.issubdtype(input_table[col].dtype, np.number):
            mean_values[col] = np.mean(input_table[col])
        else:
            mean_values[col] = None  # Handle non-numeric columns if necessary

        # Create a new table with the computed means
    mean_row = {col: [mean_values[col]] for col in input_table.colnames if mean_values[col] is not None}
    output_table = Table(mean_row)
#    output_table.add_column([''],name='id')
#    output_table.rename_columns(output_table.colnames, input_table.colnames)
    return output_table

#mpl.use('TkAgg')#,warn=False, force=True)
# %matplotlib inline

# %%
from astropy.io import fits, ascii
from astropy.table import vstack as tab_vstack

# %%
dap_dir = '/disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/'
pattern = '*.dap.fits.gz'

#list_sel = ('ra','dec','flux_pe_6583.45','flux_pe_6562.85','flux_pe_5006.84')
list_sel = ('ra','dec','flux_pe_6583.41','flux_pe_6562.68','flux_pe_5006.84')

verbose=False
matching_files = find_files(dap_dir, pattern)
I=0
for file in matching_files:
    print(I,file)
    tab_DAP_tmp=read_DAP_file(file,verbose=verbose)
    try:
        tab_DAP_sec=tab_DAP_tmp[list_sel]
        if (I==0):
            tab_DAP = tab_DAP_sec
        else:
            tab_DAP=tab_vstack([tab_DAP,tab_DAP_sec])
        I=I+1        
    except:
        print('Non equal files...')
# Out:
# 0 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006876.dap.fits.gz
# 1 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006373.dap.fits.gz
# 2 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006566.dap.fits.gz
# 3 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006872.dap.fits.gz
# 4 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006564.dap.fits.gz
# 5 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006320.dap.fits.gz
# 6 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006048.dap.fits.gz
# 7 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006864.dap.fits.gz
# 8 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006161.dap.fits.gz
# 9 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006571.dap.fits.gz
# 10 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006366.dap.fits.gz
# 11 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006561.dap.fits.gz
# 12 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006557.dap.fits.gz
# 13 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006875.dap.fits.gz
# 14 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006425.dap.fits.gz
# 15 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006841.dap.fits.gz
# 16 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006443.dap.fits.gz
# 17 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006814.dap.fits.gz
# 18 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006323.dap.fits.gz
# 19 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006422.dap.fits.gz
# 20 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006689.dap.fits.gz
# 21 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006865.dap.fits.gz
# 22 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006868.dap.fits.gz
# 23 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006245.dap.fits.gz
# 24 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006565.dap.fits.gz
# 25 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006447.dap.fits.gz
# 26 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006328.dap.fits.gz
# 27 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006427.dap.fits.gz
# 28 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006863.dap.fits.gz
# 29 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006423.dap.fits.gz
# 30 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006840.dap.fits.gz
# 31 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006657.dap.fits.gz
# 32 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006428.dap.fits.gz
# 33 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006101.dap.fits.gz
# 34 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006883.dap.fits.gz
# 35 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006314.dap.fits.gz
# 36 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006812.dap.fits.gz
# 37 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006325.dap.fits.gz
# 38 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006241.dap.fits.gz
# 39 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006871.dap.fits.gz
# 40 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006661.dap.fits.gz
# 41 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006563.dap.fits.gz
# 42 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006326.dap.fits.gz
# 43 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006558.dap.fits.gz
# 44 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006559.dap.fits.gz
# 45 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006536.dap.fits.gz
# 46 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006586.dap.fits.gz
# 47 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006870.dap.fits.gz
# 48 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006108.dap.fits.gz
# 49 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006113.dap.fits.gz
# 50 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006538.dap.fits.gz
# 51 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006110.dap.fits.gz
# 52 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006445.dap.fits.gz
# 53 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006450.dap.fits.gz
# 54 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006560.dap.fits.gz
# 55 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006424.dap.fits.gz
# 56 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006102.dap.fits.gz
# 57 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006446.dap.fits.gz
# 58 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006226.dap.fits.gz
# 59 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006420.dap.fits.gz
# 60 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006219.dap.fits.gz
# 61 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006873.dap.fits.gz
# 62 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006112.dap.fits.gz
# 63 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006556.dap.fits.gz
# 64 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006588.dap.fits.gz
# 65 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006881.dap.fits.gz
# 66 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006168.dap.fits.gz
# 67 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006562.dap.fits.gz
# 68 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006451.dap.fits.gz
# 69 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006572.dap.fits.gz
# 70 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006162.dap.fits.gz
# 71 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006585.dap.fits.gz
# 72 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006634.dap.fits.gz
# 73 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006243.dap.fits.gz
# 74 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006862.dap.fits.gz
# 75 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006839.dap.fits.gz
# 76 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006105.dap.fits.gz
# 77 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006884.dap.fits.gz
# 78 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006659.dap.fits.gz
# 79 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006114.dap.fits.gz
# 80 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006115.dap.fits.gz
# 81 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006372.dap.fits.gz
# 82 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006106.dap.fits.gz
# 83 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006861.dap.fits.gz
# 84 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006567.dap.fits.gz
# 85 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006587.dap.fits.gz
# 86 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006321.dap.fits.gz
# 87 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006537.dap.fits.gz
# 88 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006813.dap.fits.gz
# 89 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006322.dap.fits.gz
# 90 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006886.dap.fits.gz
# 91 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006421.dap.fits.gz
# 92 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006705.dap.fits.gz
# 93 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006555.dap.fits.gz
# 94 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006570.dap.fits.gz
# 95 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006104.dap.fits.gz
# 96 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006160.dap.fits.gz
# 97 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006116.dap.fits.gz
# 98 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006879.dap.fits.gz
# 99 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006169.dap.fits.gz
# 100 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006109.dap.fits.gz
# 101 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006815.dap.fits.gz
# 102 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006444.dap.fits.gz
# 103 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006107.dap.fits.gz
# 104 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006842.dap.fits.gz
# 105 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006635.dap.fits.gz
# 106 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006448.dap.fits.gz
# 107 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006707.dap.fits.gz
# 108 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006637.dap.fits.gz
# 109 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006878.dap.fits.gz
# 110 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006817.dap.fits.gz
# 111 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006573.dap.fits.gz
# 112 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006539.dap.fits.gz
# 113 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006867.dap.fits.gz
# 114 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006426.dap.fits.gz
# 115 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006419.dap.fits.gz
# 116 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006819.dap.fits.gz
# 117 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006638.dap.fits.gz
# 118 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006866.dap.fits.gz
# 119 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006706.dap.fits.gz
# 120 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006818.dap.fits.gz
# 121 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006816.dap.fits.gz
# 122 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006843.dap.fits.gz
# 123 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006111.dap.fits.gz
# 124 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006117.dap.fits.gz
# 125 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006244.dap.fits.gz
# 126 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006047.dap.fits.gz
# 127 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006885.dap.fits.gz
# 128 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006838.dap.fits.gz
# 129 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006882.dap.fits.gz
# 130 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006869.dap.fits.gz
# 131 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006639.dap.fits.gz
# 132 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006877.dap.fits.gz
# 133 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006660.dap.fits.gz
# 134 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006874.dap.fits.gz
# 135 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006100.dap.fits.gz
# 136 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006449.dap.fits.gz
# 137 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006365.dap.fits.gz
# 138 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006324.dap.fits.gz
# 139 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006590.dap.fits.gz
# 140 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006167.dap.fits.gz
# 141 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006636.dap.fits.gz
# 142 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006589.dap.fits.gz
# 143 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006103.dap.fits.gz
# 144 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006658.dap.fits.gz
# 145 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006880.dap.fits.gz
# 146 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006327.dap.fits.gz

# %%
dap_dir = '/disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/'
pattern = '*.dap.fits.gz'

#list_sel = ('ra','dec','flux_pe_6583.45','flux_pe_6562.85','flux_pe_5006.84')
list_sel = ('ra','dec','flux_pe_6583.41','flux_pe_6562.68','flux_pe_5006.84')

verbose=False
matching_files = find_files(dap_dir, pattern)
I=0
for file in matching_files:
    print(I,file)
    tab_DAP_tmp=read_DAP_file(file,verbose=verbose)
    m_tab_DAP = Table_mean_rows(tab_DAP_tmp)
    m_tab_DAP.add_column([file],name='id')
    a_files = file.split('/')
    file_sec=a_files[-1].replace('lvmSFrame-','')
    file_sec=file_sec.replace('.fits','')
    m_tab_DAP['fiberid']=[file_sec] 
    try:
        tab_DAP_sec=m_tab_DAP[list_sel]        
        if (I==0):
            tab_DAP = tab_DAP_sec
        else:
            tab_DAP=tab_vstack([tab_DAP,tab_DAP_sec])
        I=I+1        
    except:
        print('Non equal files...')
# Out:
# 0 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006876.dap.fits.gz
# 1 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006373.dap.fits.gz
# 2 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006566.dap.fits.gz
# 3 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006872.dap.fits.gz
# 4 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006564.dap.fits.gz
# 5 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006320.dap.fits.gz
# 6 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006048.dap.fits.gz
# 7 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006864.dap.fits.gz
# 8 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006161.dap.fits.gz
# 9 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006571.dap.fits.gz
# 10 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006366.dap.fits.gz
# 11 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006561.dap.fits.gz
# 12 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006557.dap.fits.gz
# 13 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006875.dap.fits.gz
# 14 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006425.dap.fits.gz
# 15 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006841.dap.fits.gz
# 16 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006443.dap.fits.gz
# 17 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006814.dap.fits.gz
# 18 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006323.dap.fits.gz
# 19 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006422.dap.fits.gz
# 20 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006689.dap.fits.gz
# 21 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006865.dap.fits.gz
# 22 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006868.dap.fits.gz
# 23 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006245.dap.fits.gz
# 24 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006565.dap.fits.gz
# 25 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006447.dap.fits.gz
# 26 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006328.dap.fits.gz
# 27 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006427.dap.fits.gz
# 28 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006863.dap.fits.gz
# 29 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006423.dap.fits.gz
# 30 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006840.dap.fits.gz
# 31 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006657.dap.fits.gz
# 32 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006428.dap.fits.gz
# 33 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006101.dap.fits.gz
# 34 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006883.dap.fits.gz
# 35 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006314.dap.fits.gz
# 36 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006812.dap.fits.gz
# 37 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006325.dap.fits.gz
# 38 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006241.dap.fits.gz
# 39 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006871.dap.fits.gz
# 40 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006661.dap.fits.gz
# 41 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006563.dap.fits.gz
# 42 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006326.dap.fits.gz
# 43 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006558.dap.fits.gz
# 44 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006559.dap.fits.gz
# 45 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006536.dap.fits.gz
# 46 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006586.dap.fits.gz
# 47 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006870.dap.fits.gz
# 48 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006108.dap.fits.gz
# 49 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006113.dap.fits.gz
# 50 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006538.dap.fits.gz
# 51 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006110.dap.fits.gz
# 52 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006445.dap.fits.gz
# 53 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006450.dap.fits.gz
# 54 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006560.dap.fits.gz
# 55 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006424.dap.fits.gz
# 56 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006102.dap.fits.gz
# 57 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006446.dap.fits.gz
# 58 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006226.dap.fits.gz
# 59 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006420.dap.fits.gz
# 60 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006219.dap.fits.gz
# 61 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006873.dap.fits.gz
# 62 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006112.dap.fits.gz
# 63 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006556.dap.fits.gz
# 64 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006588.dap.fits.gz
# 65 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006881.dap.fits.gz
# 66 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006168.dap.fits.gz
# 67 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006562.dap.fits.gz
# 68 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006451.dap.fits.gz
# 69 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006572.dap.fits.gz
# 70 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006162.dap.fits.gz
# 71 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006585.dap.fits.gz
# 72 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006634.dap.fits.gz
# 73 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006243.dap.fits.gz
# 74 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006862.dap.fits.gz
# 75 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006839.dap.fits.gz
# 76 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006105.dap.fits.gz
# 77 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006884.dap.fits.gz
# 78 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006659.dap.fits.gz
# 79 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006114.dap.fits.gz
# 80 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006115.dap.fits.gz
# 81 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006372.dap.fits.gz
# 82 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006106.dap.fits.gz
# 83 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006861.dap.fits.gz
# 84 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006567.dap.fits.gz
# 85 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006587.dap.fits.gz
# 86 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006321.dap.fits.gz
# 87 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006537.dap.fits.gz
# 88 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006813.dap.fits.gz
# 89 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006322.dap.fits.gz
# 90 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006886.dap.fits.gz
# 91 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006421.dap.fits.gz
# 92 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006705.dap.fits.gz
# 93 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006555.dap.fits.gz
# 94 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006570.dap.fits.gz
# 95 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006104.dap.fits.gz
# 96 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006160.dap.fits.gz
# 97 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006116.dap.fits.gz
# 98 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006879.dap.fits.gz
# 99 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006169.dap.fits.gz
# 100 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006109.dap.fits.gz
# 101 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006815.dap.fits.gz
# 102 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006444.dap.fits.gz
# 103 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006107.dap.fits.gz
# 104 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006842.dap.fits.gz
# 105 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006635.dap.fits.gz
# 106 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006448.dap.fits.gz
# 107 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006707.dap.fits.gz
# 108 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006637.dap.fits.gz
# 109 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006878.dap.fits.gz
# 110 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006817.dap.fits.gz
# 111 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006573.dap.fits.gz
# 112 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006539.dap.fits.gz
# 113 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006867.dap.fits.gz
# 114 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006426.dap.fits.gz
# 115 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006419.dap.fits.gz
# 116 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006819.dap.fits.gz
# 117 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006638.dap.fits.gz
# 118 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006866.dap.fits.gz
# 119 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006706.dap.fits.gz
# 120 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006818.dap.fits.gz
# 121 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006816.dap.fits.gz
# 122 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006843.dap.fits.gz
# 123 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006111.dap.fits.gz
# 124 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006117.dap.fits.gz
# 125 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006244.dap.fits.gz
# 126 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006047.dap.fits.gz
# 127 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006885.dap.fits.gz
# 128 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006838.dap.fits.gz
# 129 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006882.dap.fits.gz
# 130 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006869.dap.fits.gz
# 131 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006639.dap.fits.gz
# 132 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006877.dap.fits.gz
# 133 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006660.dap.fits.gz
# 134 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006874.dap.fits.gz
# 135 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006100.dap.fits.gz
# 136 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006449.dap.fits.gz
# 137 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006365.dap.fits.gz
# 138 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006324.dap.fits.gz
# 139 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006590.dap.fits.gz
# 140 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006167.dap.fits.gz
# 141 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006636.dap.fits.gz
# 142 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006589.dap.fits.gz
# 143 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006103.dap.fits.gz
# 144 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006658.dap.fits.gz
# 145 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006880.dap.fits.gz
# 146 /disk-a/sanchez/LVM/LVM/ver_231113/output_ofelia_new/dap-rsp30-sn20-00006327.dap.fits.gz

# %%
tab_DAP
# Out:
# <Table length=147>
#          ra                 dec            flux_pe_6583.41        flux_pe_6562.68       flux_pe_5006.84
#       float64             float64              float64                float64               float64
# ------------------- ------------------- ---------------------- --------------------- ----------------------
#     86.499961828555  -32.30558095485392     1436.1854498116047     64.36236322532027      26317.44908183873
#   21.01887056343941 -22.926080954853923      9.181135404789053    21.822565792474347     136.17025872291904
#    83.8202502961666  -5.389080954853921     251347.91863797035     921506.9146116305      556036.0510741733
# 0.45616653773042515 -3.0265809548539218       4723.67512538524     4253.081967639902     1796.3532916463907
#    83.8202502961666  -5.389080954853921       263711.391927138    1033545.2545343785      572916.8570598061
#  24.174204953122704  15.784580045146077     16.566688540478903     69.64656140250855     27.134352451539336
#    98.4377501406773   4.999252045146077      6669.708721263037    23303.576109038237      4573.794353650058
#    113.363975460544 -50.583441954853924      888.6530517673889    2325.7247237742304     149.36113244013683
#                 ...                 ...                    ...                   ...                    ...
#  11.887920132309567 -25.287380775582204      63.91880587229191    169.14564646522234     39.026265906499425
#  103.92837355738556 -24.078492950996097      61.31476391106044     639.7172043329533     1108.7547708665907
#    98.6394429636577   4.511577045146078     1763.0898750285064     6171.593575370582      639.0087606043329
#  11.888192600356065  -25.28741395485392      79.78199709070167    206.70354729035938     159.43402795208215
#  53.401975564900916 -36.139358954853925     42.248500456360524    17.362019053051913     13.524703593839131
#    270.900273091065 -24.149080954853925 1.3349890369750794e+18 5.208976116471096e+18 1.0628915468457471e+18
#  102.01968127710141 -44.315552954853906      336.5516440597954     824.7035357199055      2181.480078284815
#  24.174204953122704  15.784580045146077      23.82136356898518     82.86259749144813     118.57575935005701

# %%
DIR_out = 'DAP_0.1.3_mean'
lvmid='mean'
hdu_hdr = fits.PrimaryHDU()
hdu_DAP = fits.BinTableHDU(tab_DAP,name='PT')
hdu_list = fits.HDUList([hdu_hdr,hdu_DAP])#,names=('PRIMARY','FLUX','ERROR','SKY'))
out_file = f'{DIR_out}/mean_DAP.fits'
hdu_list.writeto(out_file,overwrite=True)

# %%
def map_plot_DAP_rgb(tab_DAP,\
                     rgb_key=('flux_pe_6583.45','flux_pe_6562.85','flux_pe_5006.84'), \
                     rgb_scale=(1.0,1.0,1.0),\
                 vmin=0, vmax=0, titles=('r','g','b'), filename='junk',\
                fsize=5, figs_dir='.',fig_type='png',\
                 gamma=1.0, sf=1.0, tab_pt=None,fs=18,x_scale=1,marker='O'):

    rc.update({'font.size': fs*fsize/5,\
               'font.weight': 900,\
               'text.usetex': True,\
               'path.simplify'           :   True,\
               'xtick.labelsize' : fs*fsize/5,\
               'ytick.labelsize' : fs*fsize/5,\
               'axes.linewidth'  : 2.0,\
               'xtick.major.size'        :   6,\
               'ytick.major.size'        :   6,\
               'xtick.minor.size'        :   3,\
               'ytick.minor.size'        :   3,\
               'xtick.major.width'       :   1,\
               'ytick.major.width'       :   1,\
               'lines.markeredgewidth'   :   1,\
               'legend.numpoints'        :   1,\
               'xtick.minor.width'       :   1,\
               'ytick.minor.width'       :   1,\
               'legend.frameon'          :   False,\
               'legend.handletextpad'    :   0.3,\
               'font.family'    :   'serif',\
               'mathtext.fontset'        :   'stix',\
               'axes.facecolor' : "w",\
               })
    
    X= tab_DAP['ra'].value
    Y= tab_DAP['dec'].value
    R=tab_DAP[rgb_key[2]].value  
    G=tab_DAP[rgb_key[1]].value    
    B=tab_DAP[rgb_key[0]].value 
    R = R * rgb_scale[2]
    G = G * rgb_scale[1]
    B = B * rgb_scale[0]
    RGB = np.stack((R, G, B), axis=1)
    if (vmin==vmax):
        vmin=np.nanmin(RGB)
        vmax=np.nanmax(RGB)
    print(f'min/max:{vmin}/{vmax}')
    r = (R-vmin)/(vmax-vmin)
    g = (G-vmin)/(vmax-vmin)
    b = (B-vmin)/(vmax-vmin)

    r[r>1]=1
    r[r<0]=0
    b[b>1]=1
    b[b<0]=0
    r[r>1]=1
    r[r<0]=0    
    
    r = np.ma.filled(r, fill_value=0.0)
    g = np.ma.filled(g, fill_value=0.0)
    b = np.ma.filled(b, fill_value=0.0)

    r=r**gamma
    g=g**gamma
    b=b**gamma
    
#    print (r)
    r = np.ma.compressed(r)
    g = np.ma.compressed(g)
    b = np.ma.compressed(b)   


    #print(r,g,b)
    colors = np.stack((r, g, b), axis=1)
    colors[colors>1]=1
    colors[colors<0]=0
#    print(colors)
    fig,ax = plt.subplots(1,1,figsize=(fsize*x_scale,fsize*0.95))
#    norm=mpl_colors.PowerNorm(vmin=0,vmax=1,gamma=gamma)
    scatter(X, Y, ax, color=colors, size=sf*35.6/3600,marker=marker)#, color=colors)
    ax.set_xlabel('Ra [deg]')#,fontsize=21)
    ax.set_ylabel('Dec [deg]')#,fontsize=21)
    xx = ax.get_xlim()
    yy = ax.get_ylim()
    ax.set_xlim(xx[1],xx[0])
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.06*(yy[1]-yy[0]),titles[0],fontsize=fs*(fsize/5),color='tomato')
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.12*(yy[1]-yy[0]),titles[1],fontsize=fs*(fsize/5),color='forestgreen')
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.18*(yy[1]-yy[0]),titles[2],fontsize=fs*(fsize/5),color='steelblue')

    if (tab_pt != None):
        for tap_pt_now in tab_pt:
            ax.text(tab_pt['ra'],tab_pt['dec'],tab_pt['id'])
#    ax.set_aspect('equal', adjustable='box')
    try:
        plt.show()
    except:
        plt_show=False
    fig.tight_layout()
    fig.savefig(f'{figs_dir}/{filename}.{fig_type}', facecolor='white')
    plt.close()
    return colors

# %%
def map_plot_DAP_rgb(tab_DAP,\
                     rgb_key=('flux_pe_6583.45','flux_pe_6562.85','flux_pe_5006.84'), \
                     rgb_scale=(1.0,1.0,1.0),\
                 vmin=0, vmax=0, titles=('r','g','b'), filename='junk',\
                fsize=5, figs_dir='.',fig_type='png',\
                 gamma=1.0, sf=1.0, tab_pt=None,fs=18):

    rc.update({'font.size': fs*fsize/5,\
               'font.weight': 900,\
               'text.usetex': True,\
               'path.simplify'           :   True,\
               'xtick.labelsize' : fs*fsize/5,\
               'ytick.labelsize' : fs*fsize/5,\
               'axes.linewidth'  : 2.0,\
               'xtick.major.size'        :   6,\
               'ytick.major.size'        :   6,\
               'xtick.minor.size'        :   3,\
               'ytick.minor.size'        :   3,\
               'xtick.major.width'       :   1,\
               'ytick.major.width'       :   1,\
               'lines.markeredgewidth'   :   1,\
               'legend.numpoints'        :   1,\
               'xtick.minor.width'       :   1,\
               'ytick.minor.width'       :   1,\
               'legend.frameon'          :   False,\
               'legend.handletextpad'    :   0.3,\
               'font.family'    :   'serif',\
               'mathtext.fontset'        :   'stix',\
               'axes.facecolor' : "w",\
               })
    
    X= tab_DAP['ra'].value
    Y= tab_DAP['dec'].value
    R=tab_DAP[rgb_key[2]].value  
    G=tab_DAP[rgb_key[1]].value    
    B=tab_DAP[rgb_key[0]].value 
    R = R * rgb_scale[2]
    G = G * rgb_scale[1]
    B = B * rgb_scale[0]
    RGB = np.stack((R, G, B), axis=1)
    if (vmin==vmax):
        vmin=np.nanmin(RGB)
        vmax=np.nanmax(RGB)
    print(f'min/max:{vmin}/{vmax}')
    r = (R-vmin)/(vmax-vmin)
    g = (G-vmin)/(vmax-vmin)
    b = (B-vmin)/(vmax-vmin)

    r[r>1]=1
    r[r<0]=0
    b[b>1]=1
    b[b<0]=0
    r[r>1]=1
    r[r<0]=0    
    
    r = np.ma.filled(r, fill_value=0.0)
    g = np.ma.filled(g, fill_value=0.0)
    b = np.ma.filled(b, fill_value=0.0)

    r=r**gamma
    g=g**gamma
    b=b**gamma
    
#    print (r)
    r = np.ma.compressed(r)
    g = np.ma.compressed(g)
    b = np.ma.compressed(b)   


    #print(r,g,b)
    colors = np.stack((r, g, b), axis=1)
    colors[colors>1]=1
    colors[colors<0]=0
#    print(colors)
    fig,ax = plt.subplots(1,1,figsize=(fsize,fsize*0.95))
#    norm=mpl_colors.PowerNorm(vmin=0,vmax=1,gamma=gamma)
    scatter(X, Y, ax, color=colors, size=sf*35.6/3600)#, color=colors)
    ax.set_xlabel('Ra [deg]')#,fontsize=21)
    ax.set_ylabel('Dec [deg]')#,fontsize=21)
    xx = ax.get_xlim()
    yy = ax.get_ylim()
    ax.set_xlim(xx[1],xx[0])
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.06*(yy[1]-yy[0]),titles[0],fontsize=fs*(fsize/5),color='tomato')
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.12*(yy[1]-yy[0]),titles[1],fontsize=fs*(fsize/5),color='forestgreen')
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.18*(yy[1]-yy[0]),titles[2],fontsize=fs*(fsize/5),color='steelblue')

    if (tab_pt != None):
        for tap_pt_now in tab_pt:
            ax.text(tab_pt['ra'],tab_pt['dec'],tab_pt['id'])
#    ax.set_aspect('equal', adjustable='box')
    try:
        plt.show()
    except:
        plt_show=False
    fig.tight_layout()
    fig.savefig(f'{figs_dir}/{filename}.{fig_type}', facecolor='white')
    plt.close()
    return colors

# %%
# 637.416/110230.7468
colors=map_plot_DAP_rgb(tab_DAP, \
                 rgb_key=('flux_pe_6583.41','flux_pe_6562.68','flux_pe_5006.84'), \
                 rgb_scale = (3,1,1.5), \
                 vmin=600.0, vmax=100000.0,\
                 titles=('[NII]',r'H$\alpha$','[OIII]'), filename='test',\
                 fsize=8, figs_dir='figs',gamma=0.35,fig_type='png')#
#,fs=20,sf=19,x_scale=3)
# Out:
# min/max:600.0/100000.0
# /tmp/ipykernel_164319/2606146357.py:61: RuntimeWarning: invalid value encountered in power
#   g=g**gamma

# %%
# 637.416/110230.7468
colors=map_plot_DAP_rgb(tab_DAP, \
                 rgb_key=('flux_[NII]_6583.45','flux_Halpha_6562.85','flux_[OIII]_5006.84'), \
                 rgb_scale = (3,1,1.5), \
                 vmin=600.0, vmax=100000.0,\
                 titles=('[NII]',r'H$\alpha$','[OIII]'), filename='Rosetta_NP',\
                 fsize=25, figs_dir='figs',gamma=0.35,fig_type='png',fs=13)
# Out:
# min/max:600.0/100000.0
# <ipython-input-192-13a150769c86>:61: RuntimeWarning: invalid value encountered in power
#   g=g**gamma

# %%
# 637.416/110230.7468
colors=map_plot_DAP_rgb(tab_DAP, \
                 rgb_key=('flux_[SIII]_9531.1','flux_Halpha_6562.85','flux_[OII]_3728.82'), \
                 rgb_scale = (3,1,1.5), \
                 vmin=600.0, vmax=100000.0,\
                 titles=('[SIII]',r'H$\alpha$','[OII]'), filename='Rosetta_NP_test',\
                 fsize=25, figs_dir='figs',gamma=0.35,fig_type='png',fs=13)
# Out:
# min/max:600.0/100000.0
# <ipython-input-192-13a150769c86>:61: RuntimeWarning: invalid value encountered in power
#   g=g**gamma

# %%
search_col(tab_DAP,'flux_[OII]')
# Out:
# flux_[OII]_3726.03
# flux_[OII]_3728.82
# e_flux_[OII]_3726.03
# e_flux_[OII]_3728.82
# flux_[OII]_7318.92
# flux_[OII]_7329.66
# e_flux_[OII]_7318.92
# e_flux_[OII]_7329.66

# %%
rc.update({'font.size': 20,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 20,\
           'ytick.labelsize' : 20,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })


mask_Ha = (tab_DAP['flux_Halpha_6562.85']>100) & (tab_DAP['flux_Halpha_6562.85']>50.0*tab_DAP['e_flux_Halpha_6562.85'])



Ha=tab_DAP['flux_Halpha_6562.85']
Hb=tab_DAP['flux_Hbeta_4861.36']
OIII=tab_DAP['flux_[OIII]_5006.84']
NII=tab_DAP['flux_[NII]_6583.45']
SII=tab_DAP['flux_[SII]_6716.44']+tab_DAP['flux_[SII]_6730.82']
OI=tab_DAP['flux_[OI]_6300.3']
#tab_DAP['flux_pe_3726.03']+tab_DAP['flux_pe_3728.82']

map_dist=np.arange(len(Ha))

eHa=tab_DAP['e_flux_pe_6562.68']
eHb=tab_DAP['e_flux_pe_4861.36']
eOIII=tab_DAP['e_flux_pe_5006.84']
eNII=tab_DAP['e_flux_pe_6583.41']
eSII=np.sqrt(tab_DAP['e_flux_pe_6716.44']**2+tab_DAP['e_flux_pe_6730.82']**2)
eOI=tab_DAP['flux_pe_9531.1']
#tab_DAP['e_flux_pe_3726.03']+tab_DAP['e_flux_pe_3728.82']

#tab_DAP['e_flux_pe_9531.1']

O3=np.log10(OIII)-np.log10(Hb)
N2=np.log10(NII)-np.log10(Ha)
S2=np.log10(SII/Ha)
O1=np.log10(OI/Ha)
lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
nx = 2.5 #np.max(tab_DAP[mask_Ha]['R_Re'])
#
#
#
fig, axes = plt.subplots(1,3,figsize=(15.5,6), sharey=True, squeeze=False)
x_min1=-1.19
x_max1=0.39
y_min1=-2.49
y_max1=1.29

x=np.linspace(5*x_min1,2*x_max1,100)
cut_y=-0.7+0.2-3.67*x
cut_y2=-1.7+0.5-3.67*x
cut_y3=0.61/(x-0.05)+1.3
cut_y4=0.61/(x-0.47)+1.19
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII_AGNs=1.89*(x)+0.76;
cut_y_OI=0.73/((x+0.59))+1.33;#+1.10;
cut_y_OI_AGNs=1.18*(x)+1.30;
cut_y_OIII_AGNs=1.14*(x)+0.36;
cm = plt.cm.get_cmap('viridis')
cax1=axes[0,0].scatter(N2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=10)
#                       c=map_dist[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=0, vmax=nx)
cax2=axes[0,1].scatter(S2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=10)
cax3=axes[0,2].scatter(O1[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=10)

#axes[0,0].scatter(N2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,1].scatter(S2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,2].scatter(O1,O3,alpha=0.75, marker='*', s=100,c='green')

axes[0,0].plot(x[x<0],cut_y3[x<0],'r-.')
axes[0,0].plot(x,cut_y4,'b-')
axes[0,1].plot(x[x<0.2],cut_y_SII[x<0.2],'b-')
axes[0,2].plot(x[x<-0.6],cut_y_OI[x<-0.6],'b-')


#plt.rcParams.update({'font.size': 16})
axes[0,0].set_ylabel(r'log([Oiii]/H$\beta$)')
axes[0,0].set_xlabel(r'log([Nii]/H$\alpha$)')
axes[0,1].set_xlabel(r'log([Sii]/H$\alpha$)')
axes[0,2].set_xlabel(r'log([Oi]/H$\alpha$)')
axes[0,0].set_xlim(x_min1,x_max1)
axes[0,1].set_xlim(x_min1-0.3,x_max1)
axes[0,2].set_xlim(x_min1-2.9,x_max1+0.1)
axes[0,0].set_ylim(y_min1,y_max1)




plt.subplots_adjust(wspace=0)

plt.tight_layout
fig.savefig(f'figs/BPT_Rosetta.png', facecolor='white')
plt.close()

#cax1=axes[0,2].scatter(N2[mask_Ha],O3[mask_Ha],c=log_EW_Ha[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=-3, vmax=2.5)
#axes[0,2].plot(x[x<0],cut_y3[x<0],'r-.')
#axes[0,2].plot(x,cut_y4,'b-')
#cb1=add_colorbar(cax1)
#cb1.set_label(r'$log|EW(H\alpha)|$')
# Out:
# <ipython-input-267-f657ea85db2f>:54: RuntimeWarning: invalid value encountered in log10
#   O3=np.log10(OIII)-np.log10(Hb)
# <ipython-input-267-f657ea85db2f>:55: RuntimeWarning: invalid value encountered in log10
#   N2=np.log10(NII)-np.log10(Ha)
# <ipython-input-267-f657ea85db2f>:56: RuntimeWarning: invalid value encountered in log10
#   S2=np.log10(SII/Ha)
# <ipython-input-267-f657ea85db2f>:57: RuntimeWarning: invalid value encountered in log10
#   O1=np.log10(OI/Ha)
# <ipython-input-267-f657ea85db2f>:58: RuntimeWarning: divide by zero encountered in log10
#   lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
# <ipython-input-267-f657ea85db2f>:59: RuntimeWarning: divide by zero encountered in true_divide
#   e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
# <ipython-input-267-f657ea85db2f>:81: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %%
rc.update({'font.size': 20,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 20,\
           'ytick.labelsize' : 20,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })


mask_Ha = (tab_DAP['flux_pe_6562.68']>80) & (tab_DAP['flux_pe_6562.68']>3.0*tab_DAP['e_flux_pe_6562.68'])



Ha=tab_DAP['flux_pe_6562.68']
Hb=tab_DAP['flux_pe_4861.36']
OIII=tab_DAP['flux_pe_5006.84']
NII=tab_DAP['flux_pe_6583.41']
SII=tab_DAP['flux_pe_6716.44']+tab_DAP['flux_pe_6730.82']
OI=tab_DAP['flux_pe_9531.1']
#tab_DAP['flux_pe_3726.03']+tab_DAP['flux_pe_3728.82']

map_dist=np.arange(len(Ha))

eHa=tab_DAP['e_flux_pe_6562.68']
eHb=tab_DAP['e_flux_pe_4861.36']
eOIII=tab_DAP['e_flux_pe_5006.84']
eNII=tab_DAP['e_flux_pe_6583.41']
eSII=np.sqrt(tab_DAP['e_flux_pe_6716.44']**2+tab_DAP['e_flux_pe_6730.82']**2)
eOI=tab_DAP['flux_pe_9531.1']
#tab_DAP['e_flux_pe_3726.03']+tab_DAP['e_flux_pe_3728.82']

#tab_DAP['e_flux_pe_9531.1']

O3=np.log10(OIII)-np.log10(Hb)
N2=np.log10(NII)-np.log10(Ha)
S2=np.log10(SII/Ha)
O1=np.log10(OI/Ha)
lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
nx = 2.5 #np.max(tab_DAP[mask_Ha]['R_Re'])
#
#
#
fig, axes = plt.subplots(1,3,figsize=(9.5,4.3), sharey=True, squeeze=False)
x_min1=-1.39
x_max1=0.39
y_min1=-1.19
y_max1=1.19

x=np.linspace(2*x_min1,2*x_max1,100)
cut_y=-0.7+0.2-3.67*x
cut_y2=-1.7+0.5-3.67*x
cut_y3=0.61/(x-0.05)+1.3
cut_y4=0.61/(x-0.47)+1.19
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII_AGNs=1.89*(x)+0.76;
cut_y_OI=0.73/((x+0.59))+1.33;#+1.10;
cut_y_OI_AGNs=1.18*(x)+1.30;
cut_y_OIII_AGNs=1.14*(x)+0.36;
cm = plt.cm.get_cmap('viridis')
cax1=axes[0,0].scatter(N2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha])
#                       c=map_dist[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=0, vmax=nx)
cax2=axes[0,1].scatter(S2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha])
cax3=axes[0,2].scatter(O1[mask_Ha],O3[mask_Ha],color=colors[mask_Ha])

#axes[0,0].scatter(N2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,1].scatter(S2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,2].scatter(O1,O3,alpha=0.75, marker='*', s=100,c='green')

axes[0,0].plot(x[x<0],cut_y3[x<0],'r-.')
axes[0,0].plot(x,cut_y4,'b-')
axes[0,1].plot(x[x<0.1],cut_y_SII[x<0.1],'b-')
#axes[0,2].plot(x[x<-0.6],cut_y_OI[x<-0.6],'b-')


#plt.rcParams.update({'font.size': 16})
axes[0,0].set_ylabel(r'log([Oiii]/H$\beta$)')
axes[0,0].set_xlabel(r'log([Nii]/H$\alpha$)')
axes[0,1].set_xlabel(r'log([Sii]/H$\alpha$)')
axes[0,2].set_xlabel(r'log([Siii]/H$\alpha$)')
axes[0,0].set_xlim(x_min1,x_max1)
axes[0,1].set_xlim(x_min1,x_max1)
axes[0,2].set_xlim(x_min1-1.1,x_max1-0.2)
axes[0,0].set_ylim(y_min1,y_max1)




plt.subplots_adjust(wspace=0)

plt.tight_layout
#cax1=axes[0,2].scatter(N2[mask_Ha],O3[mask_Ha],c=log_EW_Ha[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=-3, vmax=2.5)
#axes[0,2].plot(x[x<0],cut_y3[x<0],'r-.')
#axes[0,2].plot(x,cut_y4,'b-')
#cb1=add_colorbar(cax1)
#cb1.set_label(r'$log|EW(H\alpha)|$')
# Out:
# <ipython-input-261-8785b05f024a>:54: RuntimeWarning: invalid value encountered in log10
#   O3=np.log10(OIII)-np.log10(Hb)
# <ipython-input-261-8785b05f024a>:54: RuntimeWarning: divide by zero encountered in log10
#   O3=np.log10(OIII)-np.log10(Hb)
# <ipython-input-261-8785b05f024a>:55: RuntimeWarning: invalid value encountered in log10
#   N2=np.log10(NII)-np.log10(Ha)
# <ipython-input-261-8785b05f024a>:56: RuntimeWarning: divide by zero encountered in log10
#   S2=np.log10(SII/Ha)
# <ipython-input-261-8785b05f024a>:57: RuntimeWarning: invalid value encountered in log10
#   O1=np.log10(OI/Ha)
# <ipython-input-261-8785b05f024a>:58: RuntimeWarning: divide by zero encountered in log10
#   lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
# <ipython-input-261-8785b05f024a>:59: RuntimeWarning: divide by zero encountered in true_divide
#   e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
# <ipython-input-261-8785b05f024a>:81: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
#DIR_DAP = '/disk-a/sanchez/LVM/LVM/ver_231113/output_dap/'
#dap_file='dap-nsp-00006109.dap.fits.gz'
#'dap-rsp30-00006109.dap.fits.gz'
#dap_file='dap-rsp30-00006690.dap.fits.gz'

#DIR_DAP = 'output_dap'
#dap-test-SN50-00006109.dap.fits.gz
#dap_file='dap-test-SN50-00006109.dap.fits.gz'
#'dap-rsp30-00006109.dap.fits.gz'
#dap-test-00006109.dap.fits.gz'

#DIR_DAP = 'output_chiripa'
#dap_file='dap-rsp30-SN50-00006109.dap.fits.gz'
#dap_file='dap-rsp30-00006709.dap.fits.gz'

# Download the files from here!
# http://ifs.astroscu.unam.mx/LVM/LVMDAP/v0.231130/

# Store them in the director DIR_DAP, like below


#DIR_DAP = 'output_ofelia'
#DIR_DAP = 'output_ofelia_new'
DIR_DAP = 'output_atocatl/'
#dap_files=['dap-rsp30-sn20-00006109.dap.fits.gz',
#           'dap-rsp30-sn20-00006110.dap.fits.gz',
#           'dap-rsp30-sn20-00006111.dap.fits.gz',
#           'dap-rsp30-sn20-00006112.dap.fits.gz',
#           'dap-rsp30-sn20-00006113.dap.fits.gz',
#           'dap-rsp30-sn20-00006114.dap.fits.gz',
#           'dap-rsp30-sn20-00006115.dap.fits.gz',
#           'dap-rsp30-sn20-00005684.dap.fits.gz',                                         
#           'dap-rsp30-sn20-00005685.dap.fits.gz',                                                      
#           'dap-rsp30-sn20-00006047.dap.fits.gz',                                                      
#           'dap-rsp30-sn20-00006048.dap.fits.gz',
#           'dap-rsp30-sn20-00006116.dap.fits.gz',
#           'dap-rsp30-sn20-00006117.dap.fits.gz',
#           'dap-rsp30-sn20-00006445.dap.fits.gz',
#           'dap-rsp30-sn20-00006446.dap.fits.gz',                                         
#           'dap-rsp30-sn20-00006447.dap.fits.gz',
#          'dap-rsp30-sn20-00006448.dap.fits.gz']

#'dap-rsp30-sn20-00005684.dap.fits.gz',
#'dap-rsp30-sn20-00005685.dap.fits.gz',
#'dap-rsp30-sn20-00006047.dap.fits.gz',
#'dap-rsp30-sn20-00006048.dap.fits.gz',

dap_files=['dap-rsp108-sn20-00006109.dap.fits.gz',
'dap-rsp108-sn20-00006110.dap.fits.gz',
'dap-rsp108-sn20-00006111.dap.fits.gz',
'dap-rsp108-sn20-00006112.dap.fits.gz']

#'dap-rsp30-sn20-00006113.dap.fits.gz',
#'dap-rsp30-sn20-00006114.dap.fits.gz',
#'dap-rsp30-sn20-00006115.dap.fits.gz',
#'dap-rsp30-sn20-00006116.dap.fits.gz',
#'dap-rsp30-sn20-00006117.dap.fits.gz',
#'dap-rsp30-sn20-00006445.dap.fits.gz',
#'dap-rsp30-sn20-00006446.dap.fits.gz',
#'dap-rsp30-sn20-00006447.dap.fits.gz',
#'dap-rsp30-sn20-00006448.dap.fits.gz',
#'dap-rsp30-sn20-00006449.dap.fits.gz',
#'dap-rsp30-sn20-00006450.dap.fits.gz',
#'dap-rsp30-sn20-00006634.dap.fits.gz',
#'dap-rsp30-sn20-00006635.dap.fits.gz',
#'dap-rsp30-sn20-00006636.dap.fits.gz',
#'dap-rsp30-sn20-00006637.dap.fits.gz',
#'dap-rsp30-sn20-00006638.dap.fits.gz',
#'dap-rsp30-sn20-00006639.dap.fits.gz']


#dap_files=['dap-rsp30-sn5-00006701.dap.fits.gz',\
#           'dap-rsp30-sn5-00006702.dap.fits.gz',\
#           'dap-rsp30-sn5-00006703.dap.fits.gz',\
#           'dap-rsp30-sn5-00006704.dap.fits.gz',\
#           'dap-rsp30-sn5-00006708.dap.fits.gz',\
#           'dap-rsp30-sn5-00006709.dap.fits.gz']

#DIR_DAP = 'output_chiripa'
#dap_files=['dap-rsp30-00006690.dap.fits.gz','dap-rsp30-00006691.dap.fits.gz','dap-rsp30-00006692.dap.fits.gz']
#dap_files=['dap-rsp30-00006112.dap.fits.gz','dap-rsp30-00006111.dap.fits.gz','dap-rsp30-SN50-00006109.dap.fits.gz']
verbose=True
verbose=False
ra=[]
dec=[]
idn=[]
for I,dap_file in enumerate(dap_files):
    dap_file=f'{DIR_DAP}/{dap_file}'
    tab_DAP_tmp=read_DAP_file(dap_file,verbose=verbose)
    if (I==0):
        tab_DAP=tab_DAP_tmp
    else:
        tab_DAP=tab_vstack([tab_DAP,tab_DAP_tmp])
    verbose=False
    ra_now=np.nanmean(tab_DAP_tmp['ra'])
    dec_now=np.nanmean(tab_DAP_tmp['dec'])
    id_now=str(tab_DAP_tmp['id'][0])
    ra.append(ra_now)
    dec.append(dec_now)
    idn.append(id_now)
    print(I,dap_file,tab_DAP_tmp['ra'][0],tab_DAP_tmp['dec'][0],tab_DAP_tmp['id'][0])

ra=np.array(ra)    
dec=np.array(dec)    
idn=np.array(idn)    

#dap_file='dap-rsp30-sn5-00006701.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006702.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006703.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006704.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006708.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006709.dap.fits.gz'

#dap_file='dap-rsp30-sn5-00006708.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006709.dap.fits.gz'

#tab_DAP_0=read_DAP_file('output_ofelia/dap-rsp30-sn5-00006701.dap.fits.gz',verbose=verbose)
#tab_DAP_1=read_DAP_file('output_ofelia/dap-rsp30-sn5-00006709.dap.fits.gz',verbose=verbose)
# Out:
# 0 output_atocatl//dap-rsp108-sn20-00006109.dap.fits.gz 97.66300971713306 4.7103637711339665 6109.10
# 1 output_atocatl//dap-rsp108-sn20-00006110.dap.fits.gz 97.85784589660625 4.337067771133967 6110.10
# 2 output_atocatl//dap-rsp108-sn20-00006111.dap.fits.gz 97.8903353906415 5.0654177711339665 6111.10
# 3 output_atocatl//dap-rsp108-sn20-00006112.dap.fits.gz 98.08524798941808 4.691990771133966 6112.10

# %%
#print(ra,dec,idn)
idp=[]
for idns in idn:
    idp.append(idns.split('.')[0])
idp=np.array(idp)
#print(idp)
tab_pt=Table()
tab_pt['id']=idp
tab_pt['ra']=ra
tab_pt['dec']=dec
tab_pt

#tab_DAP_0=read_DAP_file('output_chiripa/dap-rsp30-00006690.dap.fits.gz',verbose=verbose)
#tab_DAP_1=read_DAP_file('output_chiripa/dap-rsp30-00006691.dap.fits.gz',verbose=verbose)
# Out:
# <Table length=4>
#  id          ra               dec
# str4      float64           float64
# ---- ----------------- -----------------
# 6109 97.60057111157647 4.922440045146079
# 6110 97.79544097664143 4.549144045146079
# 6111 97.82786224991473 5.277494045146079
# 6112 98.02281110468336 4.904067045146078

# %%
#print(len(tab_DAP))
#plt.scatter(tab_DAP['ra'],tab_DAP['dec'],s=2)
#fig,ax = plt.subplots(1,1,figsize=(5,5))
#ax.scatter(tab_DAP_0['flux_Halpha_6562.85'],tab_DAP_1['flux_Halpha_6562.85'])
#ax.set_xlabel(r'H$\alpha$ flux 6690')
#ax.set_ylabel(r'H$\alpha$ flux 6691')
#ax.set_aspect('equal', adjustable='box')
#ax.set_xlim(-100,500)
#ax.set_ylim(-100,500)

#plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(5,5))
ax.scatter(tab_DAP['EW_Halpha_6562.85'],tab_DAP['flux_Halpha_6562.85'],\
           alpha=0.2,edgecolor='None')
ax.set_ylabel(r'H$\alpha$ flux')
ax.set_xlabel(r'WH$\alpha$')
ax.set_xlim(-500,100)
#ax.set_aspect('equal', adjustable='box')
#plt.show()
# Out:
# (-500.0, 100.0)

# %%
fig,ax = plt.subplots(1,1,figsize=(5,5))
ax.scatter(np.log10(np.abs(tab_DAP['EW_Halpha_6562.85'])),\
           np.log10(tab_DAP['flux_Halpha_6562.85']),\
           alpha=0.2,edgecolor='None')
ax.set_ylabel(r'log(H$\alpha$) flux 10$^6$ cgs')
ax.set_xlabel(r'log(WH$\alpha$) $\AA$')
ax.set_xlim(-1,4)
ax.set_ylim(1,5)
# Out:
# <ipython-input-8-a2a25b919ed7>:2: RuntimeWarning: divide by zero encountered in log10
#   ax.scatter(np.log10(np.abs(tab_DAP['EW_Halpha_6562.85'])),\
# <ipython-input-8-a2a25b919ed7>:3: RuntimeWarning: invalid value encountered in log10
#   np.log10(tab_DAP['flux_Halpha_6562.85']),\
# (1.0, 5.0)

# %%
fig,ax = plt.subplots(1,1,figsize=(5,5))
ax.scatter(tab_DAP['flux_Halpha_6562.85'],tab_DAP['flux_pe_6562.85'],\
           alpha=0.1,s=3,edgecolor='None')
ax.set_xlabel(r'H$\alpha$ flux Non-Parametric')
ax.set_ylabel(r'H$\alpha$ flux Parametric')
ax.set_aspect('equal', adjustable='box')
ax.set_xlim(-1e3,1e5)
ax.set_ylim(-1e3,1e5)

#plt.show()
#tab_DAP['flux_Halpha_6562.85','flux_pe_6562.68']
# Out:
# (-1000.0, 100000.0)

# %%
class scatter():
    def __init__(self,x,y,ax,size=1,**kwargs):
        self.n = len(x)
        self.ax = ax
        self.ax.figure.canvas.draw()
        self.size_data=size
        self.size = size
        self.sc = ax.scatter(x,y,s=self.size,**kwargs)
        self._resize()
        self.cid = ax.figure.canvas.mpl_connect('draw_event', self._resize)

    def _resize(self,event=None):
        ppd=72./self.ax.figure.dpi
        trans = self.ax.transData.transform
        s =  ((trans((1,self.size_data))-trans((0,0)))*ppd)[1]
        if s != self.size:
            self.sc.set_sizes(s**2*np.ones(self.n))
            self.size = s
            self._redraw_later()

    def _redraw_later(self):
        self.timer = self.ax.figure.canvas.new_timer(interval=10)
        self.timer.single_shot = True
        self.timer.add_callback(lambda : self.ax.figure.canvas.draw_idle())
        self.timer.start()
        
def search_col(tab,key):
    for keys in tab.columns:
        if (keys.find(key)>-1):
            print(keys)

# %%
def map_plot_DAP(tab_DAP,line='flux_Halpha_6562.85', \
                 vmin=0, vmax=0, title=None, filename='junk',\
                 cmap='Spectral', fsize=5, figs_dir='.',fig_type='png',\
                 gamma=1.0, sf=1.0,tab_pt=False):

    rc.update({'font.size': 19,\
               'font.weight': 900,\
               'text.usetex': True,\
               'path.simplify'           :   True,\
               'xtick.labelsize' : 19,\
               'ytick.labelsize' : 19,\
               'axes.linewidth'  : 2.0,\
               'xtick.major.size'        :   6,\
               'ytick.major.size'        :   6,\
               'xtick.minor.size'        :   3,\
               'ytick.minor.size'        :   3,\
               'xtick.major.width'       :   1,\
               'ytick.major.width'       :   1,\
               'lines.markeredgewidth'   :   1,\
               'legend.numpoints'        :   1,\
               'xtick.minor.width'       :   1,\
               'ytick.minor.width'       :   1,\
               'legend.frameon'          :   False,\
               'legend.handletextpad'    :   0.3,\
               'font.family'    :   'serif',\
               'mathtext.fontset'        :   'stix',\
               'axes.facecolor' : "w",\
               })
    
    X=tab_DAP['ra']
    Y=tab_DAP['dec']
    C=tab_DAP[line]    
    if (title== None):
        title=line.replace("_"," ")
        title=line.replace("_"," ")
    if (vmin==vmax):
        vmin=np.nanmin(C)
        vmax=np.nanmax(C)
    print(line,vmin,vmax)
    fig,ax = plt.subplots(1,1,figsize=(fsize,fsize))
    norm=mpl_colors.PowerNorm(vmin=vmin,vmax=vmax,gamma=gamma)
    scat=scatter(X, Y, ax, size=sf*35.6/3600, c=C, cmap=cmap, norm=norm)
#    scat=scatter(X, Y, ax, size=35.6/3600, c=C,vmin = vmin, vmax = vmax, cmap=cmap, norm=colors.PowerNorm(gamma=gamma))
    ax.set_xlabel('Ra [deg]')#,fontsize=21)
    ax.set_ylabel('Dec [deg]')#,fontsize=21)
    xx = ax.get_xlim()
    ax.set_xlim(xx[1],xx[0])
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(scat.sc, cax=cax,label=fr'{title}')#,fontsize=21)
    try:
        for tab_pt_now in tab_pt:
            ax.text(tab_pt_now['ra'],tab_pt_now['dec'],tab_pt_now['id'],fontsize=17)
    except:
        tab_pt=False
#    ax.set_aspect('equal', adjustable='box')
    try:
        plt.show()
    except:
        plt_show=False
    fig.tight_layout()
    fig.savefig(f'{figs_dir}/{filename}.{fig_type}')
    plt.close()

# %%
search_col(tab_DAP,'flux_Hb')
search_col(tab_DAP,'flux_pe_486')
# Out:
# flux_Hbeta_4861.36
# e_flux_Hbeta_4861.36
# flux_pe_4861.36
# e_flux_pe_4861.36

# %%
map_plot_DAP(tab_DAP,line='flux_pe_4861.36', \
                 vmin=-200, vmax=1e5, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')#,tab_pt=tab_pt)
# Out:
# flux_pe_4861.36 -200 100000.0

# %%
map_plot_DAP(tab_DAP,line='flux_pe_6562.85', \
                 vmin=-200, vmax=1e5, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')#,tab_pt=tab_pt)
# Out:
# flux_pe_6562.85 -200 100000.0

# %%
try:
    tab_DAP.add_column(tab_DAP['flux_pe_6562.85']/tab_DAP['flux_pe_4861.36'],name='HaHb')
except:
    print('HaHb not needed')
try:
    tab_DAP.add_column(tab_DAP['flux_Halpha_6562.85']/tab_DAP['flux_Hbeta_4861.36'],name='HaHb_fit')
except:
    print('HaHb not needed')
# Out:
# HaHb not needed
# HaHb not needed

# %%
map_plot_DAP(tab_DAP,line='flux_pe_6562.85', \
                 vmin=-200, vmax=1e5, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')#,tab_pt=tab_pt)
# Out:
# flux_pe_6562.85 -200 100000.0

# %%
map_plot_DAP(tab_DAP,line='HaHb_fit', \
                 vmin=2.5, vmax=15, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=1.0,fig_type='pdf')#,tab_pt=tab_pt)
# Out:
# HaHb_fit 2.5 15

# %%
map_plot_DAP(tab_DAP,line='HaHb', \
                 vmin=2.5, vmax=15, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=1.0,fig_type='pdf')#,tab_pt=tab_pt)
# Out:
# HaHb 2.5 15

# %%
map_plot_DAP(tab_DAP,line='flux_pe_6562.85', \
                 vmin=-200, vmax=1e5, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')#,tab_pt=tab_pt)
# Out:
# flux_pe_6562.85 -200 100000.0

# %%
map_plot_DAP(tab_DAP,line='flux_Halpha_6562.85', \
                 vmin=-200, vmax=1e5, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Halpha_6562.85 -200 100000.0

# %%
map_plot_DAP(tab_DAP,line='flux_Hbeta_4861.36', \
                 vmin=-200, vmax=1e5, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Hbeta_4861.36 -200 100000.0

# %%
mask_flux = tab_DAP['flux_Hbeta_4861.36']>-1
plt.scatter(tab_DAP['HaHb'][mask_flux],tab_DAP['HaHb_fit'][mask_flux],alpha=0.3,edgecolor='None')
plt.plot([-0.5,25],[-0.5,25],c='red')
plt.xlim(-0.5,25)
plt.ylim(-0.5,25)
# Out:
# (-0.5, 25.0)

# %%
map_plot_DAP(tab_DAP,line='flux_[SIII]_6312.06', \
                 vmin=-200, vmax=500, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
#0 otput_chiripa/dap-rsp30-00006112.dap.fits.gz 98.08524798941808 4.691990771133966
#1 output_chiripa/dap-rsp30-00006111.dap.fits.gz 97.8903353906415 5.0654177711339665
#2 output_chiripa/dap-rsp30-SN50-00006109.dap.fits.gz 97.66300971713306 4.7103637711339665
# Out:
# flux_[SIII]_6312.06 -200 500

# %%
map_plot_DAP(tab_DAP,line='flux_Hgamma_4340.49',\
                 vmin=-500, vmax=15000, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Hgamma_4340.49 -500 15000

# %%
#flux_Hepsilon_3970.07'
#flux_Hdelta_4101.77',\
map_plot_DAP(tab_DAP,line='flux_Hgamma_4340.49',\
                 vmin=-100, vmax=15000, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Hgamma_4340.49 -100 15000

# %%
#flux_[OIII]_4363.21
map_plot_DAP(tab_DAP,line='flux_[OIII]_4363.21', \
                 vmin=-500, vmax=6000, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_[OIII]_4363.21 -500 6000

# %%
map_plot_DAP(tab_DAP,line='flux_[SIII]_6312.06', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_[SIII]_6312.06 -2305.4233971574276 2430.607427722567

# %%
#[NII]_5754.59
map_plot_DAP(tab_DAP,line='flux_[NII]_5754.59', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_[NII]_5754.59 -3879645.195033283 3407823.803621313

# %%
map_plot_DAP(tab_DAP,line='flux_st', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_st 38346.8359375 491601600.0

# %%
map_plot_DAP(tab_DAP,line='vel_Halpha_6562.85', \
                 vmin=-20, vmax=20, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=1.0)
# Out:
# vel_Halpha_6562.85 -20 20

# %%
map_plot_DAP(tab_DAP,line='vel_st', \
                 vmin=-20, vmax=20, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=1.0)
# Out:
# vel_st -20 20

# %%
map_plot_DAP(tab_DAP,line='Teff', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs')
# Out:
# Teff 3152.5033564249266 9998.128156596242

# %%
map_plot_DAP(tab_DAP,line='Fe', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs')
# Out:
# Fe -2.57243275642395 0.1981826275587082
