# %%
__author__ = 'Sebastian F. Sanchez and LVM team'
__version__ = '20260416'
__datasets__ = ['SDSS-V LVM DAP (DRPVER=1.2.0, DAPVER = 1.2.0.251218, MJD=60349, EXPNUM=12183)']  
__keywords__ = ['NGC4945','Mosaic','LVM','DR20','model spectra','tutorial']

# %% [markdown]
# # SDSS-V LVM DR20 Mosaic/Local Volume (NGC4945) DAP tutorial
#
# **Purpose.** This notebook documents the process of generating the plots from several tiles analyzed  using the LVM DAP (https://github.com/sdss/lvmdap), doing Mosaics using the the DAP-files.
#
# It teaches how to:
# 1. open and inspect several DR20 DAP products,
# 2. generate RGB maps and individual line maps,
# 4. explore the BPT diagrams based on the emission lines,
# 5. explore kinematics and radial structure,
# 6. inspect simple stellar-continuum products,
#
# Although we focus here on the two pointings delivered for M33 included in the SDSS5 DR20, the workflow is broadly applicable to any Mosaic included in the DR20 LVM distribution.

# %% [markdown]
# ## Required Python dependencies
#
# This notebook uses a small set of external Python packages in addition to the Python standard library. The main required dependencies are:
#
# - **numpy**: numerical arrays and vectorized operations
# - **matplotlib**: plotting and figure generation
# - **astropy**: reading FITS files and handling tables
# - **sdss-access**: optional access to SDSS paths and remote files
# - **sdss-tree**: required by `sdss-access`
# - **gdown**: optional helper to download external template files from Google Drive
#
# In practice:
# - `math` and `pathlib` belong to the Python standard library and do **not** need installation.
# - `mpl_toolkits.axes_grid1` is part of `matplotlib` and is installed automatically with it.
# - If the template files are downloaded manually, `gdown` is **not required**.
#
# ### Recommended installation
#
# Using `pip`:
#
# ```bash
# pip install numpy matplotlib astropy sdss-access sdss-tree gdown

# %% [markdown]
# # Importing some routines that are needed for the plotting and analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table,join
import matplotlib.colors as mpl_colors
from matplotlib import rcParams as rc
rc.update({'font.size': 19,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 19,\
           'ytick.labelsize' : 19,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })
import math
from mpl_toolkits.axes_grid1 import make_axes_locatable
from astropy.io import fits
from astropy.table import vstack as tab_vstack
# Import the sdss_access package to get the data


# Tools for downloading the RSP templates
import gdown 
from pathlib import Path

# %%
#####################################################
# Patch for non delivered dataset, still under Tree
#####################################################
#from tree import Tree
# Once the data is delivered
from sdss_access import Access

try:
    #################################################
    # For already delivered datasets, in DR20
    #################################################
    
    access = Access(release='dr20', verbose=True)
except:
    ##################################################
    # For not yet delivered datasets, still under Tree
    ##################################################
    from tree import Tree
    #from sdss_access import Access
    tree = Tree(config = 'dr20')
    #tree = Tree(config = 'dr20')
    access = Access(release='dr20', verbose=True)

# %%
def read_DAP_file(dap_file,verbose=False):
    dap_hdu=fits.open(dap_file)
    tab_PT=Table(dap_hdu['PT'].data)
    tab_RSP=Table(dap_hdu['RSP'].data)
    tab_COEFFS=Table(dap_hdu['COEFFS'].data)
    tab_PE=Table(dap_hdu['PM_ELINES'].data)
    tab_NPE_B=Table(dap_hdu['NP_ELINES_B'].data)
    tab_NPE_R=Table(dap_hdu['NP_ELINES_R'].data)
    tab_NPE_I=Table(dap_hdu['NP_ELINES_I'].data)
    kel_ext = 0
    try:
        kel_ext = 1
        tab_KEL=Table(dap_hdu['PM_KEL'].data)
    except:
        kel_ext = 0
        print('No PM_KEL extension')

    sig_ext = 0
    try:
        sig_ext = 1
        tab_SIGMA = Table(dap_hdu['ELINES_SIGMA_CHI'].data)
    except:
        sig_ext = 0
        print('No SIGMA_CHI extension')

    #
    # Rename some entries!
    #
    tab_RSP.rename_column('Av','Av_st')
    tab_RSP.rename_column('e_Av','e_Av_st')
    tab_RSP.rename_column('z','z_st')
    tab_RSP.rename_column('e_z','e_z_st')
    tab_RSP.rename_column('disp','disp_st')
    tab_RSP.rename_column('e_disp','e_disp_st')
    tab_RSP.rename_column('flux','flux_st')
    tab_RSP.rename_column('redshift','redshift_st')
    tab_RSP.rename_column('med_flux','med_flux_st')
    tab_RSP.rename_column('e_med_flux','e_med_flux_st')
    tab_RSP.rename_column('sys_vel','vel_st')
    #
    # Parametric elines
    #
    tab_PE.rename_column('flux','flux_pe')
    tab_PE.rename_column('e_flux','e_flux_pe')
    tab_PE.rename_column('disp','disp_pe')
    tab_PE.rename_column('e_disp','e_disp_pe')
    tab_PE.rename_column('vel','vel_pe')
    tab_PE.rename_column('e_vel','e_vel_pe')

    if (kel_ext == 1):
        tab_KEL.rename_column('flux','flux_pek')
        tab_KEL.rename_column('e_flux','e_flux_pek')
        tab_KEL.rename_column('disp','disp_pek')
        tab_KEL.rename_column('e_disp','e_disp_pek')
        tab_KEL.rename_column('vel','vel_pek')
        tab_KEL.rename_column('e_vel','e_vel_pek')
    #
    # id	id_fib	rsp	TEFF	LOGG	META	ALPHAM	COEFF	Min.Coeff	log(M/L)	AV	N.Coeff	Err.Coeff
    #
    tab_COEFFS.rename_column('rsp','id_rsp')
    tab_COEFFS.rename_column('TEFF','Teff_rsp')
    tab_COEFFS.rename_column('LOGG','Log_g_rsp')
    tab_COEFFS.rename_column('META','Fe_rsp')
    tab_COEFFS.rename_column('ALPHAM','alpha_rsp')
    tab_COEFFS.rename_column('COEFF','W_rsp')
    tab_COEFFS.rename_column('Min.Coeff','min_W_rsp')
    tab_COEFFS.rename_column('log(M/L)','log_ML_rsp')
    tab_COEFFS.rename_column('AV','Av_rsp')
    tab_COEFFS.rename_column('N.Coeff','n_W_rsp')
    tab_COEFFS.rename_column('Err.Coeff','e_W_rsp')
    
    tab_DAP=Table(dap_hdu['PT'].data)
    tab_DAP=join(tab_DAP,tab_RSP,keys=['id'],join_type='left')
    tab_DAP=join(tab_DAP,tab_NPE_B,keys=['id'],join_type='left')
    tab_DAP=join(tab_DAP,tab_NPE_R,keys=['id'],join_type='left')
    tab_DAP=join(tab_DAP,tab_NPE_I,keys=['id'],join_type='left')

    #
    # order parametric emission line table
    #
    mask_elines = (tab_PE['model']=='eline')
    tab_PE = tab_PE[mask_elines]
    
    a_wl = np.unique(tab_PE['wl'])
    I=0
    for wl_now in a_wl:
        if (wl_now>0.0):
            tab_PE_now=tab_PE[tab_PE['wl']==wl_now]
            tab_PE_tmp=tab_PE_now['id','flux_pe','e_flux_pe','disp_pe','e_disp_pe','vel_pe','e_vel_pe']
            for cols in tab_PE_tmp.colnames:        
                if (cols != 'id'):
                    tab_PE_tmp.rename_column(cols,f'{cols}_{wl_now}')
            if (I==0):
                tab_PE_ord=tab_PE_tmp
            else:
                tab_PE_ord=join(tab_PE_ord,tab_PE_tmp,keys=['id'],join_type='left')
            I=I+1        
    tab_DAP=join(tab_DAP,tab_PE_ord,keys=['id'],join_type='left')


    #
    # order parametric emission line table with fixed kinematics
    #
    if (kel_ext == 1):
        mask_elines = (tab_KEL['model']=='eline')
        tab_KEL = tab_KEL[mask_elines]
    
        a_wl = np.unique(tab_KEL['wl'])
        I=0
        for wl_now in a_wl:
            if (wl_now>0.0):
                tab_KEL_now=tab_KEL[tab_KEL['wl']==wl_now]
                tab_KEL_tmp=tab_KEL_now['id','flux_pek','e_flux_pek','disp_pek','e_disp_pek','vel_pek','e_vel_pek']
                for cols in tab_KEL_tmp.colnames:        
                    if (cols != 'id'):
                        tab_KEL_tmp.rename_column(cols,f'{cols}_{wl_now}')
                if (I==0):
                    tab_KEL_ord=tab_KEL_tmp
                else:
                    tab_KEL_ord=join(tab_KEL_ord,tab_KEL_tmp,keys=['id'],join_type='left')
                I=I+1        
        tab_DAP=join(tab_DAP,tab_KEL_ord,keys=['id'],join_type='left')

    #
    # Order COEFFS table
    #
    a_rsp=np.unique(tab_COEFFS['id_rsp'])
    for I,rsp_now in enumerate(a_rsp):
        tab_C_now=tab_COEFFS[tab_COEFFS['id_rsp']==rsp_now]
        tab_C_tmp=tab_C_now['id','Teff_rsp', 'Log_g_rsp', 'Fe_rsp',\
                            'alpha_rsp', 'W_rsp', 'min_W_rsp',\
                            'log_ML_rsp', 'Av_rsp', 'n_W_rsp', 'e_W_rsp']
        for cols in tab_C_tmp.colnames:        
            if (cols != 'id'):
                tab_C_tmp.rename_column(cols,f'{cols}_{rsp_now}')
        if (I==0):
            tab_C_ord=tab_C_tmp
        else:
            tab_C_ord=join(tab_C_ord,tab_C_tmp,keys=['id'],join_type='left')
    tab_DAP=join(tab_DAP,tab_C_ord,keys=['id'],join_type='left')

    if (sig_ext == 1):
        tab_DAP=join(tab_DAP,tab_SIGMA,keys=['id'],join_type='left')
     
    if (verbose==True):
        print('---- ALL Table Columns -----')
        print('-------------------------------')
        print('|        PT                   |')
        print('-------------------------------')
        list_columns(tab_PT.colnames)
        print('----------------------------------')
        print('|        RSP                      |')
        print('----------------------------------')
        list_columns(tab_RSP.colnames)
        print('----------------------------------')
        print('|        PE_ord                   |')
        print('----------------------------------')
        list_columns(tab_PE_ord.colnames)
        if (kel_ext == 1):
            print('----------------------------------')
            print('|        PEK_ord                   |')
            print('----------------------------------')
            list_columns(tab_KEL_ord.colnames)
        print('----------------------------------')
        print('|        NPE_B                    |')
        print('----------------------------------')
        list_columns(tab_NPE_B.colnames,3)
        print('----------------------------------')
        print('|        NPE_R                    |')
        print('----------------------------------')
        list_columns(tab_NPE_R.colnames,3)
        print('----------------------------------')
        print('|        NPE_I                    |')
        print('----------------------------------')
        list_columns(tab_NPE_I.colnames,3)
        print('----------------------------------')
        print('|        C_ord                    |')
        print('----------------------------------')
        list_columns(tab_C_ord.colnames,4)
        if (sig_ext == 1):
            print('----------------------------------')
            print('|        SIGMA_CHI                   |')
            print('----------------------------------')
            list_columns(tab_SIGMA.colnames)
        
    return tab_DAP

def list_columns(obj, cols=4, columnwise=True, gap=2):
    """
    Print the given list in evenly-spaced columns.

    Parameters
    ----------
    obj : list
        The list to be printed.
    cols : int
        The number of columns in which the list should be printed.
    columnwise : bool, default=True
        If True, the items in the list will be printed column-wise.
        If False the items in the list will be printed row-wise.
    gap : int
        The number of spaces that should separate the longest column
        item/s from the next column. This is the effective spacing
        between columns based on the maximum len() of the list items.
    """

    sobj = [str(item) for item in obj]
    if cols > len(sobj): cols = len(sobj)
    max_len = max([len(item) for item in sobj])
    if columnwise: cols = int(math.ceil(float(len(sobj)) / float(cols)))
    plist = [sobj[i: i+cols] for i in range(0, len(sobj), cols)]
    if columnwise:
        if not len(plist[-1]) == cols:
            plist[-1].extend(['']*(len(sobj) - len(plist[-1])))
        plist = zip(*plist)
    printer = '\n'.join([
        ''.join([c.ljust(max_len + gap) for c in p])
        for p in plist])
    print(printer)


class scatter():
    def __init__(self,x,y,ax,size=1,**kwargs):
        self.n = len(x)
        self.ax = ax
        self.ax.figure.canvas.draw()
        self.size_data=size
        self.size = size
        self.sc = ax.scatter(x,y,s=self.size,**kwargs)
        self._resize()
        self.cid = ax.figure.canvas.mpl_connect('draw_event', self._resize)

    def _resize(self,event=None):
        ppd=72./self.ax.figure.dpi
        trans = self.ax.transData.transform
        s =  ((trans((1,self.size_data))-trans((0,0)))*ppd)[1]
        if s != self.size:
            self.sc.set_sizes(s**2*np.ones(self.n))
            self.size = s
            self._redraw_later()

    def _redraw_later(self):
        self.timer = self.ax.figure.canvas.new_timer(interval=10)
        self.timer.single_shot = True
        self.timer.add_callback(lambda : self.ax.figure.canvas.draw_idle())
        self.timer.start()
        


def gamma_scale(flux,gamma):
    return (flux/np.abs(flux))*(np.abs(flux))**gamma

def gamma_scale_abs(flux,gamma):
    return (np.abs(flux))**gamma

# %% [markdown]
# ## 1. Load the DR20 DAP file
#
# This cell defines the local directories, identifies the DR20 DAP product to use, and reads it into a single table.
# The chosen example are the two delivered DAP files on M33, expnums 5511 and 5512, using the experimental analysis
# in which the contribution of the Milky Way has been removed (both ISM and stellar component), i.e, the files
# labeled "LV_dap*".
#
# From here on, `tab_DAP` is the main table used throughout the notebook, that in this case is constructed by stacking two individual DAP tables.
#
#
# In here we have to options: (1.1) getting the data using the SDSS acccess procedure, or  (1.2) read it from a local directory. Select the option that is more suitable to you

# %%
#####################################################
# (1.0) We define some basic working directories
#####################################################
drpver = "1.2.0"
dapver = '1.2.0.251218' 
DIR_CACHE = 'cache/'
DRVER = 'DR20'
DIR_DAP = 'dap_v1.2.0/'
DIR_FIG = 'figs/'
rsp = 'rsp108'
sn = 'sn20'
#
# You could define an array of expnums, tileids and mjds to define your ouwn Mosaic
# 1056XX,1056242,60349,12183
# 1056XX,1056242,60349,12183
expnum = '00012183'
tileid = '1056242'
mjd = 60349
rsp = 'rsp108'
sn = 'sn20'
i_expnum = int(expnum)

# %%
##################################################
# (1.1) Get the data using the sdss_access pachage
##################################################
access.remote()
access.add('lvm_lv_dap', drpver = drpver, dapver = dapver, tileid = tileid, mjd = mjd, expnum = i_expnum, rspid = rsp, snlevel = sn, daptype = 'dap')
access.set_stream()
access.commit()
# PATH to lvmDAP file
path_to_data_file = access.full('lvm_lv_dap',  drpver = drpver, dapver = dapver, tileid = tileid, mjd = mjd, expnum = i_expnum, rspid = rsp, snlevel = sn, daptype = 'dap')
print(path_to_data_file)
# Open data file and print a summary of the Header Data Units
tab_DAP=read_DAP_file(path_to_data_file,verbose=True)
# Out:
# authentication for netloc=data.sdss5.org set for username=sdss5
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/LV_dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/LV_dap-rsp108-sn20-00012183.dap.fits*"
# SDSS_ACCESS> CREATE /tmp/sdss_access/20260420_014
# SDSS_ACCESS> streamlets added to /tmp/sdss_access/20260420_014
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_014/sdss_access_00.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 0 logging to /tmp/sdss_access/20260420_014/sdss_access_00.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_014/sdss_access_01.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 1 logging to /tmp/sdss_access/20260420_014/sdss_access_01.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_014/sdss_access_02.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 2 logging to /tmp/sdss_access/20260420_014/sdss_access_02.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_014/sdss_access_03.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 3 logging to /tmp/sdss_access/20260420_014/sdss_access_03.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_014/sdss_access_04.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 4 logging to /tmp/sdss_access/20260420_014/sdss_access_04.log
# Progress:   0%|          | 0/8 [00:00<?, ?files/s, n_files=8, n_streams=5]
# SDSS_ACCESS> syncing... please wait for 1 rsync streams (1 files) to complete [running for 0 seconds]
# Progress:  12%|█▎        | 1/8 [00:05<00:35,  5.00s/files, n_files=8, n_streams=5]
# SDSS_ACCESS> Done!
# /home/sanchez/sas/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/LV_dap-rsp108-sn20-00012183.dap.fits
# ---- ALL Table Columns -----
# -------------------------------
# |        PT                   |
# -------------------------------
# id               dec              fiberid          star_id
# ra               mask             exposure         star_sep_arcsec
# ----------------------------------
# |        RSP                      |
# ----------------------------------
# id             alpha          flux_st        Fe_MW
# MIN_CHISQ      e_alpha        redshift_st    e_Fe_MW
# Teff           Av_st          med_flux_st    alpha_MW
# e_Teff         e_Av_st        e_med_flux_st  e_alpha_MW
# Log_g          z_st           Teff_MW        vel_st
# e_Log_g        e_z_st         e_Teff_MW      log_ML
# Fe             disp_st        Log_g_MW       log_Mass
# flux_pek_3728.82    e_vel_pek_4861.36   vel_pek_6548.05     e_disp_pek_6730.82
# e_flux_pek_3728.82  flux_pek_4958.91    e_vel_pek_6548.05   vel_pek_6730.82
# disp_pek_3728.82    e_flux_pek_4958.91  flux_pek_6562.85    e_vel_pek_6730.82
# e_disp_pek_3728.82  disp_pek_4958.91    e_flux_pek_6562.85  flux_pek_9069.0
# vel_pek_3728.82     e_disp_pek_4958.91  disp_pek_6562.85    e_flux_pek_9069.0
# e_vel_pek_3728.82   vel_pek_4958.91     e_disp_pek_6562.85  disp_pek_9069.0
# flux_pek_4101.77    e_vel_pek_4958.91   vel_pek_6562.85     e_disp_pek_9069.0
# e_flux_pek_4101.77  flux_pek_5006.84    e_vel_pek_6562.85   vel_pek_9069.0
# disp_pek_4101.77    e_flux_pek_5006.84  flux_pek_6583.45    e_vel_pek_9069.0
# e_disp_pek_4101.77  disp_pek_5006.84    e_flux_pek_6583.45  flux_pek_9531.1
# vel_pek_4101.77     e_disp_pek_5006.84  disp_pek_6583.45    e_flux_pek_9531.1
# e_vel_pek_4101.77   vel_pek_5006.84     e_disp_pek_6583.45  disp_pek_9531.1
# flux_pek_4340.49    e_vel_pek_5006.84   vel_pek_6583.45     e_disp_pek_9531.1
# e_flux_pek_4340.49  flux_pek_6300.3     e_vel_pek_6583.45   vel_pek_9531.1
# disp_pek_4340.49    e_flux_pek_6300.3   flux_pek_6716.44    e_vel_pek_9531.1
# e_disp_pek_4340.49  disp_pek_6300.3     e_flux_pek_6716.44
# ----------------------------------
# |        NPE_B                    |
# ----------------------------------
# id                       disp_[OIII]_5006.84      e_vel_[FeII]_4416.27
# flux_HI_3686.83          disp_HeI_5015.68         e_vel_[FeII]_4452.11
# flux_HI_3691.56          disp_[FeII]_5039.1       e_vel_[FeII]_4457.95
# flux_HI_3697.15          disp_[FeII]_5072.4       e_vel_[FeII]_4470.29
# flux_HI_3703.85          disp_[FeII]_5107.95      e_vel_HeI_4471.48
# flux_HI_3711.97          disp_[FeII]_5111.63      e_vel_[FeII]_4474.91
# flux_[OII]_3726.03       disp_[FeVI]_5145.8       e_vel_[NiII]_4485.21
# flux_[OII]_3728.82       disp_[FeII]_5158.0       e_vel_[MgI]_4562.48
# flux_HI_3734.37          disp_[FeVII]_5158.9      e_vel_MgI]_4571.1
# flux_HI_3750.15          disp_[FeVI]_5176.0       e_vel_[FeII]_4632.27
# flux_[FeVII]_3758.9      disp_[FeII]_5184.8       e_vel_[FeIII]_4658.1
# flux_HI_3770.63          disp_[ArIII]_5191.82     e_vel_HeII_4685.68
# flux_HI_3797.9           disp_[NI]_5197.9         e_vel_[FeIII]_4701.62
# flux_HeI_3819.61         disp_[NI]_5200.26        e_vel_[ArIV]_4711.33
# flux_HI_3835.38          disp_[FeII]_5220.06      e_vel_HeI_4713.14
# flux_[NeIII]_3868.75     disp_[FeII]_5261.61      e_vel_[NeIV]_4724.17
# flux_HeI_3888.65         disp_[FeII]_5268.88      e_vel_[FeIII]_4733.93
# flux_HI_3889.05          disp_[FeIII]_5270.3      e_vel_[ArIV]_4740.2
# flux_CaII_3933.66        disp_[FeII]_5273.38      e_vel_[FeIII]_4754.83
# flux_HeI_3964.73         disp_[FeVI]_5277.8       e_vel_[FeIII]_4769.6
# flux_[NeIII]_3967.46     disp_[FeII]_5296.84      e_vel_[FeII]_4774.74
# flux_CaII_3968.47        disp_[FeXIV]_5302.86     e_vel_[FeIII]_4777.88
# flux_Hepsilon_3970.07    disp_[CaV]_5309.18       e_vel_[FeIII]_4813.9
# flux_HeI_4026.19         disp_[FeII]_5333.65      e_vel_[FeII]_4814.55
# flux_[SII]_4068.6        disp_[FeVI]_5335.2       e_vel_Hbeta_4861.36
# flux_[SII]_4076.35       disp_[FeII]_5376.47      e_vel_[FeIII]_4881.11
# flux_Hdelta_4101.77      disp_HeII_5411.52        e_vel_[FeII]_4889.63
# flux_HeI_4120.81         disp_[FeII]_5412.64      e_vel_[FeVII]_4893.4
# flux_[FeII]_4177.21      disp_[FeVI]_5424.2       e_vel_[FeII]_4905.35
# flux_[FeV]_4227.2        disp_[FeVI]_5426.6       e_vel_HeI_4921.93
# flux_[FeII]_4243.98      disp_[FeVI]_5484.8       e_vel_[FeIII]_4924.5
# flux_CII_4267.0          disp_[ClIII]_5517.71     e_vel_[FeIII]_4930.5
# flux_[FeII]_4287.4       disp_[FeII]_5527.33      e_vel_[FeVII]_4942.5
# flux_Hgamma_4340.49      disp_[OI]_5577.34        e_vel_[OIII]_4958.91
# flux_[FeII]_4358.1       disp_[FeVI]_5631.1       e_vel_[FeVI]_4972.5
# flux_[FeII]_4358.37      disp_[FeVI]_5677.0       e_vel_[FeII]_4973.39
# flux_[FeII]_4359.34      disp_[FeVII]_5720.7      e_vel_[FeIII]_4985.9
# flux_[OIII]_4363.21      disp_[NII]_5754.59       e_vel_[OIII]_5006.84
# flux_[FeII]_4413.78      EW_HI_3686.83            e_vel_HeI_5015.68
# flux_[FeII]_4414.45      EW_HI_3691.56            e_vel_[FeII]_5039.1
# flux_[FeII]_4416.27      EW_HI_3697.15            e_vel_[FeII]_5072.4
# flux_[FeII]_4452.11      EW_HI_3703.85            e_vel_[FeII]_5107.95
# flux_[FeII]_4457.95      EW_HI_3711.97            e_vel_[FeII]_5111.63
# flux_[FeII]_4470.29      EW_[OII]_3726.03         e_vel_[FeVI]_5145.8
# flux_HeI_4471.48         EW_[OII]_3728.82         e_vel_[FeII]_5158.0
# flux_[FeII]_4474.91      EW_HI_3734.37            e_vel_[FeVII]_5158.9
# flux_[NiII]_4485.21      EW_HI_3750.15            e_vel_[FeVI]_5176.0
# flux_[MgI]_4562.48       EW_[FeVII]_3758.9        e_vel_[FeII]_5184.8
# flux_MgI]_4571.1         EW_HI_3770.63            e_vel_[ArIII]_5191.82
# flux_[FeII]_4632.27      EW_HI_3797.9             e_vel_[NI]_5197.9
# flux_[FeIII]_4658.1      EW_HeI_3819.61           e_vel_[NI]_5200.26
# flux_HeII_4685.68        EW_HI_3835.38            e_vel_[FeII]_5220.06
# flux_[FeIII]_4701.62     EW_[NeIII]_3868.75       e_vel_[FeII]_5261.61
# flux_[ArIV]_4711.33      EW_HeI_3888.65           e_vel_[FeII]_5268.88
# flux_HeI_4713.14         EW_HI_3889.05            e_vel_[FeIII]_5270.3
# flux_[NeIV]_4724.17      EW_CaII_3933.66          e_vel_[FeII]_5273.38
# flux_[FeIII]_4733.93     EW_HeI_3964.73           e_vel_[FeVI]_5277.8
# flux_[ArIV]_4740.2       EW_[NeIII]_3967.46       e_vel_[FeII]_5296.84
# flux_[FeIII]_4754.83     EW_CaII_3968.47          e_vel_[FeXIV]_5302.86
# flux_[FeIII]_4769.6      EW_Hepsilon_3970.07      e_vel_[CaV]_5309.18
# flux_[FeII]_4774.74      EW_HeI_4026.19           e_vel_[FeII]_5333.65
# flux_[FeIII]_4777.88     EW_[SII]_4068.6          e_vel_[FeVI]_5335.2
# flux_[FeIII]_4813.9      EW_[SII]_4076.35         e_vel_[FeII]_5376.47
# flux_[FeII]_4814.55      EW_Hdelta_4101.77        e_vel_HeII_5411.52
# flux_Hbeta_4861.36       EW_HeI_4120.81           e_vel_[FeII]_5412.64
# flux_[FeIII]_4881.11     EW_[FeII]_4177.21        e_vel_[FeVI]_5424.2
# flux_[FeII]_4889.63      EW_[FeV]_4227.2          e_vel_[FeVI]_5426.6
# flux_[FeVII]_4893.4      EW_[FeII]_4243.98        e_vel_[FeVI]_5484.8
# flux_[FeII]_4905.35      EW_CII_4267.0            e_vel_[ClIII]_5517.71
# flux_HeI_4921.93         EW_[FeII]_4287.4         e_vel_[FeII]_5527.33
# flux_[FeIII]_4924.5      EW_Hgamma_4340.49        e_vel_[OI]_5577.34
# flux_[FeIII]_4930.5      EW_[FeII]_4358.1         e_vel_[FeVI]_5631.1
# flux_[FeVII]_4942.5      EW_[FeII]_4358.37        e_vel_[FeVI]_5677.0
# flux_[OIII]_4958.91      EW_[FeII]_4359.34        e_vel_[FeVII]_5720.7
# flux_[FeVI]_4972.5       EW_[OIII]_4363.21        e_vel_[NII]_5754.59
# flux_[FeII]_4973.39      EW_[FeII]_4413.78        e_disp_HI_3686.83
# flux_[FeIII]_4985.9      EW_[FeII]_4414.45        e_disp_HI_3691.56
# flux_[OIII]_5006.84      EW_[FeII]_4416.27        e_disp_HI_3697.15
# flux_HeI_5015.68         EW_[FeII]_4452.11        e_disp_HI_3703.85
# flux_[FeII]_5039.1       EW_[FeII]_4457.95        e_disp_HI_3711.97
# flux_[FeII]_5072.4       EW_[FeII]_4470.29        e_disp_[OII]_3726.03
# flux_[FeII]_5107.95      EW_HeI_4471.48           e_disp_[OII]_3728.82
# flux_[FeII]_5111.63      EW_[FeII]_4474.91        e_disp_HI_3734.37
# flux_[FeVI]_5145.8       EW_[NiII]_4485.21        e_disp_HI_3750.15
# flux_[FeII]_5158.0       EW_[MgI]_4562.48         e_disp_[FeVII]_3758.9
# flux_[FeVII]_5158.9      EW_MgI]_4571.1           e_disp_HI_3770.63
# flux_[FeVI]_5176.0       EW_[FeII]_4632.27        e_disp_HI_3797.9
# flux_[FeII]_5184.8       EW_[FeIII]_4658.1        e_disp_HeI_3819.61
# flux_[ArIII]_5191.82     EW_HeII_4685.68          e_disp_HI_3835.38
# flux_[NI]_5197.9         EW_[FeIII]_4701.62       e_disp_[NeIII]_3868.75
# flux_[NI]_5200.26        EW_[ArIV]_4711.33        e_disp_HeI_3888.65
# flux_[FeII]_5220.06      EW_HeI_4713.14           e_disp_HI_3889.05
# flux_[FeII]_5261.61      EW_[NeIV]_4724.17        e_disp_CaII_3933.66
# flux_[FeII]_5268.88      EW_[FeIII]_4733.93       e_disp_HeI_3964.73
# flux_[FeIII]_5270.3      EW_[ArIV]_4740.2         e_disp_[NeIII]_3967.46
# flux_[FeII]_5273.38      EW_[FeIII]_4754.83       e_disp_CaII_3968.47
# flux_[FeVI]_5277.8       EW_[FeIII]_4769.6        e_disp_Hepsilon_3970.07
# flux_[FeII]_5296.84      EW_[FeII]_4774.74        e_disp_HeI_4026.19
# flux_[FeXIV]_5302.86     EW_[FeIII]_4777.88       e_disp_[SII]_4068.6
# flux_[CaV]_5309.18       EW_[FeIII]_4813.9        e_disp_[SII]_4076.35
# flux_[FeII]_5333.65      EW_[FeII]_4814.55        e_disp_Hdelta_4101.77
# flux_[FeVI]_5335.2       EW_Hbeta_4861.36         e_disp_HeI_4120.81
# flux_[FeII]_5376.47      EW_[FeIII]_4881.11       e_disp_[FeII]_4177.21
# flux_HeII_5411.52        EW_[FeII]_4889.63        e_disp_[FeV]_4227.2
# flux_[FeII]_5412.64      EW_[FeVII]_4893.4        e_disp_[FeII]_4243.98
# flux_[FeVI]_5424.2       EW_[FeII]_4905.35        e_disp_CII_4267.0
# flux_[FeVI]_5426.6       EW_HeI_4921.93           e_disp_[FeII]_4287.4
# flux_[FeVI]_5484.8       EW_[FeIII]_4924.5        e_disp_Hgamma_4340.49
# flux_[ClIII]_5517.71     EW_[FeIII]_4930.5        e_disp_[FeII]_4358.1
# flux_[FeII]_5527.33      EW_[FeVII]_4942.5        e_disp_[FeII]_4358.37
# flux_[OI]_5577.34        EW_[OIII]_4958.91        e_disp_[FeII]_4359.34
# flux_[FeVI]_5631.1       EW_[FeVI]_4972.5         e_disp_[OIII]_4363.21
# flux_[FeVI]_5677.0       EW_[FeII]_4973.39        e_disp_[FeII]_4413.78
# flux_[FeVII]_5720.7      EW_[FeIII]_4985.9        e_disp_[FeII]_4414.45
# flux_[NII]_5754.59       EW_[OIII]_5006.84        e_disp_[FeII]_4416.27
# vel_HI_3686.83           EW_HeI_5015.68           e_disp_[FeII]_4452.11
# vel_HI_3691.56           EW_[FeII]_5039.1         e_disp_[FeII]_4457.95
# vel_HI_3697.15           EW_[FeII]_5072.4         e_disp_[FeII]_4470.29
# vel_HI_3703.85           EW_[FeII]_5107.95        e_disp_HeI_4471.48
# vel_HI_3711.97           EW_[FeII]_5111.63        e_disp_[FeII]_4474.91
# vel_[OII]_3726.03        EW_[FeVI]_5145.8         e_disp_[NiII]_4485.21
# vel_[OII]_3728.82        EW_[FeII]_5158.0         e_disp_[MgI]_4562.48
# vel_HI_3734.37           EW_[FeVII]_5158.9        e_disp_MgI]_4571.1
# vel_HI_3750.15           EW_[FeVI]_5176.0         e_disp_[FeII]_4632.27
# vel_[FeVII]_3758.9       EW_[FeII]_5184.8         e_disp_[FeIII]_4658.1
# vel_HI_3770.63           EW_[ArIII]_5191.82       e_disp_HeII_4685.68
# vel_HI_3797.9            EW_[NI]_5197.9           e_disp_[FeIII]_4701.62
# vel_HeI_3819.61          EW_[NI]_5200.26          e_disp_[ArIV]_4711.33
# vel_HI_3835.38           EW_[FeII]_5220.06        e_disp_HeI_4713.14
# vel_[NeIII]_3868.75      EW_[FeII]_5261.61        e_disp_[NeIV]_4724.17
# vel_HeI_3888.65          EW_[FeII]_5268.88        e_disp_[FeIII]_4733.93
# vel_HI_3889.05           EW_[FeIII]_5270.3        e_disp_[ArIV]_4740.2
# vel_CaII_3933.66         EW_[FeII]_5273.38        e_disp_[FeIII]_4754.83
# vel_HeI_3964.73          EW_[FeVI]_5277.8         e_disp_[FeIII]_4769.6
# vel_[NeIII]_3967.46      EW_[FeII]_5296.84        e_disp_[FeII]_4774.74
# vel_CaII_3968.47         EW_[FeXIV]_5302.86       e_disp_[FeIII]_4777.88
# vel_Hepsilon_3970.07     EW_[CaV]_5309.18         e_disp_[FeIII]_4813.9
# vel_HeI_4026.19          EW_[FeII]_5333.65        e_disp_[FeII]_4814.55
# vel_[SII]_4068.6         EW_[FeVI]_5335.2         e_disp_Hbeta_4861.36
# vel_[SII]_4076.35        EW_[FeII]_5376.47        e_disp_[FeIII]_4881.11
# vel_Hdelta_4101.77       EW_HeII_5411.52          e_disp_[FeII]_4889.63
# vel_HeI_4120.81          EW_[FeII]_5412.64        e_disp_[FeVII]_4893.4
# vel_[FeII]_4177.21       EW_[FeVI]_5424.2         e_disp_[FeII]_4905.35
# vel_[FeV]_4227.2         EW_[FeVI]_5426.6         e_disp_HeI_4921.93
# vel_[FeII]_4243.98       EW_[FeVI]_5484.8         e_disp_[FeIII]_4924.5
# vel_CII_4267.0           EW_[ClIII]_5517.71       e_disp_[FeIII]_4930.5
# vel_[FeII]_4287.4        EW_[FeII]_5527.33        e_disp_[FeVII]_4942.5
# vel_Hgamma_4340.49       EW_[OI]_5577.34          e_disp_[OIII]_4958.91
# vel_[FeII]_4358.1        EW_[FeVI]_5631.1         e_disp_[FeVI]_4972.5
# vel_[FeII]_4358.37       EW_[FeVI]_5677.0         e_disp_[FeII]_4973.39
# vel_[FeII]_4359.34       EW_[FeVII]_5720.7        e_disp_[FeIII]_4985.9
# vel_[OIII]_4363.21       EW_[NII]_5754.59         e_disp_[OIII]_5006.84
# vel_[FeII]_4413.78       e_flux_HI_3686.83        e_disp_HeI_5015.68
# vel_[FeII]_4414.45       e_flux_HI_3691.56        e_disp_[FeII]_5039.1
# vel_[FeII]_4416.27       e_flux_HI_3697.15        e_disp_[FeII]_5072.4
# vel_[FeII]_4452.11       e_flux_HI_3703.85        e_disp_[FeII]_5107.95
# vel_[FeII]_4457.95       e_flux_HI_3711.97        e_disp_[FeII]_5111.63
# vel_[FeII]_4470.29       e_flux_[OII]_3726.03     e_disp_[FeVI]_5145.8
# vel_HeI_4471.48          e_flux_[OII]_3728.82     e_disp_[FeII]_5158.0
# vel_[FeII]_4474.91       e_flux_HI_3734.37        e_disp_[FeVII]_5158.9
# vel_[NiII]_4485.21       e_flux_HI_3750.15        e_disp_[FeVI]_5176.0
# vel_[MgI]_4562.48        e_flux_[FeVII]_3758.9    e_disp_[FeII]_5184.8
# vel_MgI]_4571.1          e_flux_HI_3770.63        e_disp_[ArIII]_5191.82
# vel_[FeII]_4632.27       e_flux_HI_3797.9         e_disp_[NI]_5197.9
# vel_[FeIII]_4658.1       e_flux_HeI_3819.61       e_disp_[NI]_5200.26
# vel_HeII_4685.68         e_flux_HI_3835.38        e_disp_[FeII]_5220.06
# vel_[FeIII]_4701.62      e_flux_[NeIII]_3868.75   e_disp_[FeII]_5261.61
# vel_[ArIV]_4711.33       e_flux_HeI_3888.65       e_disp_[FeII]_5268.88
# vel_HeI_4713.14          e_flux_HI_3889.05        e_disp_[FeIII]_5270.3
# vel_[NeIV]_4724.17       e_flux_CaII_3933.66      e_disp_[FeII]_5273.38
# vel_[FeIII]_4733.93      e_flux_HeI_3964.73       e_disp_[FeVI]_5277.8
# vel_[ArIV]_4740.2        e_flux_[NeIII]_3967.46   e_disp_[FeII]_5296.84
# vel_[FeIII]_4754.83      e_flux_CaII_3968.47      e_disp_[FeXIV]_5302.86
# vel_[FeIII]_4769.6       e_flux_Hepsilon_3970.07  e_disp_[CaV]_5309.18
# vel_[FeII]_4774.74       e_flux_HeI_4026.19       e_disp_[FeII]_5333.65
# vel_[FeIII]_4777.88      e_flux_[SII]_4068.6      e_disp_[FeVI]_5335.2
# vel_[FeIII]_4813.9       e_flux_[SII]_4076.35     e_disp_[FeII]_5376.47
# vel_[FeII]_4814.55       e_flux_Hdelta_4101.77    e_disp_HeII_5411.52
# vel_Hbeta_4861.36        e_flux_HeI_4120.81       e_disp_[FeII]_5412.64
# vel_[FeIII]_4881.11      e_flux_[FeII]_4177.21    e_disp_[FeVI]_5424.2
# vel_[FeII]_4889.63       e_flux_[FeV]_4227.2      e_disp_[FeVI]_5426.6
# vel_[FeVII]_4893.4       e_flux_[FeII]_4243.98    e_disp_[FeVI]_5484.8
# vel_[FeII]_4905.35       e_flux_CII_4267.0        e_disp_[ClIII]_5517.71
# vel_HeI_4921.93          e_flux_[FeII]_4287.4     e_disp_[FeII]_5527.33
# vel_[FeIII]_4924.5       e_flux_Hgamma_4340.49    e_disp_[OI]_5577.34
# vel_[FeIII]_4930.5       e_flux_[FeII]_4358.1     e_disp_[FeVI]_5631.1
# vel_[FeVII]_4942.5       e_flux_[FeII]_4358.37    e_disp_[FeVI]_5677.0
# vel_[OIII]_4958.91       e_flux_[FeII]_4359.34    e_disp_[FeVII]_5720.7
# vel_[FeVI]_4972.5        e_flux_[OIII]_4363.21    e_disp_[NII]_5754.59
# vel_[FeII]_4973.39       e_flux_[FeII]_4413.78    e_EW_HI_3686.83
# vel_[FeIII]_4985.9       e_flux_[FeII]_4414.45    e_EW_HI_3691.56
# vel_[OIII]_5006.84       e_flux_[FeII]_4416.27    e_EW_HI_3697.15
# vel_HeI_5015.68          e_flux_[FeII]_4452.11    e_EW_HI_3703.85
# vel_[FeII]_5039.1        e_flux_[FeII]_4457.95    e_EW_HI_3711.97
# vel_[FeII]_5072.4        e_flux_[FeII]_4470.29    e_EW_[OII]_3726.03
# vel_[FeII]_5107.95       e_flux_HeI_4471.48       e_EW_[OII]_3728.82
# vel_[FeII]_5111.63       e_flux_[FeII]_4474.91    e_EW_HI_3734.37
# vel_[FeVI]_5145.8        e_flux_[NiII]_4485.21    e_EW_HI_3750.15
# vel_[FeII]_5158.0        e_flux_[MgI]_4562.48     e_EW_[FeVII]_3758.9
# vel_[FeVII]_5158.9       e_flux_MgI]_4571.1       e_EW_HI_3770.63
# vel_[FeVI]_5176.0        e_flux_[FeII]_4632.27    e_EW_HI_3797.9
# vel_[FeII]_5184.8        e_flux_[FeIII]_4658.1    e_EW_HeI_3819.61
# vel_[ArIII]_5191.82      e_flux_HeII_4685.68      e_EW_HI_3835.38
# vel_[NI]_5197.9          e_flux_[FeIII]_4701.62   e_EW_[NeIII]_3868.75
# vel_[NI]_5200.26         e_flux_[ArIV]_4711.33    e_EW_HeI_3888.65
# vel_[FeII]_5220.06       e_flux_HeI_4713.14       e_EW_HI_3889.05
# vel_[FeII]_5261.61       e_flux_[NeIV]_4724.17    e_EW_CaII_3933.66
# vel_[FeII]_5268.88       e_flux_[FeIII]_4733.93   e_EW_HeI_3964.73
# vel_[FeIII]_5270.3       e_flux_[ArIV]_4740.2     e_EW_[NeIII]_3967.46
# vel_[FeII]_5273.38       e_flux_[FeIII]_4754.83   e_EW_CaII_3968.47
# vel_[FeVI]_5277.8        e_flux_[FeIII]_4769.6    e_EW_Hepsilon_3970.07
# vel_[FeII]_5296.84       e_flux_[FeII]_4774.74    e_EW_HeI_4026.19
# vel_[FeXIV]_5302.86      e_flux_[FeIII]_4777.88   e_EW_[SII]_4068.6
# vel_[CaV]_5309.18        e_flux_[FeIII]_4813.9    e_EW_[SII]_4076.35
# vel_[FeII]_5333.65       e_flux_[FeII]_4814.55    e_EW_Hdelta_4101.77
# vel_[FeVI]_5335.2        e_flux_Hbeta_4861.36     e_EW_HeI_4120.81
# vel_[FeII]_5376.47       e_flux_[FeIII]_4881.11   e_EW_[FeII]_4177.21
# vel_HeII_5411.52         e_flux_[FeII]_4889.63    e_EW_[FeV]_4227.2
# vel_[FeII]_5412.64       e_flux_[FeVII]_4893.4    e_EW_[FeII]_4243.98
# vel_[FeVI]_5424.2        e_flux_[FeII]_4905.35    e_EW_CII_4267.0
# vel_[FeVI]_5426.6        e_flux_HeI_4921.93       e_EW_[FeII]_4287.4
# vel_[FeVI]_5484.8        e_flux_[FeIII]_4924.5    e_EW_Hgamma_4340.49
# vel_[ClIII]_5517.71      e_flux_[FeIII]_4930.5    e_EW_[FeII]_4358.1
# disp_[FeIII]_4777.88     e_vel_[SII]_4068.6       e_EW_[FeVI]_5335.2
# disp_[FeIII]_4813.9      e_vel_[SII]_4076.35      e_EW_[FeII]_5376.47
# disp_[FeII]_4814.55      e_vel_Hdelta_4101.77     e_EW_HeII_5411.52
# disp_Hbeta_4861.36       e_vel_HeI_4120.81        e_EW_[FeII]_5412.64
# disp_[FeIII]_4881.11     e_vel_[FeII]_4177.21     e_EW_[FeVI]_5424.2
# disp_[FeII]_4889.63      e_vel_[FeV]_4227.2       e_EW_[FeVI]_5426.6
# disp_[FeVII]_4893.4      e_vel_[FeII]_4243.98     e_EW_[FeVI]_5484.8
# disp_[FeII]_4905.35      e_vel_CII_4267.0         e_EW_[ClIII]_5517.71
# disp_HeI_4921.93         e_vel_[FeII]_4287.4      e_EW_[FeII]_5527.33
# disp_[FeIII]_4924.5      e_vel_Hgamma_4340.49     e_EW_[OI]_5577.34
# disp_[FeIII]_4930.5      e_vel_[FeII]_4358.1      e_EW_[FeVI]_5631.1
# disp_[FeVII]_4942.5      e_vel_[FeII]_4358.37     e_EW_[FeVI]_5677.0
# disp_[OIII]_4958.91      e_vel_[FeII]_4359.34     e_EW_[FeVII]_5720.7
# disp_[FeVI]_4972.5       e_vel_[OIII]_4363.21     e_EW_[NII]_5754.59
# disp_[FeII]_4973.39      e_vel_[FeII]_4413.78
# disp_[FeIII]_4985.9      e_vel_[FeII]_4414.45
# ----------------------------------
# |        NPE_R                    |
# ----------------------------------
# id                     disp_CII_7236.0        e_vel_[NII]_6583.45
# flux_HeI_5876.0        disp_HeI_7281.35       e_vel_HeI_6678.15
# flux_NaI_5889.95       disp_[FeI]_7290.42     e_vel_[SII]_6716.44
# flux_NaI_5895.92       disp_[CaII]_7291.46    e_vel_[SII]_6730.82
# flux_[FeVII]_6087.0    disp_[OII]_7318.92     e_vel_FeI_6855.18
# flux_[OI]_6300.3       disp_[CaII]_7323.88    e_vel_[ArV]_7005.67
# flux_[SIII]_6312.06    disp_[OII]_7329.66     e_vel_HeI_7065.19
# flux_[OI]_6363.78      disp_[NiII]_7377.83    e_vel_[ArIII]_7135.8
# flux_[FeX]_6374.51     disp_[FeII]_7388.16    e_vel_[FeII]_7155.14
# flux_[ArV]_6435.1      disp_[NiII]_7411.61    e_vel_[FeII]_7171.98
# flux_[NII]_6548.05     disp_[FeII]_7452.5     e_vel_CII_7236.0
# flux_Halpha_6562.85    EW_HeI_5876.0          e_vel_HeI_7281.35
# flux_[NII]_6583.45     EW_NaI_5889.95         e_vel_[FeI]_7290.42
# flux_HeI_6678.15       EW_NaI_5895.92         e_vel_[CaII]_7291.46
# flux_[SII]_6716.44     EW_[FeVII]_6087.0      e_vel_[OII]_7318.92
# flux_[SII]_6730.82     EW_[OI]_6300.3         e_vel_[CaII]_7323.88
# flux_FeI_6855.18       EW_[SIII]_6312.06      e_vel_[OII]_7329.66
# flux_[ArV]_7005.67     EW_[OI]_6363.78        e_vel_[NiII]_7377.83
# flux_HeI_7065.19       EW_[FeX]_6374.51       e_vel_[FeII]_7388.16
# sigma_kms_HeII_4685.68      sigma_kms_pek_4958.91       X_sq_[FeII]_5184.8          fr_HI_8314.89
# sigma_kms_[FeIII]_4701.62   sigma_kms_pek_5006.84       fr_[FeII]_5184.8            X_sq_HI_8324.06
# sigma_kms_[ArIV]_4711.33    sigma_kms_pek_6300.3        X_sq_[ArIII]_5191.82        fr_HI_8324.06
# sigma_kms_HeI_4713.14       sigma_kms_pek_6548.05       fr_[ArIII]_5191.82          X_sq_HI_8334.42
# sigma_kms_[NeIV]_4724.17    sigma_kms_pek_6562.85       X_sq_[NI]_5197.9            fr_HI_8334.42
# sigma_kms_[FeIII]_4733.93   sigma_kms_pek_6583.45       fr_[NI]_5197.9              X_sq_HI_8345.55
# sigma_kms_[ArIV]_4740.2     sigma_kms_pek_6716.44       X_sq_[NI]_5200.26           fr_HI_8345.55
# sigma_kms_[FeIII]_4754.83   sigma_kms_pek_6730.82       fr_[NI]_5200.26             X_sq_[CrII]_8357.51
# sigma_kms_[FeIII]_4769.6    sigma_kms_pek_9069.0        X_sq_[FeII]_5220.06         fr_[CrII]_8357.51
# sigma_kms_[FeII]_4774.74    sigma_kms_pek_9531.1        fr_[FeII]_5220.06           X_sq_HI_8359.0
# sigma_kms_[FeIII]_4777.88   X_sq_st                     X_sq_[FeII]_5261.61         fr_HI_8359.0
# sigma_kms_[FeIII]_4813.9    X_sq_st_np                  fr_[FeII]_5261.61           X_sq_HI_8374.48
# sigma_kms_[FeII]_4814.55    X_sq_st_pek                 X_sq_[FeII]_5268.88         fr_HI_8374.48
# sigma_kms_Hbeta_4861.36     X_sq_HI_3686.83             fr_[FeII]_5268.88           X_sq_HI_8392.4
# sigma_kms_[FeIII]_4881.11   fr_HI_3686.83               X_sq_[FeIII]_5270.3         fr_HI_8392.4
# sigma_kms_[FeII]_4889.63    X_sq_HI_3691.56             fr_[FeIII]_5270.3           X_sq_OI_8446.0
# sigma_kms_[FeVII]_4893.4    fr_HI_3691.56               X_sq_[FeII]_5273.38         fr_OI_8446.0
# sigma_kms_[FeII]_4905.35    X_sq_HI_3697.15             fr_[FeII]_5273.38           X_sq_HI_8467.25
# sigma_kms_HeI_4921.93       fr_HI_3697.15               X_sq_[FeVI]_5277.8          fr_HI_8467.25
# sigma_kms_[FeIII]_4924.5    X_sq_HI_3703.85             fr_[FeVI]_5277.8            X_sq_CaII_8498.02
# sigma_kms_[FeIII]_4930.5    fr_HI_3703.85               X_sq_[FeII]_5296.84         fr_CaII_8498.02
# sigma_kms_[FeVII]_4942.5    X_sq_HI_3711.97             fr_[FeII]_5296.84           X_sq_HI_8502.48
# sigma_kms_[OIII]_4958.91    fr_HI_3711.97               X_sq_[FeXIV]_5302.86        fr_HI_8502.48
# sigma_kms_[FeVI]_4972.5     X_sq_[OII]_3726.03          fr_[FeXIV]_5302.86          X_sq_CaII_8542.09
# sigma_kms_[FeII]_4973.39    fr_[OII]_3726.03            X_sq_[CaV]_5309.18          fr_CaII_8542.09
# sigma_kms_[FeIII]_4985.9    X_sq_[OII]_3728.82          fr_[CaV]_5309.18            X_sq_HI_8545.38
# sigma_kms_[OIII]_5006.84    fr_[OII]_3728.82            X_sq_[FeII]_5333.65         fr_HI_8545.38
# sigma_kms_HeI_5015.68       X_sq_HI_3734.37             fr_[FeII]_5333.65           X_sq_[ClII]_8578.7
# sigma_kms_[FeII]_5039.1     fr_HI_3734.37               X_sq_[FeVI]_5335.2          fr_[ClII]_8578.7
# sigma_kms_[FeII]_5072.4     X_sq_HI_3750.15             fr_[FeVI]_5335.2            X_sq_HI_8598.39
# sigma_kms_[FeII]_5107.95    fr_HI_3750.15               X_sq_[FeII]_5376.47         fr_HI_8598.39
# sigma_kms_[FeII]_5111.63    X_sq_[FeVII]_3758.9         fr_[FeII]_5376.47           X_sq_[FeII]_8616.96
# sigma_kms_[FeVI]_5145.8     fr_[FeVII]_3758.9           X_sq_HeII_5411.52           fr_[FeII]_8616.96
# sigma_kms_[FeII]_5158.0     X_sq_HI_3770.63             fr_HeII_5411.52             X_sq_CaII_8662.14
# sigma_kms_[FeVII]_5158.9    fr_HI_3770.63               X_sq_[FeII]_5412.64         fr_CaII_8662.14
# sigma_kms_[FeVI]_5176.0     X_sq_HI_3797.9              fr_[FeII]_5412.64           X_sq_HI_8665.02
# sigma_kms_[FeII]_5184.8     fr_HI_3797.9                X_sq_[FeVI]_5424.2          fr_HI_8665.02
# sigma_kms_[ArIII]_5191.82   X_sq_HeI_3819.61            fr_[FeVI]_5424.2            X_sq_[CI]_8727.13
# sigma_kms_[NI]_5197.9       fr_HeI_3819.61              X_sq_[FeVI]_5426.6          fr_[CI]_8727.13
# sigma_kms_[NI]_5200.26      X_sq_HI_3835.38             fr_[FeVI]_5426.6            X_sq_HI_8750.47
# sigma_kms_[FeII]_5220.06    fr_HI_3835.38               X_sq_[FeVI]_5484.8          fr_HI_8750.47
# sigma_kms_[FeII]_5261.61    X_sq_[NeIII]_3868.75        fr_[FeVI]_5484.8            X_sq_HI_8862.78
# sigma_kms_[FeII]_5268.88    fr_[NeIII]_3868.75          X_sq_[ClIII]_5517.71        fr_HI_8862.78
# sigma_kms_[FeIII]_5270.3    X_sq_HeI_3888.65            fr_[ClIII]_5517.71          X_sq_[FeII]_8891.88
# sigma_kms_[FeII]_5273.38    fr_HeI_3888.65              X_sq_[FeII]_5527.33         fr_[FeII]_8891.88
# sigma_kms_[FeVI]_5277.8     X_sq_HI_3889.05             fr_[FeII]_5527.33           X_sq_HI_9014.91
# sigma_kms_[FeII]_5296.84    fr_HI_3889.05               X_sq_[OI]_5577.34           fr_HI_9014.91
# sigma_kms_[FeXIV]_5302.86   X_sq_CaII_3933.66           fr_[OI]_5577.34             X_sq_[FeII]_9033.45
# sigma_kms_[CaV]_5309.18     fr_CaII_3933.66             X_sq_[FeVI]_5631.1          fr_[FeII]_9033.45
# sigma_kms_[FeII]_5333.65    X_sq_HeI_3964.73            fr_[FeVI]_5631.1            X_sq_[FeII]_9051.92
# sigma_kms_[FeVI]_5335.2     fr_HeI_3964.73              X_sq_[FeVI]_5677.0          fr_[FeII]_9051.92
# sigma_kms_HeI_6678.15       fr_[FeII]_4287.4            X_sq_Halpha_6562.85         fr_pe_3728.82
# sigma_kms_[SII]_6716.44     X_sq_Hgamma_4340.49         fr_Halpha_6562.85           X_sq_pe_4101.77
# sigma_kms_[SII]_6730.82     fr_Hgamma_4340.49           X_sq_[NII]_6583.45          fr_pe_4101.77
# sigma_kms_FeI_6855.18       X_sq_[FeII]_4358.1          fr_[NII]_6583.45            X_sq_pe_4340.49
# sigma_kms_[ArV]_7005.67     fr_[FeII]_4358.1            X_sq_HeI_6678.15            fr_pe_4340.49
# sigma_kms_HeI_7065.19       X_sq_[FeII]_4358.37         fr_HeI_6678.15              X_sq_pe_4861.36
# sigma_kms_[ArIII]_7135.8    fr_[FeII]_4358.37           X_sq_[SII]_6716.44          fr_pe_4861.36
# sigma_kms_[FeII]_7155.14    X_sq_[FeII]_4359.34         fr_[SII]_6716.44            X_sq_pe_4958.91
# sigma_kms_[FeII]_7171.98    fr_[FeII]_4359.34           X_sq_[SII]_6730.82          fr_pe_4958.91
# sigma_kms_CII_7236.0        X_sq_[OIII]_4363.21         fr_[SII]_6730.82            X_sq_pe_5006.84
# sigma_kms_HeI_7281.35       fr_[OIII]_4363.21           X_sq_FeI_6855.18            fr_pe_5006.84
# sigma_kms_[FeI]_7290.42     X_sq_[FeII]_4413.78         fr_FeI_6855.18              X_sq_pe_6300.3
# sigma_kms_[CaII]_7291.46    fr_[FeII]_4413.78           X_sq_[ArV]_7005.67          fr_pe_6300.3
# sigma_kms_[OII]_7318.92     X_sq_[FeII]_4414.45         fr_[ArV]_7005.67            X_sq_pe_6548.05
# sigma_kms_[CaII]_7323.88    fr_[FeII]_4414.45           X_sq_HeI_7065.19            fr_pe_6548.05
# sigma_kms_[OII]_7329.66     X_sq_[FeII]_4416.27         fr_HeI_7065.19              X_sq_pe_6562.85
# sigma_kms_[NiII]_7377.83    fr_[FeII]_4416.27           X_sq_[ArIII]_7135.8         fr_pe_6562.85
# sigma_kms_[FeII]_7388.16    X_sq_[FeII]_4452.11         fr_[ArIII]_7135.8           X_sq_pe_6583.45
# sigma_kms_[NiII]_7411.61    fr_[FeII]_4452.11           X_sq_[FeII]_7155.14         fr_pe_6583.45
# sigma_kms_[FeII]_7452.5     X_sq_[FeII]_4457.95         fr_[FeII]_7155.14           X_sq_pe_6716.44
# sigma_kms_[FeII]_7637.52    fr_[FeII]_4457.95           X_sq_[FeII]_7171.98         fr_pe_6716.44
# sigma_kms_[FeII]_7686.19    X_sq_[FeII]_4470.29         fr_[FeII]_7171.98           X_sq_pe_6730.82
# sigma_kms_[FeII]_7686.9     fr_[FeII]_4470.29           X_sq_CII_7236.0             fr_pe_6730.82
# sigma_kms_[ArIII]_7751.06   X_sq_HeI_4471.48            fr_CII_7236.0               X_sq_pe_9069.0
# sigma_kms_OI_7774.0         fr_HeI_4471.48              X_sq_HeI_7281.35            fr_pe_9069.0
# sigma_kms_[FeXI]_7891.8     X_sq_[FeII]_4474.91         fr_HeI_7281.35              X_sq_pe_9531.1
# sigma_kms_[CrII]_7999.85    fr_[FeII]_4474.91           X_sq_[FeI]_7290.42          fr_pe_9531.1
# sigma_kms_[CrII]_8125.22    X_sq_[NiII]_4485.21         fr_[FeI]_7290.42            X_sq_pek_3726.03
# sigma_kms_[CrII]_8229.55    fr_[NiII]_4485.21           X_sq_[CaII]_7291.46         fr_pek_3726.03
# sigma_kms_HeII_8236.77      X_sq_[MgI]_4562.48          fr_[CaII]_7291.46           X_sq_pek_3728.82
# sigma_kms_HI_8239.24        fr_[MgI]_4562.48            X_sq_[OII]_7318.92          fr_pek_3728.82
# sigma_kms_HI_8240.82        X_sq_MgI]_4571.1            fr_[OII]_7318.92            X_sq_pek_4101.77
# sigma_kms_HI_8242.51        fr_MgI]_4571.1              X_sq_[CaII]_7323.88         fr_pek_4101.77
# sigma_kms_HI_8244.32        X_sq_[FeII]_4632.27         fr_[CaII]_7323.88           X_sq_pek_4340.49
# sigma_kms_HI_8246.27        fr_[FeII]_4632.27           X_sq_[OII]_7329.66          fr_pek_4340.49
# sigma_kms_HI_8248.35        X_sq_[FeIII]_4658.1         fr_[OII]_7329.66            X_sq_pek_4861.36
# sigma_kms_HI_8250.6         fr_[FeIII]_4658.1           X_sq_[NiII]_7377.83         fr_pek_4861.36
# sigma_kms_HI_8253.03        X_sq_HeII_4685.68           fr_[NiII]_7377.83           X_sq_pek_4958.91
# sigma_kms_HI_8255.65        fr_HeII_4685.68             X_sq_[FeII]_7388.16         fr_pek_4958.91
# sigma_kms_HI_8258.49        X_sq_[FeIII]_4701.62        fr_[FeII]_7388.16           X_sq_pek_5006.84
# sigma_kms_HI_8261.57        fr_[FeIII]_4701.62          X_sq_[NiII]_7411.61         fr_pek_5006.84
# sigma_kms_HI_8264.92        X_sq_[ArIV]_4711.33         fr_[NiII]_7411.61           X_sq_pek_6300.3
# sigma_kms_HI_8268.57        fr_[ArIV]_4711.33           X_sq_[FeII]_7452.5          fr_pek_6300.3
# sigma_kms_HI_8272.56        X_sq_HeI_4713.14            fr_[FeII]_7452.5            X_sq_pek_6548.05
# sigma_kms_HI_8276.94        fr_HeI_4713.14              X_sq_[FeII]_7637.52         fr_pek_6548.05
# sigma_kms_HI_8281.75        X_sq_[NeIV]_4724.17         fr_[FeII]_7637.52           X_sq_pek_6562.85
# sigma_kms_HI_8287.06        fr_[NeIV]_4724.17           X_sq_[FeII]_7686.19         fr_pek_6562.85
# sigma_kms_HI_8292.94        X_sq_[FeIII]_4733.93        fr_[FeII]_7686.19           X_sq_pek_6583.45
# sigma_kms_HI_8299.47        fr_[FeIII]_4733.93          X_sq_[FeII]_7686.9          fr_pek_6583.45
# sigma_kms_[NiII]_8300.99    X_sq_[ArIV]_4740.2          fr_[FeII]_7686.9            X_sq_pek_6716.44
# sigma_kms_HI_8306.75        fr_[ArIV]_4740.2            X_sq_[ArIII]_7751.06        fr_pek_6716.44
# sigma_kms_[CrII]_8308.39    X_sq_[FeIII]_4754.83        fr_[ArIII]_7751.06          X_sq_pek_6730.82
# sigma_kms_HI_8314.89        fr_[FeIII]_4754.83          X_sq_OI_7774.0              fr_pek_6730.82
# sigma_kms_HI_8324.06        X_sq_[FeIII]_4769.6         fr_OI_7774.0                X_sq_pek_9069.0
# sigma_kms_HI_8334.42        fr_[FeIII]_4769.6           X_sq_[FeXI]_7891.8          fr_pek_9069.0
# sigma_kms_HI_8345.55        X_sq_[FeII]_4774.74         fr_[FeXI]_7891.8            X_sq_pek_9531.1
# sigma_kms_[CrII]_8357.51    fr_[FeII]_4774.74           X_sq_[CrII]_7999.85         fr_pek_9531.1
# sigma_kms_HI_8359.0         X_sq_[FeIII]_4777.88        fr_[CrII]_7999.85

# %%
try:
    ##################################################
    # (1.1) Get the data using the sdss_access pachage
    ##################################################
    access.remote()
    kind = 'LV_dap'    
    access.add('lvm_dap', drpver = drpver, dapver = dapver, kind = kind, tileid = tileid, mjd = mjd, expnum = i_expnum, rspid = rsp, snlevel = sn, daptype = 'dap')
    access.set_stream()
    access.commit()
    # PATH to lvmDAP file
    path_to_data_file = access.full('lvm_dap',  drpver = drpver, dapver = dapver, kind = kind, tileid = tileid, mjd = mjd, expnum = i_expnum, rspid = rsp, snlevel = sn, daptype = 'dap')
    print(path_to_data_file)
    # Open data file and print a summary of the Header Data Units
    tab_DAP=read_DAP_file(path_to_data_file,verbose=True)
except:
    ################################################################
    # (1.2) Get the data from a local directory
    ################################################################
    dap_file=f'LV_dap-{rsp}-{sn}-{expnum}.dap.fits.gz'
    dap_file=f'{DIR_DAP}/{dap_file}'
    tab_DAP=read_DAP_file(dap_file,verbose=True)
# Out:
# authentication for netloc=data.sdss5.org set for username=sdss5
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# rsync -Rin --out-format='%B%16l %t %f' "rsync://sdss5@dtn.sdss.org/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits*"
# SDSS_ACCESS> CREATE /tmp/sdss_access/20260420_011
# SDSS_ACCESS> streamlets added to /tmp/sdss_access/20260420_011
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_011/sdss_access_00.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 0 logging to /tmp/sdss_access/20260420_011/sdss_access_00.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_011/sdss_access_01.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 1 logging to /tmp/sdss_access/20260420_011/sdss_access_01.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_011/sdss_access_02.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 2 logging to /tmp/sdss_access/20260420_011/sdss_access_02.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_011/sdss_access_03.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 3 logging to /tmp/sdss_access/20260420_011/sdss_access_03.log
# SDSS_ACCESS> [background]$ 'rsync -avRKL --files-from=/tmp/sdss_access/20260420_011/sdss_access_04.txt rsync://sdss5@dtn.sdss.org/dr20 /home/sanchez/sas/dr20/'
# SDSS_ACCESS> rsync stream 4 logging to /tmp/sdss_access/20260420_011/sdss_access_04.log
# Progress:   0%|          | 0/5 [00:00<?, ?files/s, n_files=5, n_streams=5]
# SDSS_ACCESS> syncing... please wait for 1 rsync streams (1 files) to complete [running for 0 seconds]
# Progress:  20%|██        | 1/5 [00:05<00:20,  5.00s/files, n_files=5, n_streams=5]
# SDSS_ACCESS> Done!
# /home/sanchez/sas/dr20/spectro/lvm/analysis/1.2.0/1.2.0.251218/1056XX/1056242/60349/00012183/dap-rsp108-sn20-00012183.dap.fits
# ---- ALL Table Columns -----
# -------------------------------
# |        PT                   |
# -------------------------------
# id        dec       fiberid
# ra        mask      exposure
# ----------------------------------
# |        RSP                      |
# ----------------------------------
# id             alpha          flux_st        Fe_MW
# MIN_CHISQ      e_alpha        redshift_st    e_Fe_MW
# Teff           Av_st          med_flux_st    alpha_MW
# e_Teff         e_Av_st        e_med_flux_st  e_alpha_MW
# Log_g          z_st           Teff_MW        vel_st
# e_Log_g        e_z_st         e_Teff_MW      log_ML
# Fe             disp_st        Log_g_MW       log_Mass
# e_Fe           e_disp_st      e_Log_g_MW
# ----------------------------------
# |        PE_ord                   |
# ----------------------------------
# id                 vel_pe_4340.49     e_disp_pe_6300.3   disp_pe_6716.44
# flux_pe_3726.03    e_vel_pe_4340.49   vel_pe_6300.3      e_disp_pe_6716.44
# e_flux_pe_3726.03  flux_pe_4861.36    e_vel_pe_6300.3    vel_pe_6716.44
# disp_pe_3726.03    e_flux_pe_4861.36  flux_pe_6548.05    e_vel_pe_6716.44
# e_disp_pe_3726.03  disp_pe_4861.36    e_flux_pe_6548.05  flux_pe_6730.82
# vel_pe_3726.03     e_disp_pe_4861.36  disp_pe_6548.05    e_flux_pe_6730.82
# e_flux_pek_4101.77  flux_pek_5006.84    e_vel_pek_6562.85   vel_pek_9069.0
# disp_pek_4101.77    e_flux_pek_5006.84  flux_pek_6583.45    e_vel_pek_9069.0
# e_disp_pek_4101.77  disp_pek_5006.84    e_flux_pek_6583.45  flux_pek_9531.1
# vel_pek_4101.77     e_disp_pek_5006.84  disp_pek_6583.45    e_flux_pek_9531.1
# e_vel_pek_4101.77   vel_pek_5006.84     e_disp_pek_6583.45  disp_pek_9531.1
# flux_pek_4340.49    e_vel_pek_5006.84   vel_pek_6583.45     e_disp_pek_9531.1
# e_flux_pek_4340.49  flux_pek_6300.3     e_vel_pek_6583.45   vel_pek_9531.1
# disp_pek_4340.49    e_flux_pek_6300.3   flux_pek_6716.44    e_vel_pek_9531.1
# e_disp_pek_4340.49  disp_pek_6300.3     e_flux_pek_6716.44
# ----------------------------------
# |        NPE_B                    |
# ----------------------------------
# id                       disp_[OIII]_5006.84      e_vel_[FeII]_4416.27
# flux_HI_3686.83          disp_HeI_5015.68         e_vel_[FeII]_4452.11
# flux_HI_3691.56          disp_[FeII]_5039.1       e_vel_[FeII]_4457.95
# flux_HI_3697.15          disp_[FeII]_5072.4       e_vel_[FeII]_4470.29
# flux_HI_3703.85          disp_[FeII]_5107.95      e_vel_HeI_4471.48
# flux_HI_3711.97          disp_[FeII]_5111.63      e_vel_[FeII]_4474.91
# flux_[OII]_3726.03       disp_[FeVI]_5145.8       e_vel_[NiII]_4485.21
# flux_[OII]_3728.82       disp_[FeII]_5158.0       e_vel_[MgI]_4562.48
# flux_HI_3734.37          disp_[FeVII]_5158.9      e_vel_MgI]_4571.1
# flux_HI_3750.15          disp_[FeVI]_5176.0       e_vel_[FeII]_4632.27
# flux_[FeVII]_3758.9      disp_[FeII]_5184.8       e_vel_[FeIII]_4658.1
# flux_HI_3770.63          disp_[ArIII]_5191.82     e_vel_HeII_4685.68
# flux_HI_3797.9           disp_[NI]_5197.9         e_vel_[FeIII]_4701.62
# flux_HeI_3819.61         disp_[NI]_5200.26        e_vel_[ArIV]_4711.33
# flux_HI_3835.38          disp_[FeII]_5220.06      e_vel_HeI_4713.14
# flux_[NeIII]_3868.75     disp_[FeII]_5261.61      e_vel_[NeIV]_4724.17
# flux_HeI_3888.65         disp_[FeII]_5268.88      e_vel_[FeIII]_4733.93
# flux_HI_3889.05          disp_[FeIII]_5270.3      e_vel_[ArIV]_4740.2
# flux_CaII_3933.66        disp_[FeII]_5273.38      e_vel_[FeIII]_4754.83
# flux_HeI_3964.73         disp_[FeVI]_5277.8       e_vel_[FeIII]_4769.6
# flux_[NeIII]_3967.46     disp_[FeII]_5296.84      e_vel_[FeII]_4774.74
# flux_CaII_3968.47        disp_[FeXIV]_5302.86     e_vel_[FeIII]_4777.88
# flux_Hepsilon_3970.07    disp_[CaV]_5309.18       e_vel_[FeIII]_4813.9
# flux_HeI_4026.19         disp_[FeII]_5333.65      e_vel_[FeII]_4814.55
# flux_[SII]_4068.6        disp_[FeVI]_5335.2       e_vel_Hbeta_4861.36
# flux_[SII]_4076.35       disp_[FeII]_5376.47      e_vel_[FeIII]_4881.11
# flux_Hdelta_4101.77      disp_HeII_5411.52        e_vel_[FeII]_4889.63
# flux_HeI_4120.81         disp_[FeII]_5412.64      e_vel_[FeVII]_4893.4
# flux_[FeII]_4177.21      disp_[FeVI]_5424.2       e_vel_[FeII]_4905.35
# flux_[FeV]_4227.2        disp_[FeVI]_5426.6       e_vel_HeI_4921.93
# flux_[FeII]_4243.98      disp_[FeVI]_5484.8       e_vel_[FeIII]_4924.5
# flux_CII_4267.0          disp_[ClIII]_5517.71     e_vel_[FeIII]_4930.5
# flux_[FeII]_4287.4       disp_[FeII]_5527.33      e_vel_[FeVII]_4942.5
# flux_Hgamma_4340.49      disp_[OI]_5577.34        e_vel_[OIII]_4958.91
# flux_[FeII]_4358.1       disp_[FeVI]_5631.1       e_vel_[FeVI]_4972.5
# flux_[FeII]_4358.37      disp_[FeVI]_5677.0       e_vel_[FeII]_4973.39
# flux_[FeII]_4359.34      disp_[FeVII]_5720.7      e_vel_[FeIII]_4985.9
# flux_[OIII]_4363.21      disp_[NII]_5754.59       e_vel_[OIII]_5006.84
# flux_[FeII]_4413.78      EW_HI_3686.83            e_vel_HeI_5015.68
# flux_[FeII]_4414.45      EW_HI_3691.56            e_vel_[FeII]_5039.1
# flux_[FeII]_4416.27      EW_HI_3697.15            e_vel_[FeII]_5072.4
# flux_[FeII]_4452.11      EW_HI_3703.85            e_vel_[FeII]_5107.95
# flux_[FeII]_4457.95      EW_HI_3711.97            e_vel_[FeII]_5111.63
# flux_[FeII]_4470.29      EW_[OII]_3726.03         e_vel_[FeVI]_5145.8
# flux_HeI_4471.48         EW_[OII]_3728.82         e_vel_[FeII]_5158.0
# flux_[FeII]_4474.91      EW_HI_3734.37            e_vel_[FeVII]_5158.9
# flux_[NiII]_4485.21      EW_HI_3750.15            e_vel_[FeVI]_5176.0
# flux_[MgI]_4562.48       EW_[FeVII]_3758.9        e_vel_[FeII]_5184.8
# flux_MgI]_4571.1         EW_HI_3770.63            e_vel_[ArIII]_5191.82
# flux_[FeII]_4632.27      EW_HI_3797.9             e_vel_[NI]_5197.9
# flux_[FeIII]_4658.1      EW_HeI_3819.61           e_vel_[NI]_5200.26
# flux_HeII_4685.68        EW_HI_3835.38            e_vel_[FeII]_5220.06
# flux_[FeIII]_4701.62     EW_[NeIII]_3868.75       e_vel_[FeII]_5261.61
# flux_[ArIV]_4711.33      EW_HeI_3888.65           e_vel_[FeII]_5268.88
# flux_HeI_4713.14         EW_HI_3889.05            e_vel_[FeIII]_5270.3
# flux_[NeIV]_4724.17      EW_CaII_3933.66          e_vel_[FeII]_5273.38
# flux_[FeIII]_4733.93     EW_HeI_3964.73           e_vel_[FeVI]_5277.8
# flux_[ArIV]_4740.2       EW_[NeIII]_3967.46       e_vel_[FeII]_5296.84
# flux_[FeIII]_4754.83     EW_CaII_3968.47          e_vel_[FeXIV]_5302.86
# flux_[FeIII]_4769.6      EW_Hepsilon_3970.07      e_vel_[CaV]_5309.18
# flux_[FeII]_4774.74      EW_HeI_4026.19           e_vel_[FeII]_5333.65
# flux_[FeIII]_4777.88     EW_[SII]_4068.6          e_vel_[FeVI]_5335.2
# flux_[FeIII]_4813.9      EW_[SII]_4076.35         e_vel_[FeII]_5376.47
# flux_[FeII]_4814.55      EW_Hdelta_4101.77        e_vel_HeII_5411.52
# flux_Hbeta_4861.36       EW_HeI_4120.81           e_vel_[FeII]_5412.64
# flux_[FeIII]_4881.11     EW_[FeII]_4177.21        e_vel_[FeVI]_5424.2
# flux_[FeII]_4889.63      EW_[FeV]_4227.2          e_vel_[FeVI]_5426.6
# flux_[FeVII]_4893.4      EW_[FeII]_4243.98        e_vel_[FeVI]_5484.8
# flux_[FeII]_4905.35      EW_CII_4267.0            e_vel_[ClIII]_5517.71
# flux_HeI_4921.93         EW_[FeII]_4287.4         e_vel_[FeII]_5527.33
# flux_[FeIII]_4924.5      EW_Hgamma_4340.49        e_vel_[OI]_5577.34
# flux_[FeIII]_4930.5      EW_[FeII]_4358.1         e_vel_[FeVI]_5631.1
# flux_[FeVII]_4942.5      EW_[FeII]_4358.37        e_vel_[FeVI]_5677.0
# flux_[OIII]_4958.91      EW_[FeII]_4359.34        e_vel_[FeVII]_5720.7
# flux_[FeVI]_4972.5       EW_[OIII]_4363.21        e_vel_[NII]_5754.59
# flux_[FeII]_4973.39      EW_[FeII]_4413.78        e_disp_HI_3686.83
# flux_[FeIII]_4985.9      EW_[FeII]_4414.45        e_disp_HI_3691.56
# flux_[OIII]_5006.84      EW_[FeII]_4416.27        e_disp_HI_3697.15
# flux_HeI_5015.68         EW_[FeII]_4452.11        e_disp_HI_3703.85
# flux_[FeII]_5039.1       EW_[FeII]_4457.95        e_disp_HI_3711.97
# flux_[FeII]_5072.4       EW_[FeII]_4470.29        e_disp_[OII]_3726.03
# flux_[FeII]_5107.95      EW_HeI_4471.48           e_disp_[OII]_3728.82
# flux_[FeII]_5111.63      EW_[FeII]_4474.91        e_disp_HI_3734.37
# flux_[FeVI]_5145.8       EW_[NiII]_4485.21        e_disp_HI_3750.15
# flux_[FeII]_5158.0       EW_[MgI]_4562.48         e_disp_[FeVII]_3758.9
# flux_[FeVII]_5158.9      EW_MgI]_4571.1           e_disp_HI_3770.63
# flux_[FeVI]_5176.0       EW_[FeII]_4632.27        e_disp_HI_3797.9
# flux_[FeII]_5184.8       EW_[FeIII]_4658.1        e_disp_HeI_3819.61
# flux_[ArIII]_5191.82     EW_HeII_4685.68          e_disp_HI_3835.38
# flux_[NI]_5197.9         EW_[FeIII]_4701.62       e_disp_[NeIII]_3868.75
# flux_[NI]_5200.26        EW_[ArIV]_4711.33        e_disp_HeI_3888.65
# flux_[FeII]_5220.06      EW_HeI_4713.14           e_disp_HI_3889.05
# flux_[FeII]_5261.61      EW_[NeIV]_4724.17        e_disp_CaII_3933.66
# flux_[FeII]_5268.88      EW_[FeIII]_4733.93       e_disp_HeI_3964.73
# flux_[FeIII]_5270.3      EW_[ArIV]_4740.2         e_disp_[NeIII]_3967.46
# flux_[FeII]_5273.38      EW_[FeIII]_4754.83       e_disp_CaII_3968.47
# flux_[FeVI]_5277.8       EW_[FeIII]_4769.6        e_disp_Hepsilon_3970.07
# flux_[FeII]_5296.84      EW_[FeII]_4774.74        e_disp_HeI_4026.19
# flux_[FeXIV]_5302.86     EW_[FeIII]_4777.88       e_disp_[SII]_4068.6
# flux_[CaV]_5309.18       EW_[FeIII]_4813.9        e_disp_[SII]_4076.35
# flux_[FeII]_5333.65      EW_[FeII]_4814.55        e_disp_Hdelta_4101.77
# flux_[FeVI]_5335.2       EW_Hbeta_4861.36         e_disp_HeI_4120.81
# flux_[FeII]_5376.47      EW_[FeIII]_4881.11       e_disp_[FeII]_4177.21
# flux_HeII_5411.52        EW_[FeII]_4889.63        e_disp_[FeV]_4227.2
# flux_[FeII]_5412.64      EW_[FeVII]_4893.4        e_disp_[FeII]_4243.98
# flux_[FeVI]_5424.2       EW_[FeII]_4905.35        e_disp_CII_4267.0
# flux_[FeVI]_5426.6       EW_HeI_4921.93           e_disp_[FeII]_4287.4
# flux_[FeVI]_5484.8       EW_[FeIII]_4924.5        e_disp_Hgamma_4340.49
# flux_[ClIII]_5517.71     EW_[FeIII]_4930.5        e_disp_[FeII]_4358.1
# flux_[FeII]_5527.33      EW_[FeVII]_4942.5        e_disp_[FeII]_4358.37
# flux_[OI]_5577.34        EW_[OIII]_4958.91        e_disp_[FeII]_4359.34
# flux_[FeVI]_5631.1       EW_[FeVI]_4972.5         e_disp_[OIII]_4363.21
# flux_[FeVI]_5677.0       EW_[FeII]_4973.39        e_disp_[FeII]_4413.78
# flux_[FeVII]_5720.7      EW_[FeIII]_4985.9        e_disp_[FeII]_4414.45
# flux_[NII]_5754.59       EW_[OIII]_5006.84        e_disp_[FeII]_4416.27
# vel_HI_3686.83           EW_HeI_5015.68           e_disp_[FeII]_4452.11
# vel_HI_3691.56           EW_[FeII]_5039.1         e_disp_[FeII]_4457.95
# vel_HI_3697.15           EW_[FeII]_5072.4         e_disp_[FeII]_4470.29
# vel_HI_3703.85           EW_[FeII]_5107.95        e_disp_HeI_4471.48
# vel_HI_3711.97           EW_[FeII]_5111.63        e_disp_[FeII]_4474.91
# vel_[OII]_3726.03        EW_[FeVI]_5145.8         e_disp_[NiII]_4485.21
# vel_[OII]_3728.82        EW_[FeII]_5158.0         e_disp_[MgI]_4562.48
# vel_HI_3734.37           EW_[FeVII]_5158.9        e_disp_MgI]_4571.1
# vel_HI_3750.15           EW_[FeVI]_5176.0         e_disp_[FeII]_4632.27
# vel_[FeVII]_3758.9       EW_[FeII]_5184.8         e_disp_[FeIII]_4658.1
# vel_HI_3770.63           EW_[ArIII]_5191.82       e_disp_HeII_4685.68
# vel_HI_3797.9            EW_[NI]_5197.9           e_disp_[FeIII]_4701.62
# vel_HeI_3819.61          EW_[NI]_5200.26          e_disp_[ArIV]_4711.33
# vel_HI_3835.38           EW_[FeII]_5220.06        e_disp_HeI_4713.14
# vel_[NeIII]_3868.75      EW_[FeII]_5261.61        e_disp_[NeIV]_4724.17
# vel_HeI_3888.65          EW_[FeII]_5268.88        e_disp_[FeIII]_4733.93
# vel_HI_3889.05           EW_[FeIII]_5270.3        e_disp_[ArIV]_4740.2
# vel_CaII_3933.66         EW_[FeII]_5273.38        e_disp_[FeIII]_4754.83
# vel_HeI_3964.73          EW_[FeVI]_5277.8         e_disp_[FeIII]_4769.6
# vel_[NeIII]_3967.46      EW_[FeII]_5296.84        e_disp_[FeII]_4774.74
# vel_CaII_3968.47         EW_[FeXIV]_5302.86       e_disp_[FeIII]_4777.88
# vel_Hepsilon_3970.07     EW_[CaV]_5309.18         e_disp_[FeIII]_4813.9
# vel_HeI_4026.19          EW_[FeII]_5333.65        e_disp_[FeII]_4814.55
# vel_[SII]_4068.6         EW_[FeVI]_5335.2         e_disp_Hbeta_4861.36
# vel_[SII]_4076.35        EW_[FeII]_5376.47        e_disp_[FeIII]_4881.11
# vel_Hdelta_4101.77       EW_HeII_5411.52          e_disp_[FeII]_4889.63
# vel_HeI_4120.81          EW_[FeII]_5412.64        e_disp_[FeVII]_4893.4
# vel_[FeII]_4177.21       EW_[FeVI]_5424.2         e_disp_[FeII]_4905.35
# vel_[FeV]_4227.2         EW_[FeVI]_5426.6         e_disp_HeI_4921.93
# vel_[FeII]_4243.98       EW_[FeVI]_5484.8         e_disp_[FeIII]_4924.5
# vel_CII_4267.0           EW_[ClIII]_5517.71       e_disp_[FeIII]_4930.5
# vel_[FeII]_4287.4        EW_[FeII]_5527.33        e_disp_[FeVII]_4942.5
# vel_Hgamma_4340.49       EW_[OI]_5577.34          e_disp_[OIII]_4958.91
# vel_[FeII]_4358.1        EW_[FeVI]_5631.1         e_disp_[FeVI]_4972.5
# vel_[FeII]_4358.37       EW_[FeVI]_5677.0         e_disp_[FeII]_4973.39
# vel_[FeII]_4359.34       EW_[FeVII]_5720.7        e_disp_[FeIII]_4985.9
# vel_[OIII]_4363.21       EW_[NII]_5754.59         e_disp_[OIII]_5006.84
# vel_[FeII]_4413.78       e_flux_HI_3686.83        e_disp_HeI_5015.68
# vel_[FeII]_4414.45       e_flux_HI_3691.56        e_disp_[FeII]_5039.1
# vel_[FeII]_4416.27       e_flux_HI_3697.15        e_disp_[FeII]_5072.4
# vel_[FeII]_4452.11       e_flux_HI_3703.85        e_disp_[FeII]_5107.95
# vel_[FeII]_4457.95       e_flux_HI_3711.97        e_disp_[FeII]_5111.63
# vel_[FeII]_4470.29       e_flux_[OII]_3726.03     e_disp_[FeVI]_5145.8
# vel_HeI_4471.48          e_flux_[OII]_3728.82     e_disp_[FeII]_5158.0
# vel_[FeII]_4474.91       e_flux_HI_3734.37        e_disp_[FeVII]_5158.9
# vel_[NiII]_4485.21       e_flux_HI_3750.15        e_disp_[FeVI]_5176.0
# vel_[MgI]_4562.48        e_flux_[FeVII]_3758.9    e_disp_[FeII]_5184.8
# vel_MgI]_4571.1          e_flux_HI_3770.63        e_disp_[ArIII]_5191.82
# vel_[FeII]_4632.27       e_flux_HI_3797.9         e_disp_[NI]_5197.9
# vel_[FeIII]_4658.1       e_flux_HeI_3819.61       e_disp_[NI]_5200.26
# vel_HeII_4685.68         e_flux_HI_3835.38        e_disp_[FeII]_5220.06
# vel_[FeIII]_4701.62      e_flux_[NeIII]_3868.75   e_disp_[FeII]_5261.61
# vel_[ArIV]_4711.33       e_flux_HeI_3888.65       e_disp_[FeII]_5268.88
# vel_HeI_4713.14          e_flux_HI_3889.05        e_disp_[FeIII]_5270.3
# vel_[NeIV]_4724.17       e_flux_CaII_3933.66      e_disp_[FeII]_5273.38
# vel_[FeIII]_4733.93      e_flux_HeI_3964.73       e_disp_[FeVI]_5277.8
# vel_[ArIV]_4740.2        e_flux_[NeIII]_3967.46   e_disp_[FeII]_5296.84
# vel_[FeIII]_4754.83      e_flux_CaII_3968.47      e_disp_[FeXIV]_5302.86
# vel_[FeIII]_4769.6       e_flux_Hepsilon_3970.07  e_disp_[CaV]_5309.18
# vel_[FeII]_4774.74       e_flux_HeI_4026.19       e_disp_[FeII]_5333.65
# vel_[FeIII]_4777.88      e_flux_[SII]_4068.6      e_disp_[FeVI]_5335.2
# vel_[FeIII]_4813.9       e_flux_[SII]_4076.35     e_disp_[FeII]_5376.47
# vel_[FeII]_4814.55       e_flux_Hdelta_4101.77    e_disp_HeII_5411.52
# vel_Hbeta_4861.36        e_flux_HeI_4120.81       e_disp_[FeII]_5412.64
# vel_[FeIII]_4881.11      e_flux_[FeII]_4177.21    e_disp_[FeVI]_5424.2
# vel_[FeII]_4889.63       e_flux_[FeV]_4227.2      e_disp_[FeVI]_5426.6
# vel_[FeVII]_4893.4       e_flux_[FeII]_4243.98    e_disp_[FeVI]_5484.8
# vel_[FeII]_4905.35       e_flux_CII_4267.0        e_disp_[ClIII]_5517.71
# vel_HeI_4921.93          e_flux_[FeII]_4287.4     e_disp_[FeII]_5527.33
# vel_[FeIII]_4924.5       e_flux_Hgamma_4340.49    e_disp_[OI]_5577.34
# vel_[FeIII]_4930.5       e_flux_[FeII]_4358.1     e_disp_[FeVI]_5631.1
# vel_[FeVII]_4942.5       e_flux_[FeII]_4358.37    e_disp_[FeVI]_5677.0
# vel_[OIII]_4958.91       e_flux_[FeII]_4359.34    e_disp_[FeVII]_5720.7
# vel_[FeVI]_4972.5        e_flux_[OIII]_4363.21    e_disp_[NII]_5754.59
# vel_[FeII]_4973.39       e_flux_[FeII]_4413.78    e_EW_HI_3686.83
# vel_[FeIII]_4985.9       e_flux_[FeII]_4414.45    e_EW_HI_3691.56
# vel_[OIII]_5006.84       e_flux_[FeII]_4416.27    e_EW_HI_3697.15
# vel_HeI_5015.68          e_flux_[FeII]_4452.11    e_EW_HI_3703.85
# vel_[FeII]_5039.1        e_flux_[FeII]_4457.95    e_EW_HI_3711.97
# vel_[FeII]_5072.4        e_flux_[FeII]_4470.29    e_EW_[OII]_3726.03
# vel_[FeII]_5107.95       e_flux_HeI_4471.48       e_EW_[OII]_3728.82
# vel_[FeII]_5111.63       e_flux_[FeII]_4474.91    e_EW_HI_3734.37
# vel_[FeVI]_5145.8        e_flux_[NiII]_4485.21    e_EW_HI_3750.15
# vel_[FeII]_5158.0        e_flux_[MgI]_4562.48     e_EW_[FeVII]_3758.9
# vel_[FeVII]_5158.9       e_flux_MgI]_4571.1       e_EW_HI_3770.63
# vel_[FeVI]_5176.0        e_flux_[FeII]_4632.27    e_EW_HI_3797.9
# vel_[FeII]_5184.8        e_flux_[FeIII]_4658.1    e_EW_HeI_3819.61
# vel_[ArIII]_5191.82      e_flux_HeII_4685.68      e_EW_HI_3835.38
# vel_[NI]_5197.9          e_flux_[FeIII]_4701.62   e_EW_[NeIII]_3868.75
# vel_[NI]_5200.26         e_flux_[ArIV]_4711.33    e_EW_HeI_3888.65
# vel_[FeII]_5220.06       e_flux_HeI_4713.14       e_EW_HI_3889.05
# vel_[FeII]_5261.61       e_flux_[NeIV]_4724.17    e_EW_CaII_3933.66
# vel_[FeII]_5268.88       e_flux_[FeIII]_4733.93   e_EW_HeI_3964.73
# vel_[FeIII]_5270.3       e_flux_[ArIV]_4740.2     e_EW_[NeIII]_3967.46
# vel_[FeII]_5273.38       e_flux_[FeIII]_4754.83   e_EW_CaII_3968.47
# vel_[FeVI]_5277.8        e_flux_[FeIII]_4769.6    e_EW_Hepsilon_3970.07
# vel_[FeII]_5296.84       e_flux_[FeII]_4774.74    e_EW_HeI_4026.19
# vel_[FeXIV]_5302.86      e_flux_[FeIII]_4777.88   e_EW_[SII]_4068.6
# vel_[CaV]_5309.18        e_flux_[FeIII]_4813.9    e_EW_[SII]_4076.35
# vel_[FeII]_5333.65       e_flux_[FeII]_4814.55    e_EW_Hdelta_4101.77
# vel_[FeVI]_5335.2        e_flux_Hbeta_4861.36     e_EW_HeI_4120.81
# vel_[FeII]_5376.47       e_flux_[FeIII]_4881.11   e_EW_[FeII]_4177.21
# vel_HeII_5411.52         e_flux_[FeII]_4889.63    e_EW_[FeV]_4227.2
# vel_[FeII]_5412.64       e_flux_[FeVII]_4893.4    e_EW_[FeII]_4243.98
# vel_[FeVI]_5424.2        e_flux_[FeII]_4905.35    e_EW_CII_4267.0
# vel_[FeVI]_5426.6        e_flux_HeI_4921.93       e_EW_[FeII]_4287.4
# vel_[FeVI]_5484.8        e_flux_[FeIII]_4924.5    e_EW_Hgamma_4340.49
# vel_[ClIII]_5517.71      e_flux_[FeIII]_4930.5    e_EW_[FeII]_4358.1
# vel_[FeII]_5527.33       e_flux_[FeVII]_4942.5    e_EW_[FeII]_4358.37
# vel_[OI]_5577.34         e_flux_[OIII]_4958.91    e_EW_[FeII]_4359.34
# vel_[FeVI]_5631.1        e_flux_[FeVI]_4972.5     e_EW_[OIII]_4363.21
# vel_[FeVI]_5677.0        e_flux_[FeII]_4973.39    e_EW_[FeII]_4413.78
# vel_[FeVII]_5720.7       e_flux_[FeIII]_4985.9    e_EW_[FeII]_4414.45
# vel_[NII]_5754.59        e_flux_[OIII]_5006.84    e_EW_[FeII]_4416.27
# disp_HI_3686.83          e_flux_HeI_5015.68       e_EW_[FeII]_4452.11
# disp_HeI_4921.93         e_vel_[FeII]_4287.4      e_EW_[FeII]_5527.33
# disp_[FeIII]_4924.5      e_vel_Hgamma_4340.49     e_EW_[OI]_5577.34
# disp_[FeIII]_4930.5      e_vel_[FeII]_4358.1      e_EW_[FeVI]_5631.1
# disp_[FeVII]_4942.5      e_vel_[FeII]_4358.37     e_EW_[FeVI]_5677.0
# disp_[OIII]_4958.91      e_vel_[FeII]_4359.34     e_EW_[FeVII]_5720.7
# disp_[FeVI]_4972.5       e_vel_[OIII]_4363.21     e_EW_[NII]_5754.59
# disp_[FeII]_4973.39      e_vel_[FeII]_4413.78
# disp_[FeIII]_4985.9      e_vel_[FeII]_4414.45
# ----------------------------------
# |        NPE_R                    |
# ----------------------------------
# id                     disp_CII_7236.0        e_vel_[NII]_6583.45
# flux_HeI_5876.0        disp_HeI_7281.35       e_vel_HeI_6678.15
# flux_NaI_5889.95       disp_[FeI]_7290.42     e_vel_[SII]_6716.44
# flux_NaI_5895.92       disp_[CaII]_7291.46    e_vel_[SII]_6730.82
# flux_[FeVII]_6087.0    disp_[OII]_7318.92     e_vel_FeI_6855.18
# flux_[OI]_6300.3       disp_[CaII]_7323.88    e_vel_[ArV]_7005.67
# flux_[SIII]_6312.06    disp_[OII]_7329.66     e_vel_HeI_7065.19
# flux_[OI]_6363.78      disp_[NiII]_7377.83    e_vel_[ArIII]_7135.8
# flux_[FeX]_6374.51     disp_[FeII]_7388.16    e_vel_[FeII]_7155.14
# flux_[ArV]_6435.1      disp_[NiII]_7411.61    e_vel_[FeII]_7171.98
# flux_[NII]_6548.05     disp_[FeII]_7452.5     e_vel_CII_7236.0
# flux_Halpha_6562.85    EW_HeI_5876.0          e_vel_HeI_7281.35
# flux_[NII]_6583.45     EW_NaI_5889.95         e_vel_[FeI]_7290.42
# flux_HeI_6678.15       EW_NaI_5895.92         e_vel_[CaII]_7291.46
# flux_[SII]_6716.44     EW_[FeVII]_6087.0      e_vel_[OII]_7318.92
# flux_[SII]_6730.82     EW_[OI]_6300.3         e_vel_[CaII]_7323.88
# flux_FeI_6855.18       EW_[SIII]_6312.06      e_vel_[OII]_7329.66
# flux_[ArV]_7005.67     EW_[OI]_6363.78        e_vel_[NiII]_7377.83
# flux_HeI_7065.19       EW_[FeX]_6374.51       e_vel_[FeII]_7388.16
# flux_[ArIII]_7135.8    EW_[ArV]_6435.1        e_vel_[NiII]_7411.61
# flux_[FeII]_7155.14    EW_[NII]_6548.05       e_vel_[FeII]_7452.5
# flux_[FeII]_7171.98    EW_Halpha_6562.85      e_disp_HeI_5876.0
# flux_CII_7236.0        EW_[NII]_6583.45       e_disp_NaI_5889.95
# flux_HeI_7281.35       EW_HeI_6678.15         e_disp_NaI_5895.92
# flux_[FeI]_7290.42     EW_[SII]_6716.44       e_disp_[FeVII]_6087.0
# flux_[CaII]_7291.46    EW_[SII]_6730.82       e_disp_[OI]_6300.3
# flux_[OII]_7318.92     EW_FeI_6855.18         e_disp_[SIII]_6312.06
# sigma_kms_HeII_4685.68      sigma_kms_pek_4958.91       X_sq_[FeII]_5184.8          fr_HI_8314.89
# sigma_kms_[FeIII]_4701.62   sigma_kms_pek_5006.84       fr_[FeII]_5184.8            X_sq_HI_8324.06
# sigma_kms_[ArIV]_4711.33    sigma_kms_pek_6300.3        X_sq_[ArIII]_5191.82        fr_HI_8324.06
# sigma_kms_HeI_4713.14       sigma_kms_pek_6548.05       fr_[ArIII]_5191.82          X_sq_HI_8334.42
# sigma_kms_[NeIV]_4724.17    sigma_kms_pek_6562.85       X_sq_[NI]_5197.9            fr_HI_8334.42
# sigma_kms_[FeIII]_4733.93   sigma_kms_pek_6583.45       fr_[NI]_5197.9              X_sq_HI_8345.55
# sigma_kms_[ArIV]_4740.2     sigma_kms_pek_6716.44       X_sq_[NI]_5200.26           fr_HI_8345.55
# sigma_kms_[FeIII]_4754.83   sigma_kms_pek_6730.82       fr_[NI]_5200.26             X_sq_[CrII]_8357.51
# sigma_kms_[FeIII]_4769.6    sigma_kms_pek_9069.0        X_sq_[FeII]_5220.06         fr_[CrII]_8357.51
# sigma_kms_[FeII]_4774.74    sigma_kms_pek_9531.1        fr_[FeII]_5220.06           X_sq_HI_8359.0
# sigma_kms_[FeIII]_4777.88   X_sq_st                     X_sq_[FeII]_5261.61         fr_HI_8359.0
# sigma_kms_[FeIII]_4813.9    X_sq_st_np                  fr_[FeII]_5261.61           X_sq_HI_8374.48
# sigma_kms_[FeII]_4814.55    X_sq_st_pek                 X_sq_[FeII]_5268.88         fr_HI_8374.48
# sigma_kms_Hbeta_4861.36     X_sq_HI_3686.83             fr_[FeII]_5268.88           X_sq_HI_8392.4
# sigma_kms_[FeIII]_4881.11   fr_HI_3686.83               X_sq_[FeIII]_5270.3         fr_HI_8392.4
# sigma_kms_[FeII]_4889.63    X_sq_HI_3691.56             fr_[FeIII]_5270.3           X_sq_OI_8446.0
# sigma_kms_[FeVII]_4893.4    fr_HI_3691.56               X_sq_[FeII]_5273.38         fr_OI_8446.0
# sigma_kms_[FeII]_4905.35    X_sq_HI_3697.15             fr_[FeII]_5273.38           X_sq_HI_8467.25
# sigma_kms_HeI_4921.93       fr_HI_3697.15               X_sq_[FeVI]_5277.8          fr_HI_8467.25
# sigma_kms_[FeIII]_4924.5    X_sq_HI_3703.85             fr_[FeVI]_5277.8            X_sq_CaII_8498.02
# sigma_kms_[FeIII]_4930.5    fr_HI_3703.85               X_sq_[FeII]_5296.84         fr_CaII_8498.02
# sigma_kms_[FeVII]_4942.5    X_sq_HI_3711.97             fr_[FeII]_5296.84           X_sq_HI_8502.48
# sigma_kms_[OIII]_4958.91    fr_HI_3711.97               X_sq_[FeXIV]_5302.86        fr_HI_8502.48
# sigma_kms_[FeVI]_4972.5     X_sq_[OII]_3726.03          fr_[FeXIV]_5302.86          X_sq_CaII_8542.09
# sigma_kms_[FeII]_4973.39    fr_[OII]_3726.03            X_sq_[CaV]_5309.18          fr_CaII_8542.09
# sigma_kms_[FeIII]_4985.9    X_sq_[OII]_3728.82          fr_[CaV]_5309.18            X_sq_HI_8545.38
# sigma_kms_[OIII]_5006.84    fr_[OII]_3728.82            X_sq_[FeII]_5333.65         fr_HI_8545.38
# sigma_kms_HeI_5015.68       X_sq_HI_3734.37             fr_[FeII]_5333.65           X_sq_[ClII]_8578.7
# sigma_kms_[FeII]_5039.1     fr_HI_3734.37               X_sq_[FeVI]_5335.2          fr_[ClII]_8578.7
# sigma_kms_[FeII]_5072.4     X_sq_HI_3750.15             fr_[FeVI]_5335.2            X_sq_HI_8598.39
# sigma_kms_[FeII]_5107.95    fr_HI_3750.15               X_sq_[FeII]_5376.47         fr_HI_8598.39
# sigma_kms_[FeII]_5111.63    X_sq_[FeVII]_3758.9         fr_[FeII]_5376.47           X_sq_[FeII]_8616.96
# sigma_kms_[FeVI]_5145.8     fr_[FeVII]_3758.9           X_sq_HeII_5411.52           fr_[FeII]_8616.96
# sigma_kms_[FeII]_5158.0     X_sq_HI_3770.63             fr_HeII_5411.52             X_sq_CaII_8662.14
# sigma_kms_[FeVII]_5158.9    fr_HI_3770.63               X_sq_[FeII]_5412.64         fr_CaII_8662.14
# sigma_kms_[FeVI]_5176.0     X_sq_HI_3797.9              fr_[FeII]_5412.64           X_sq_HI_8665.02
# sigma_kms_[FeII]_5184.8     fr_HI_3797.9                X_sq_[FeVI]_5424.2          fr_HI_8665.02
# sigma_kms_[ArIII]_5191.82   X_sq_HeI_3819.61            fr_[FeVI]_5424.2            X_sq_[CI]_8727.13
# sigma_kms_[NI]_5197.9       fr_HeI_3819.61              X_sq_[FeVI]_5426.6          fr_[CI]_8727.13
# sigma_kms_[NI]_5200.26      X_sq_HI_3835.38             fr_[FeVI]_5426.6            X_sq_HI_8750.47
# sigma_kms_[FeII]_5220.06    fr_HI_3835.38               X_sq_[FeVI]_5484.8          fr_HI_8750.47
# sigma_kms_[FeII]_5261.61    X_sq_[NeIII]_3868.75        fr_[FeVI]_5484.8            X_sq_HI_8862.78
# sigma_kms_[FeII]_5268.88    fr_[NeIII]_3868.75          X_sq_[ClIII]_5517.71        fr_HI_8862.78
# sigma_kms_[FeIII]_5270.3    X_sq_HeI_3888.65            fr_[ClIII]_5517.71          X_sq_[FeII]_8891.88
# sigma_kms_[FeII]_5273.38    fr_HeI_3888.65              X_sq_[FeII]_5527.33         fr_[FeII]_8891.88
# sigma_kms_[FeVI]_5277.8     X_sq_HI_3889.05             fr_[FeII]_5527.33           X_sq_HI_9014.91
# sigma_kms_[FeII]_5296.84    fr_HI_3889.05               X_sq_[OI]_5577.34           fr_HI_9014.91
# sigma_kms_[FeXIV]_5302.86   X_sq_CaII_3933.66           fr_[OI]_5577.34             X_sq_[FeII]_9033.45
# sigma_kms_[CaV]_5309.18     fr_CaII_3933.66             X_sq_[FeVI]_5631.1          fr_[FeII]_9033.45
# sigma_kms_[FeII]_5333.65    X_sq_HeI_3964.73            fr_[FeVI]_5631.1            X_sq_[FeII]_9051.92
# sigma_kms_[FeVI]_5335.2     fr_HeI_3964.73              X_sq_[FeVI]_5677.0          fr_[FeII]_9051.92
# sigma_kms_HeI_6678.15       fr_[FeII]_4287.4            X_sq_Halpha_6562.85         fr_pe_3728.82
# sigma_kms_[SII]_6716.44     X_sq_Hgamma_4340.49         fr_Halpha_6562.85           X_sq_pe_4101.77
# sigma_kms_[SII]_6730.82     fr_Hgamma_4340.49           X_sq_[NII]_6583.45          fr_pe_4101.77
# sigma_kms_FeI_6855.18       X_sq_[FeII]_4358.1          fr_[NII]_6583.45            X_sq_pe_4340.49
# sigma_kms_[ArV]_7005.67     fr_[FeII]_4358.1            X_sq_HeI_6678.15            fr_pe_4340.49
# sigma_kms_HeI_7065.19       X_sq_[FeII]_4358.37         fr_HeI_6678.15              X_sq_pe_4861.36
# sigma_kms_[ArIII]_7135.8    fr_[FeII]_4358.37           X_sq_[SII]_6716.44          fr_pe_4861.36
# sigma_kms_[FeII]_7155.14    X_sq_[FeII]_4359.34         fr_[SII]_6716.44            X_sq_pe_4958.91
# sigma_kms_[FeII]_7171.98    fr_[FeII]_4359.34           X_sq_[SII]_6730.82          fr_pe_4958.91
# sigma_kms_CII_7236.0        X_sq_[OIII]_4363.21         fr_[SII]_6730.82            X_sq_pe_5006.84
# sigma_kms_HeI_7281.35       fr_[OIII]_4363.21           X_sq_FeI_6855.18            fr_pe_5006.84
# sigma_kms_[FeI]_7290.42     X_sq_[FeII]_4413.78         fr_FeI_6855.18              X_sq_pe_6300.3
# sigma_kms_[CaII]_7291.46    fr_[FeII]_4413.78           X_sq_[ArV]_7005.67          fr_pe_6300.3
# sigma_kms_[OII]_7318.92     X_sq_[FeII]_4414.45         fr_[ArV]_7005.67            X_sq_pe_6548.05
# sigma_kms_[CaII]_7323.88    fr_[FeII]_4414.45           X_sq_HeI_7065.19            fr_pe_6548.05
# sigma_kms_[OII]_7329.66     X_sq_[FeII]_4416.27         fr_HeI_7065.19              X_sq_pe_6562.85
# sigma_kms_[NiII]_7377.83    fr_[FeII]_4416.27           X_sq_[ArIII]_7135.8         fr_pe_6562.85
# sigma_kms_[FeII]_7388.16    X_sq_[FeII]_4452.11         fr_[ArIII]_7135.8           X_sq_pe_6583.45
# sigma_kms_[NiII]_7411.61    fr_[FeII]_4452.11           X_sq_[FeII]_7155.14         fr_pe_6583.45
# sigma_kms_[FeII]_7452.5     X_sq_[FeII]_4457.95         fr_[FeII]_7155.14           X_sq_pe_6716.44
# sigma_kms_[FeII]_7637.52    fr_[FeII]_4457.95           X_sq_[FeII]_7171.98         fr_pe_6716.44
# sigma_kms_[FeII]_7686.19    X_sq_[FeII]_4470.29         fr_[FeII]_7171.98           X_sq_pe_6730.82
# sigma_kms_[FeII]_7686.9     fr_[FeII]_4470.29           X_sq_CII_7236.0             fr_pe_6730.82
# sigma_kms_[ArIII]_7751.06   X_sq_HeI_4471.48            fr_CII_7236.0               X_sq_pe_9069.0
# sigma_kms_OI_7774.0         fr_HeI_4471.48              X_sq_HeI_7281.35            fr_pe_9069.0
# sigma_kms_[FeXI]_7891.8     X_sq_[FeII]_4474.91         fr_HeI_7281.35              X_sq_pe_9531.1
# sigma_kms_[CrII]_7999.85    fr_[FeII]_4474.91           X_sq_[FeI]_7290.42          fr_pe_9531.1
# sigma_kms_[CrII]_8125.22    X_sq_[NiII]_4485.21         fr_[FeI]_7290.42            X_sq_pek_3726.03
# sigma_kms_[CrII]_8229.55    fr_[NiII]_4485.21           X_sq_[CaII]_7291.46         fr_pek_3726.03
# sigma_kms_HeII_8236.77      X_sq_[MgI]_4562.48          fr_[CaII]_7291.46           X_sq_pek_3728.82
# sigma_kms_HI_8239.24        fr_[MgI]_4562.48            X_sq_[OII]_7318.92          fr_pek_3728.82
# sigma_kms_HI_8240.82        X_sq_MgI]_4571.1            fr_[OII]_7318.92            X_sq_pek_4101.77
# sigma_kms_HI_8242.51        fr_MgI]_4571.1              X_sq_[CaII]_7323.88         fr_pek_4101.77
# sigma_kms_HI_8244.32        X_sq_[FeII]_4632.27         fr_[CaII]_7323.88           X_sq_pek_4340.49
# sigma_kms_HI_8246.27        fr_[FeII]_4632.27           X_sq_[OII]_7329.66          fr_pek_4340.49
# sigma_kms_HI_8248.35        X_sq_[FeIII]_4658.1         fr_[OII]_7329.66            X_sq_pek_4861.36
# sigma_kms_HI_8250.6         fr_[FeIII]_4658.1           X_sq_[NiII]_7377.83         fr_pek_4861.36
# sigma_kms_HI_8253.03        X_sq_HeII_4685.68           fr_[NiII]_7377.83           X_sq_pek_4958.91
# sigma_kms_HI_8255.65        fr_HeII_4685.68             X_sq_[FeII]_7388.16         fr_pek_4958.91
# sigma_kms_HI_8258.49        X_sq_[FeIII]_4701.62        fr_[FeII]_7388.16           X_sq_pek_5006.84
# sigma_kms_HI_8261.57        fr_[FeIII]_4701.62          X_sq_[NiII]_7411.61         fr_pek_5006.84
# sigma_kms_HI_8264.92        X_sq_[ArIV]_4711.33         fr_[NiII]_7411.61           X_sq_pek_6300.3
# sigma_kms_HI_8268.57        fr_[ArIV]_4711.33           X_sq_[FeII]_7452.5          fr_pek_6300.3
# sigma_kms_HI_8272.56        X_sq_HeI_4713.14            fr_[FeII]_7452.5            X_sq_pek_6548.05
# sigma_kms_HI_8276.94        fr_HeI_4713.14              X_sq_[FeII]_7637.52         fr_pek_6548.05
# sigma_kms_HI_8281.75        X_sq_[NeIV]_4724.17         fr_[FeII]_7637.52           X_sq_pek_6562.85
# sigma_kms_HI_8287.06        fr_[NeIV]_4724.17           X_sq_[FeII]_7686.19         fr_pek_6562.85
# sigma_kms_HI_8292.94        X_sq_[FeIII]_4733.93        fr_[FeII]_7686.19           X_sq_pek_6583.45
# sigma_kms_HI_8299.47        fr_[FeIII]_4733.93          X_sq_[FeII]_7686.9          fr_pek_6583.45
# sigma_kms_[NiII]_8300.99    X_sq_[ArIV]_4740.2          fr_[FeII]_7686.9            X_sq_pek_6716.44
# sigma_kms_HI_8306.75        fr_[ArIV]_4740.2            X_sq_[ArIII]_7751.06        fr_pek_6716.44
# sigma_kms_[CrII]_8308.39    X_sq_[FeIII]_4754.83        fr_[ArIII]_7751.06          X_sq_pek_6730.82
# sigma_kms_HI_8314.89        fr_[FeIII]_4754.83          X_sq_OI_7774.0              fr_pek_6730.82
# sigma_kms_HI_8324.06        X_sq_[FeIII]_4769.6         fr_OI_7774.0                X_sq_pek_9069.0
# sigma_kms_HI_8334.42        fr_[FeIII]_4769.6           X_sq_[FeXI]_7891.8          fr_pek_9069.0
# sigma_kms_HI_8345.55        X_sq_[FeII]_4774.74         fr_[FeXI]_7891.8            X_sq_pek_9531.1
# sigma_kms_[CrII]_8357.51    fr_[FeII]_4774.74           X_sq_[CrII]_7999.85         fr_pek_9531.1
# sigma_kms_HI_8359.0         X_sq_[FeIII]_4777.88        fr_[CrII]_7999.85

# %%
################################################################
# (1.2) Get the data from a local directory
################################################################
dap_file=f'LV_dap-{rsp}-{sn}-{expnum}.dap.fits.gz'
dap_file=f'LV_{DIR_DAP}/{dap_file}'
tab_DAP=read_DAP_file(dap_file,verbose=True)
# Out:
# ---- ALL Table Columns -----
# -------------------------------
# |        PT                   |
# -------------------------------
# id               dec              fiberid          star_id
# ra               mask             exposure         star_sep_arcsec
# ----------------------------------
# |        RSP                      |
# ----------------------------------
# id             alpha          flux_st        Fe_MW
# MIN_CHISQ      e_alpha        redshift_st    e_Fe_MW
# Teff           Av_st          med_flux_st    alpha_MW
# e_Teff         e_Av_st        e_med_flux_st  e_alpha_MW
# Log_g          z_st           Teff_MW        vel_st
# e_Log_g        e_z_st         e_Teff_MW      log_ML
# Fe             disp_st        Log_g_MW       log_Mass
# e_Fe           e_disp_st      e_Log_g_MW
# ----------------------------------
# |        PE_ord                   |
# ----------------------------------
# id                 vel_pe_4340.49     e_disp_pe_6300.3   disp_pe_6716.44
# flux_pe_3726.03    e_vel_pe_4340.49   vel_pe_6300.3      e_disp_pe_6716.44
# e_flux_pe_3726.03  flux_pe_4861.36    e_vel_pe_6300.3    vel_pe_6716.44
# disp_pe_3726.03    e_flux_pe_4861.36  flux_pe_6548.05    e_vel_pe_6716.44
# e_disp_pe_3726.03  disp_pe_4861.36    e_flux_pe_6548.05  flux_pe_6730.82
# vel_pe_3726.03     e_disp_pe_4861.36  disp_pe_6548.05    e_flux_pe_6730.82
# e_vel_pe_3726.03   vel_pe_4861.36     e_disp_pe_6548.05  disp_pe_6730.82
# flux_pe_3728.82    e_vel_pe_4861.36   vel_pe_6548.05     e_disp_pe_6730.82
# e_flux_pe_3728.82  flux_pe_4958.91    e_vel_pe_6548.05   vel_pe_6730.82
# disp_pe_3728.82    e_flux_pe_4958.91  flux_pe_6562.85    e_vel_pe_6730.82
# e_disp_pe_3728.82  disp_pe_4958.91    e_flux_pe_6562.85  flux_pe_9069.0
# vel_pe_3728.82     e_disp_pe_4958.91  disp_pe_6562.85    e_flux_pe_9069.0
# e_vel_pe_3728.82   vel_pe_4958.91     e_disp_pe_6562.85  disp_pe_9069.0
# flux_pe_4101.77    e_vel_pe_4958.91   vel_pe_6562.85     e_disp_pe_9069.0
# e_flux_pe_4101.77  flux_pe_5006.84    e_vel_pe_6562.85   vel_pe_9069.0
# id                       disp_[OIII]_5006.84      e_vel_[FeII]_4416.27
# flux_HI_3686.83          disp_HeI_5015.68         e_vel_[FeII]_4452.11
# flux_HI_3691.56          disp_[FeII]_5039.1       e_vel_[FeII]_4457.95
# flux_HI_3697.15          disp_[FeII]_5072.4       e_vel_[FeII]_4470.29
# flux_HI_3703.85          disp_[FeII]_5107.95      e_vel_HeI_4471.48
# flux_HI_3711.97          disp_[FeII]_5111.63      e_vel_[FeII]_4474.91
# flux_[OII]_3726.03       disp_[FeVI]_5145.8       e_vel_[NiII]_4485.21
# flux_[OII]_3728.82       disp_[FeII]_5158.0       e_vel_[MgI]_4562.48
# flux_HI_3734.37          disp_[FeVII]_5158.9      e_vel_MgI]_4571.1
# flux_HI_3750.15          disp_[FeVI]_5176.0       e_vel_[FeII]_4632.27
# flux_[FeVII]_3758.9      disp_[FeII]_5184.8       e_vel_[FeIII]_4658.1
# flux_HI_3770.63          disp_[ArIII]_5191.82     e_vel_HeII_4685.68
# flux_HI_3797.9           disp_[NI]_5197.9         e_vel_[FeIII]_4701.62
# flux_HeI_3819.61         disp_[NI]_5200.26        e_vel_[ArIV]_4711.33
# flux_HI_3835.38          disp_[FeII]_5220.06      e_vel_HeI_4713.14
# flux_[NeIII]_3868.75     disp_[FeII]_5261.61      e_vel_[NeIV]_4724.17
# flux_HeI_3888.65         disp_[FeII]_5268.88      e_vel_[FeIII]_4733.93
# flux_HI_3889.05          disp_[FeIII]_5270.3      e_vel_[ArIV]_4740.2
# flux_CaII_3933.66        disp_[FeII]_5273.38      e_vel_[FeIII]_4754.83
# flux_HeI_3964.73         disp_[FeVI]_5277.8       e_vel_[FeIII]_4769.6
# flux_[NeIII]_3967.46     disp_[FeII]_5296.84      e_vel_[FeII]_4774.74
# flux_CaII_3968.47        disp_[FeXIV]_5302.86     e_vel_[FeIII]_4777.88
# flux_Hepsilon_3970.07    disp_[CaV]_5309.18       e_vel_[FeIII]_4813.9
# flux_HeI_4026.19         disp_[FeII]_5333.65      e_vel_[FeII]_4814.55
# flux_[SII]_4068.6        disp_[FeVI]_5335.2       e_vel_Hbeta_4861.36
# flux_[SII]_4076.35       disp_[FeII]_5376.47      e_vel_[FeIII]_4881.11
# flux_Hdelta_4101.77      disp_HeII_5411.52        e_vel_[FeII]_4889.63
# flux_HeI_4120.81         disp_[FeII]_5412.64      e_vel_[FeVII]_4893.4
# flux_[FeII]_4177.21      disp_[FeVI]_5424.2       e_vel_[FeII]_4905.35
# flux_[FeV]_4227.2        disp_[FeVI]_5426.6       e_vel_HeI_4921.93
# flux_[FeII]_4243.98      disp_[FeVI]_5484.8       e_vel_[FeIII]_4924.5
# flux_CII_4267.0          disp_[ClIII]_5517.71     e_vel_[FeIII]_4930.5
# flux_[FeII]_4287.4       disp_[FeII]_5527.33      e_vel_[FeVII]_4942.5
# flux_Hgamma_4340.49      disp_[OI]_5577.34        e_vel_[OIII]_4958.91
# flux_[FeII]_4358.1       disp_[FeVI]_5631.1       e_vel_[FeVI]_4972.5
# flux_[FeII]_4358.37      disp_[FeVI]_5677.0       e_vel_[FeII]_4973.39
# flux_[FeII]_4359.34      disp_[FeVII]_5720.7      e_vel_[FeIII]_4985.9
# flux_[OIII]_4363.21      disp_[NII]_5754.59       e_vel_[OIII]_5006.84
# flux_[FeII]_4413.78      EW_HI_3686.83            e_vel_HeI_5015.68
# flux_[FeII]_4414.45      EW_HI_3691.56            e_vel_[FeII]_5039.1
# flux_[FeII]_4416.27      EW_HI_3697.15            e_vel_[FeII]_5072.4
# flux_[FeII]_4452.11      EW_HI_3703.85            e_vel_[FeII]_5107.95
# flux_[FeII]_4457.95      EW_HI_3711.97            e_vel_[FeII]_5111.63
# flux_[FeII]_4470.29      EW_[OII]_3726.03         e_vel_[FeVI]_5145.8
# flux_HeI_4471.48         EW_[OII]_3728.82         e_vel_[FeII]_5158.0
# flux_[FeII]_4474.91      EW_HI_3734.37            e_vel_[FeVII]_5158.9
# flux_[NiII]_4485.21      EW_HI_3750.15            e_vel_[FeVI]_5176.0
# flux_[MgI]_4562.48       EW_[FeVII]_3758.9        e_vel_[FeII]_5184.8
# flux_MgI]_4571.1         EW_HI_3770.63            e_vel_[ArIII]_5191.82
# flux_[FeII]_4632.27      EW_HI_3797.9             e_vel_[NI]_5197.9
# flux_[FeIII]_4658.1      EW_HeI_3819.61           e_vel_[NI]_5200.26
# flux_HeII_4685.68        EW_HI_3835.38            e_vel_[FeII]_5220.06
# flux_[FeIII]_4701.62     EW_[NeIII]_3868.75       e_vel_[FeII]_5261.61
# flux_[ArIV]_4711.33      EW_HeI_3888.65           e_vel_[FeII]_5268.88
# flux_HeI_4713.14         EW_HI_3889.05            e_vel_[FeIII]_5270.3
# flux_[NeIV]_4724.17      EW_CaII_3933.66          e_vel_[FeII]_5273.38
# flux_[FeIII]_4733.93     EW_HeI_3964.73           e_vel_[FeVI]_5277.8
# flux_[ArIV]_4740.2       EW_[NeIII]_3967.46       e_vel_[FeII]_5296.84
# flux_[FeIII]_4754.83     EW_CaII_3968.47          e_vel_[FeXIV]_5302.86
# flux_[FeIII]_4769.6      EW_Hepsilon_3970.07      e_vel_[CaV]_5309.18
# flux_[FeII]_4774.74      EW_HeI_4026.19           e_vel_[FeII]_5333.65
# flux_[FeIII]_4777.88     EW_[SII]_4068.6          e_vel_[FeVI]_5335.2
# flux_[FeIII]_4813.9      EW_[SII]_4076.35         e_vel_[FeII]_5376.47
# flux_[FeII]_4814.55      EW_Hdelta_4101.77        e_vel_HeII_5411.52
# flux_Hbeta_4861.36       EW_HeI_4120.81           e_vel_[FeII]_5412.64
# flux_[FeIII]_4881.11     EW_[FeII]_4177.21        e_vel_[FeVI]_5424.2
# flux_[FeII]_4889.63      EW_[FeV]_4227.2          e_vel_[FeVI]_5426.6
# flux_[FeVII]_4893.4      EW_[FeII]_4243.98        e_vel_[FeVI]_5484.8
# flux_[FeII]_4905.35      EW_CII_4267.0            e_vel_[ClIII]_5517.71
# flux_HeI_4921.93         EW_[FeII]_4287.4         e_vel_[FeII]_5527.33
# flux_[FeIII]_4924.5      EW_Hgamma_4340.49        e_vel_[OI]_5577.34
# flux_[FeIII]_4930.5      EW_[FeII]_4358.1         e_vel_[FeVI]_5631.1
# flux_[FeVII]_4942.5      EW_[FeII]_4358.37        e_vel_[FeVI]_5677.0
# flux_[OIII]_4958.91      EW_[FeII]_4359.34        e_vel_[FeVII]_5720.7
# flux_[FeVI]_4972.5       EW_[OIII]_4363.21        e_vel_[NII]_5754.59
# flux_[FeII]_4973.39      EW_[FeII]_4413.78        e_disp_HI_3686.83
# flux_[FeIII]_4985.9      EW_[FeII]_4414.45        e_disp_HI_3691.56
# flux_[OIII]_5006.84      EW_[FeII]_4416.27        e_disp_HI_3697.15
# flux_HeI_5015.68         EW_[FeII]_4452.11        e_disp_HI_3703.85
# flux_[FeII]_5039.1       EW_[FeII]_4457.95        e_disp_HI_3711.97
# flux_[FeII]_5072.4       EW_[FeII]_4470.29        e_disp_[OII]_3726.03
# flux_[FeII]_5107.95      EW_HeI_4471.48           e_disp_[OII]_3728.82
# flux_[FeII]_5111.63      EW_[FeII]_4474.91        e_disp_HI_3734.37
# flux_[FeVI]_5145.8       EW_[NiII]_4485.21        e_disp_HI_3750.15
# flux_[FeII]_5158.0       EW_[MgI]_4562.48         e_disp_[FeVII]_3758.9
# flux_[FeVII]_5158.9      EW_MgI]_4571.1           e_disp_HI_3770.63
# flux_[FeVI]_5176.0       EW_[FeII]_4632.27        e_disp_HI_3797.9
# flux_[FeII]_5184.8       EW_[FeIII]_4658.1        e_disp_HeI_3819.61
# flux_[ArIII]_5191.82     EW_HeII_4685.68          e_disp_HI_3835.38
# flux_[NI]_5197.9         EW_[FeIII]_4701.62       e_disp_[NeIII]_3868.75
# flux_[NI]_5200.26        EW_[ArIV]_4711.33        e_disp_HeI_3888.65
# flux_[FeII]_5220.06      EW_HeI_4713.14           e_disp_HI_3889.05
# flux_[FeII]_5261.61      EW_[NeIV]_4724.17        e_disp_CaII_3933.66
# flux_[FeII]_5268.88      EW_[FeIII]_4733.93       e_disp_HeI_3964.73
# flux_[FeIII]_5270.3      EW_[ArIV]_4740.2         e_disp_[NeIII]_3967.46
# flux_[FeII]_5273.38      EW_[FeIII]_4754.83       e_disp_CaII_3968.47
# flux_[FeVI]_5277.8       EW_[FeIII]_4769.6        e_disp_Hepsilon_3970.07
# flux_[FeII]_5296.84      EW_[FeII]_4774.74        e_disp_HeI_4026.19
# flux_[FeXIV]_5302.86     EW_[FeIII]_4777.88       e_disp_[SII]_4068.6
# flux_[CaV]_5309.18       EW_[FeIII]_4813.9        e_disp_[SII]_4076.35
# flux_[FeII]_5333.65      EW_[FeII]_4814.55        e_disp_Hdelta_4101.77
# flux_[FeVI]_5335.2       EW_Hbeta_4861.36         e_disp_HeI_4120.81
# flux_[FeII]_5376.47      EW_[FeIII]_4881.11       e_disp_[FeII]_4177.21
# flux_HeII_5411.52        EW_[FeII]_4889.63        e_disp_[FeV]_4227.2
# flux_[FeII]_5412.64      EW_[FeVII]_4893.4        e_disp_[FeII]_4243.98
# flux_[FeVI]_5424.2       EW_[FeII]_4905.35        e_disp_CII_4267.0
# flux_[FeVI]_5426.6       EW_HeI_4921.93           e_disp_[FeII]_4287.4
# flux_[FeVI]_5484.8       EW_[FeIII]_4924.5        e_disp_Hgamma_4340.49
# flux_[ClIII]_5517.71     EW_[FeIII]_4930.5        e_disp_[FeII]_4358.1
# flux_[FeII]_5527.33      EW_[FeVII]_4942.5        e_disp_[FeII]_4358.37
# flux_[OI]_5577.34        EW_[OIII]_4958.91        e_disp_[FeII]_4359.34
# flux_[FeVI]_5631.1       EW_[FeVI]_4972.5         e_disp_[OIII]_4363.21
# flux_[FeVI]_5677.0       EW_[FeII]_4973.39        e_disp_[FeII]_4413.78
# flux_[FeVII]_5720.7      EW_[FeIII]_4985.9        e_disp_[FeII]_4414.45
# flux_[NII]_5754.59       EW_[OIII]_5006.84        e_disp_[FeII]_4416.27
# vel_HI_3686.83           EW_HeI_5015.68           e_disp_[FeII]_4452.11
# vel_HI_3691.56           EW_[FeII]_5039.1         e_disp_[FeII]_4457.95
# vel_HI_3697.15           EW_[FeII]_5072.4         e_disp_[FeII]_4470.29
# vel_HI_3703.85           EW_[FeII]_5107.95        e_disp_HeI_4471.48
# vel_HI_3711.97           EW_[FeII]_5111.63        e_disp_[FeII]_4474.91
# vel_[OII]_3726.03        EW_[FeVI]_5145.8         e_disp_[NiII]_4485.21
# vel_[OII]_3728.82        EW_[FeII]_5158.0         e_disp_[MgI]_4562.48
# vel_HI_3734.37           EW_[FeVII]_5158.9        e_disp_MgI]_4571.1
# vel_HI_3750.15           EW_[FeVI]_5176.0         e_disp_[FeII]_4632.27
# vel_[FeVII]_3758.9       EW_[FeII]_5184.8         e_disp_[FeIII]_4658.1
# vel_HI_3770.63           EW_[ArIII]_5191.82       e_disp_HeII_4685.68
# vel_HI_3797.9            EW_[NI]_5197.9           e_disp_[FeIII]_4701.62
# vel_HeI_3819.61          EW_[NI]_5200.26          e_disp_[ArIV]_4711.33
# vel_HI_3835.38           EW_[FeII]_5220.06        e_disp_HeI_4713.14
# vel_[NeIII]_3868.75      EW_[FeII]_5261.61        e_disp_[NeIV]_4724.17
# vel_HeI_3888.65          EW_[FeII]_5268.88        e_disp_[FeIII]_4733.93
# vel_HI_3889.05           EW_[FeIII]_5270.3        e_disp_[ArIV]_4740.2
# vel_CaII_3933.66         EW_[FeII]_5273.38        e_disp_[FeIII]_4754.83
# vel_HeI_3964.73          EW_[FeVI]_5277.8         e_disp_[FeIII]_4769.6
# vel_[NeIII]_3967.46      EW_[FeII]_5296.84        e_disp_[FeII]_4774.74
# vel_CaII_3968.47         EW_[FeXIV]_5302.86       e_disp_[FeIII]_4777.88
# vel_Hepsilon_3970.07     EW_[CaV]_5309.18         e_disp_[FeIII]_4813.9
# vel_HeI_4026.19          EW_[FeII]_5333.65        e_disp_[FeII]_4814.55
# vel_[SII]_4068.6         EW_[FeVI]_5335.2         e_disp_Hbeta_4861.36
# vel_[SII]_4076.35        EW_[FeII]_5376.47        e_disp_[FeIII]_4881.11
# vel_Hdelta_4101.77       EW_HeII_5411.52          e_disp_[FeII]_4889.63
# vel_HeI_4120.81          EW_[FeII]_5412.64        e_disp_[FeVII]_4893.4
# vel_[FeII]_4177.21       EW_[FeVI]_5424.2         e_disp_[FeII]_4905.35
# vel_[FeV]_4227.2         EW_[FeVI]_5426.6         e_disp_HeI_4921.93
# vel_[FeII]_4243.98       EW_[FeVI]_5484.8         e_disp_[FeIII]_4924.5
# vel_CII_4267.0           EW_[ClIII]_5517.71       e_disp_[FeIII]_4930.5
# vel_[FeII]_4287.4        EW_[FeII]_5527.33        e_disp_[FeVII]_4942.5
# vel_Hgamma_4340.49       EW_[OI]_5577.34          e_disp_[OIII]_4958.91
# vel_[FeII]_4358.1        EW_[FeVI]_5631.1         e_disp_[FeVI]_4972.5
# vel_[FeII]_4358.37       EW_[FeVI]_5677.0         e_disp_[FeII]_4973.39
# vel_[FeII]_4359.34       EW_[FeVII]_5720.7        e_disp_[FeIII]_4985.9
# vel_[OIII]_4363.21       EW_[NII]_5754.59         e_disp_[OIII]_5006.84
# vel_[FeII]_4413.78       e_flux_HI_3686.83        e_disp_HeI_5015.68
# vel_[FeII]_4414.45       e_flux_HI_3691.56        e_disp_[FeII]_5039.1
# vel_[FeII]_4416.27       e_flux_HI_3697.15        e_disp_[FeII]_5072.4
# vel_[FeII]_4452.11       e_flux_HI_3703.85        e_disp_[FeII]_5107.95
# vel_[FeII]_4457.95       e_flux_HI_3711.97        e_disp_[FeII]_5111.63
# vel_[FeII]_4470.29       e_flux_[OII]_3726.03     e_disp_[FeVI]_5145.8
# vel_HeI_4471.48          e_flux_[OII]_3728.82     e_disp_[FeII]_5158.0
# vel_[FeII]_4474.91       e_flux_HI_3734.37        e_disp_[FeVII]_5158.9
# vel_[NiII]_4485.21       e_flux_HI_3750.15        e_disp_[FeVI]_5176.0
# vel_[MgI]_4562.48        e_flux_[FeVII]_3758.9    e_disp_[FeII]_5184.8
# vel_MgI]_4571.1          e_flux_HI_3770.63        e_disp_[ArIII]_5191.82
# vel_[FeII]_4632.27       e_flux_HI_3797.9         e_disp_[NI]_5197.9
# vel_[FeIII]_4658.1       e_flux_HeI_3819.61       e_disp_[NI]_5200.26
# vel_HeII_4685.68         e_flux_HI_3835.38        e_disp_[FeII]_5220.06
# vel_[FeIII]_4701.62      e_flux_[NeIII]_3868.75   e_disp_[FeII]_5261.61
# vel_[ArIV]_4711.33       e_flux_HeI_3888.65       e_disp_[FeII]_5268.88
# vel_HeI_4713.14          e_flux_HI_3889.05        e_disp_[FeIII]_5270.3
# vel_[NeIV]_4724.17       e_flux_CaII_3933.66      e_disp_[FeII]_5273.38
# vel_[FeIII]_4733.93      e_flux_HeI_3964.73       e_disp_[FeVI]_5277.8
# vel_[ArIV]_4740.2        e_flux_[NeIII]_3967.46   e_disp_[FeII]_5296.84
# vel_[FeIII]_4754.83      e_flux_CaII_3968.47      e_disp_[FeXIV]_5302.86
# vel_[FeIII]_4769.6       e_flux_Hepsilon_3970.07  e_disp_[CaV]_5309.18
# vel_[FeII]_4774.74       e_flux_HeI_4026.19       e_disp_[FeII]_5333.65
# vel_[FeIII]_4777.88      e_flux_[SII]_4068.6      e_disp_[FeVI]_5335.2
# vel_[FeIII]_4813.9       e_flux_[SII]_4076.35     e_disp_[FeII]_5376.47
# vel_[FeII]_4814.55       e_flux_Hdelta_4101.77    e_disp_HeII_5411.52
# vel_Hbeta_4861.36        e_flux_HeI_4120.81       e_disp_[FeII]_5412.64
# vel_[FeIII]_4881.11      e_flux_[FeII]_4177.21    e_disp_[FeVI]_5424.2
# vel_[FeII]_4889.63       e_flux_[FeV]_4227.2      e_disp_[FeVI]_5426.6
# vel_[FeVII]_4893.4       e_flux_[FeII]_4243.98    e_disp_[FeVI]_5484.8
# vel_[FeII]_4905.35       e_flux_CII_4267.0        e_disp_[ClIII]_5517.71
# vel_HeI_4921.93          e_flux_[FeII]_4287.4     e_disp_[FeII]_5527.33
# vel_[FeIII]_4924.5       e_flux_Hgamma_4340.49    e_disp_[OI]_5577.34
# vel_[FeIII]_4930.5       e_flux_[FeII]_4358.1     e_disp_[FeVI]_5631.1
# vel_[FeVII]_4942.5       e_flux_[FeII]_4358.37    e_disp_[FeVI]_5677.0
# vel_[OIII]_4958.91       e_flux_[FeII]_4359.34    e_disp_[FeVII]_5720.7
# vel_[FeVI]_4972.5        e_flux_[OIII]_4363.21    e_disp_[NII]_5754.59
# vel_[FeII]_4973.39       e_flux_[FeII]_4413.78    e_EW_HI_3686.83
# vel_[FeIII]_4985.9       e_flux_[FeII]_4414.45    e_EW_HI_3691.56
# vel_[OIII]_5006.84       e_flux_[FeII]_4416.27    e_EW_HI_3697.15
# vel_HeI_5015.68          e_flux_[FeII]_4452.11    e_EW_HI_3703.85
# vel_[FeII]_5039.1        e_flux_[FeII]_4457.95    e_EW_HI_3711.97
# vel_[FeII]_5072.4        e_flux_[FeII]_4470.29    e_EW_[OII]_3726.03
# vel_[FeII]_5107.95       e_flux_HeI_4471.48       e_EW_[OII]_3728.82
# vel_[FeII]_5111.63       e_flux_[FeII]_4474.91    e_EW_HI_3734.37
# vel_[FeVI]_5145.8        e_flux_[NiII]_4485.21    e_EW_HI_3750.15
# vel_[FeII]_5158.0        e_flux_[MgI]_4562.48     e_EW_[FeVII]_3758.9
# vel_[FeVII]_5158.9       e_flux_MgI]_4571.1       e_EW_HI_3770.63
# vel_[FeVI]_5176.0        e_flux_[FeII]_4632.27    e_EW_HI_3797.9
# vel_[FeII]_5184.8        e_flux_[FeIII]_4658.1    e_EW_HeI_3819.61
# vel_[ArIII]_5191.82      e_flux_HeII_4685.68      e_EW_HI_3835.38
# vel_[NI]_5197.9          e_flux_[FeIII]_4701.62   e_EW_[NeIII]_3868.75
# vel_[NI]_5200.26         e_flux_[ArIV]_4711.33    e_EW_HeI_3888.65
# vel_[FeII]_5220.06       e_flux_HeI_4713.14       e_EW_HI_3889.05
# vel_[FeII]_5261.61       e_flux_[NeIV]_4724.17    e_EW_CaII_3933.66
# vel_[FeII]_5268.88       e_flux_[FeIII]_4733.93   e_EW_HeI_3964.73
# vel_[FeIII]_5270.3       e_flux_[ArIV]_4740.2     e_EW_[NeIII]_3967.46
# vel_[FeII]_5273.38       e_flux_[FeIII]_4754.83   e_EW_CaII_3968.47
# vel_[FeVI]_5277.8        e_flux_[FeIII]_4769.6    e_EW_Hepsilon_3970.07
# vel_[FeII]_5296.84       e_flux_[FeII]_4774.74    e_EW_HeI_4026.19
# vel_[FeXIV]_5302.86      e_flux_[FeIII]_4777.88   e_EW_[SII]_4068.6
# vel_[CaV]_5309.18        e_flux_[FeIII]_4813.9    e_EW_[SII]_4076.35
# vel_[FeII]_5333.65       e_flux_[FeII]_4814.55    e_EW_Hdelta_4101.77
# vel_[FeVI]_5335.2        e_flux_Hbeta_4861.36     e_EW_HeI_4120.81
# vel_[FeII]_5376.47       e_flux_[FeIII]_4881.11   e_EW_[FeII]_4177.21
# vel_HeII_5411.52         e_flux_[FeII]_4889.63    e_EW_[FeV]_4227.2
# vel_[FeII]_5412.64       e_flux_[FeVII]_4893.4    e_EW_[FeII]_4243.98
# vel_[FeVI]_5424.2        e_flux_[FeII]_4905.35    e_EW_CII_4267.0
# vel_[FeVI]_5426.6        e_flux_HeI_4921.93       e_EW_[FeII]_4287.4
# vel_[FeVI]_5484.8        e_flux_[FeIII]_4924.5    e_EW_Hgamma_4340.49
# vel_[ClIII]_5517.71      e_flux_[FeIII]_4930.5    e_EW_[FeII]_4358.1
# vel_[FeII]_5527.33       e_flux_[FeVII]_4942.5    e_EW_[FeII]_4358.37
# vel_[OI]_5577.34         e_flux_[OIII]_4958.91    e_EW_[FeII]_4359.34
# vel_[FeVI]_5631.1        e_flux_[FeVI]_4972.5     e_EW_[OIII]_4363.21
# vel_[FeVI]_5677.0        e_flux_[FeII]_4973.39    e_EW_[FeII]_4413.78
# vel_[FeVII]_5720.7       e_flux_[FeIII]_4985.9    e_EW_[FeII]_4414.45
# vel_[NII]_5754.59        e_flux_[OIII]_5006.84    e_EW_[FeII]_4416.27
# disp_HI_3686.83          e_flux_HeI_5015.68       e_EW_[FeII]_4452.11
# disp_HI_3691.56          e_flux_[FeII]_5039.1     e_EW_[FeII]_4457.95
# disp_HI_3697.15          e_flux_[FeII]_5072.4     e_EW_[FeII]_4470.29
# disp_HI_3703.85          e_flux_[FeII]_5107.95    e_EW_HeI_4471.48
# disp_HI_3711.97          e_flux_[FeII]_5111.63    e_EW_[FeII]_4474.91
# disp_[OII]_3726.03       e_flux_[FeVI]_5145.8     e_EW_[NiII]_4485.21
# disp_[OII]_3728.82       e_flux_[FeII]_5158.0     e_EW_[MgI]_4562.48
# disp_HI_3734.37          e_flux_[FeVII]_5158.9    e_EW_MgI]_4571.1
# disp_HI_3750.15          e_flux_[FeVI]_5176.0     e_EW_[FeII]_4632.27
# disp_[FeVII]_3758.9      e_flux_[FeII]_5184.8     e_EW_[FeIII]_4658.1
# disp_HI_3770.63          e_flux_[ArIII]_5191.82   e_EW_HeII_4685.68
# disp_HI_3797.9           e_flux_[NI]_5197.9       e_EW_[FeIII]_4701.62
# disp_HeI_3819.61         e_flux_[NI]_5200.26      e_EW_[ArIV]_4711.33
# disp_HI_3835.38          e_flux_[FeII]_5220.06    e_EW_HeI_4713.14
# disp_[NeIII]_3868.75     e_flux_[FeII]_5261.61    e_EW_[NeIV]_4724.17
# disp_HeI_3888.65         e_flux_[FeII]_5268.88    e_EW_[FeIII]_4733.93
# disp_HI_3889.05          e_flux_[FeIII]_5270.3    e_EW_[ArIV]_4740.2
# disp_CaII_3933.66        e_flux_[FeII]_5273.38    e_EW_[FeIII]_4754.83
# disp_HeI_3964.73         e_flux_[FeVI]_5277.8     e_EW_[FeIII]_4769.6
# disp_[NeIII]_3967.46     e_flux_[FeII]_5296.84    e_EW_[FeII]_4774.74
# disp_CaII_3968.47        e_flux_[FeXIV]_5302.86   e_EW_[FeIII]_4777.88
# disp_Hepsilon_3970.07    e_flux_[CaV]_5309.18     e_EW_[FeIII]_4813.9
# disp_HeI_4026.19         e_flux_[FeII]_5333.65    e_EW_[FeII]_4814.55
# disp_[SII]_4068.6        e_flux_[FeVI]_5335.2     e_EW_Hbeta_4861.36
# disp_[SII]_4076.35       e_flux_[FeII]_5376.47    e_EW_[FeIII]_4881.11
# disp_Hdelta_4101.77      e_flux_HeII_5411.52      e_EW_[FeII]_4889.63
# disp_HeI_4120.81         e_flux_[FeII]_5412.64    e_EW_[FeVII]_4893.4
# disp_[FeII]_4177.21      e_flux_[FeVI]_5424.2     e_EW_[FeII]_4905.35
# disp_[FeV]_4227.2        e_flux_[FeVI]_5426.6     e_EW_HeI_4921.93
# disp_[FeII]_4243.98      e_flux_[FeVI]_5484.8     e_EW_[FeIII]_4924.5
# disp_CII_4267.0          e_flux_[ClIII]_5517.71   e_EW_[FeIII]_4930.5
# disp_[FeII]_4287.4       e_flux_[FeII]_5527.33    e_EW_[FeVII]_4942.5
# disp_Hgamma_4340.49      e_flux_[OI]_5577.34      e_EW_[OIII]_4958.91
# disp_[FeII]_4358.1       e_flux_[FeVI]_5631.1     e_EW_[FeVI]_4972.5
# disp_[FeII]_4358.37      e_flux_[FeVI]_5677.0     e_EW_[FeII]_4973.39
# disp_[FeII]_4359.34      e_flux_[FeVII]_5720.7    e_EW_[FeIII]_4985.9
# disp_[OIII]_4363.21      e_flux_[NII]_5754.59     e_EW_[OIII]_5006.84
# disp_[FeII]_4413.78      e_vel_HI_3686.83         e_EW_HeI_5015.68
# disp_[FeII]_4414.45      e_vel_HI_3691.56         e_EW_[FeII]_5039.1
# disp_[FeII]_4416.27      e_vel_HI_3697.15         e_EW_[FeII]_5072.4
# disp_[FeII]_4452.11      e_vel_HI_3703.85         e_EW_[FeII]_5107.95
# disp_[FeII]_4457.95      e_vel_HI_3711.97         e_EW_[FeII]_5111.63
# disp_[FeII]_4470.29      e_vel_[OII]_3726.03      e_EW_[FeVI]_5145.8
# disp_HeI_4471.48         e_vel_[OII]_3728.82      e_EW_[FeII]_5158.0
# disp_[FeII]_4474.91      e_vel_HI_3734.37         e_EW_[FeVII]_5158.9
# disp_[NiII]_4485.21      e_vel_HI_3750.15         e_EW_[FeVI]_5176.0
# disp_[MgI]_4562.48       e_vel_[FeVII]_3758.9     e_EW_[FeII]_5184.8
# disp_MgI]_4571.1         e_vel_HI_3770.63         e_EW_[ArIII]_5191.82
# disp_[FeII]_4632.27      e_vel_HI_3797.9          e_EW_[NI]_5197.9
# disp_[FeIII]_4658.1      e_vel_HeI_3819.61        e_EW_[NI]_5200.26
# disp_HeII_4685.68        e_vel_HI_3835.38         e_EW_[FeII]_5220.06
# disp_[FeIII]_4701.62     e_vel_[NeIII]_3868.75    e_EW_[FeII]_5261.61
# disp_[ArIV]_4711.33      e_vel_HeI_3888.65        e_EW_[FeII]_5268.88
# disp_HeI_4713.14         e_vel_HI_3889.05         e_EW_[FeIII]_5270.3
# disp_[NeIV]_4724.17      e_vel_CaII_3933.66       e_EW_[FeII]_5273.38
# disp_[FeIII]_4733.93     e_vel_HeI_3964.73        e_EW_[FeVI]_5277.8
# disp_[ArIV]_4740.2       e_vel_[NeIII]_3967.46    e_EW_[FeII]_5296.84
# disp_[FeIII]_4754.83     e_vel_CaII_3968.47       e_EW_[FeXIV]_5302.86
# disp_[FeIII]_4769.6      e_vel_Hepsilon_3970.07   e_EW_[CaV]_5309.18
# disp_[FeII]_4774.74      e_vel_HeI_4026.19        e_EW_[FeII]_5333.65
# disp_[FeIII]_4777.88     e_vel_[SII]_4068.6       e_EW_[FeVI]_5335.2
# disp_[FeIII]_4813.9      e_vel_[SII]_4076.35      e_EW_[FeII]_5376.47
# disp_[FeII]_4814.55      e_vel_Hdelta_4101.77     e_EW_HeII_5411.52
# disp_Hbeta_4861.36       e_vel_HeI_4120.81        e_EW_[FeII]_5412.64
# disp_[FeIII]_4881.11     e_vel_[FeII]_4177.21     e_EW_[FeVI]_5424.2
# disp_[FeII]_4889.63      e_vel_[FeV]_4227.2       e_EW_[FeVI]_5426.6
# disp_[FeVII]_4893.4      e_vel_[FeII]_4243.98     e_EW_[FeVI]_5484.8
# disp_[FeII]_4905.35      e_vel_CII_4267.0         e_EW_[ClIII]_5517.71
# disp_HeI_4921.93         e_vel_[FeII]_4287.4      e_EW_[FeII]_5527.33
# disp_[FeIII]_4924.5      e_vel_Hgamma_4340.49     e_EW_[OI]_5577.34
# disp_[FeIII]_4930.5      e_vel_[FeII]_4358.1      e_EW_[FeVI]_5631.1
# disp_[FeVII]_4942.5      e_vel_[FeII]_4358.37     e_EW_[FeVI]_5677.0
# disp_[OIII]_4958.91      e_vel_[FeII]_4359.34     e_EW_[FeVII]_5720.7
# disp_[FeVI]_4972.5       e_vel_[OIII]_4363.21     e_EW_[NII]_5754.59
# disp_[FeII]_4973.39      e_vel_[FeII]_4413.78
# disp_[FeIII]_4985.9      e_vel_[FeII]_4414.45
# ----------------------------------
# |        NPE_R                    |
# ----------------------------------
# id                     disp_CII_7236.0        e_vel_[NII]_6583.45
# flux_HeI_5876.0        disp_HeI_7281.35       e_vel_HeI_6678.15
# disp_[FeX]_6374.51     e_flux_[FeII]_7388.16  e_EW_[FeII]_7155.14
# disp_[ArV]_6435.1      e_flux_[NiII]_7411.61  e_EW_[FeII]_7171.98
# disp_[NII]_6548.05     e_flux_[FeII]_7452.5   e_EW_CII_7236.0
# disp_Halpha_6562.85    e_vel_HeI_5876.0       e_EW_HeI_7281.35
# disp_[NII]_6583.45     e_vel_NaI_5889.95      e_EW_[FeI]_7290.42
# disp_HeI_6678.15       e_vel_NaI_5895.92      e_EW_[CaII]_7291.46
# disp_[SII]_6716.44     e_vel_[FeVII]_6087.0   e_EW_[OII]_7318.92
# disp_[SII]_6730.82     e_vel_[OI]_6300.3      e_EW_[CaII]_7323.88
# disp_FeI_6855.18       e_vel_[SIII]_6312.06   e_EW_[OII]_7329.66
# disp_[ArV]_7005.67     e_vel_[OI]_6363.78     e_EW_[NiII]_7377.83
# disp_HeI_7065.19       e_vel_[FeX]_6374.51    e_EW_[FeII]_7388.16
# disp_[ArIII]_7135.8    e_vel_[ArV]_6435.1     e_EW_[NiII]_7411.61
# disp_[FeII]_7155.14    e_vel_[NII]_6548.05    e_EW_[FeII]_7452.5
# disp_[FeII]_7171.98    e_vel_Halpha_6562.85
# ----------------------------------
# |        NPE_I                    |
# ----------------------------------
# id                      disp_[ClII]_8578.7      e_vel_HI_8276.94
# flux_[FeII]_7637.52     disp_HI_8598.39         e_vel_HI_8281.75
# flux_[FeII]_7686.19     disp_[FeII]_8616.96     e_vel_HI_8287.06
# flux_[FeII]_7686.9      disp_CaII_8662.14       e_vel_HI_8292.94
# flux_[ArIII]_7751.06    disp_HI_8665.02         e_vel_HI_8299.47
# flux_OI_7774.0          disp_[CI]_8727.13       e_vel_[NiII]_8300.99
# flux_[FeXI]_7891.8      disp_HI_8750.47         e_vel_HI_8306.75
# flux_[CrII]_7999.85     disp_HI_8862.78         e_vel_[CrII]_8308.39
# flux_[CrII]_8125.22     disp_[FeII]_8891.88     e_vel_HI_8314.89
# flux_[CrII]_8229.55     disp_HI_9014.91         e_vel_HI_8324.06
# flux_HeII_8236.77       disp_[FeII]_9033.45     e_vel_HI_8334.42
# flux_HI_8239.24         disp_[FeII]_9051.92     e_vel_HI_8345.55
# flux_HI_8240.82         disp_[SIII]_9069.0      e_vel_[CrII]_8357.51
# flux_HI_8242.51         disp_[ClII]_9123.6      e_vel_HI_8359.0
# flux_HI_8244.32         disp_[FeII]_9226.6      e_vel_HI_8374.48
# flux_HI_8246.27         disp_HI_9229.02         e_vel_HI_8392.4
# flux_HI_8248.35         disp_OI_9266.0          e_vel_OI_8446.0
# flux_HI_8250.6          disp_[FeII]_9267.54     e_vel_HI_8467.25
# flux_HI_8253.03         disp_[FeII]_9399.02     e_vel_CaII_8498.02
# flux_HI_8255.65         disp_[FeII]_9470.93     e_vel_HI_8502.48
# flux_HI_8258.49         disp_[SIII]_9531.1      e_vel_CaII_8542.09
# flux_HI_8261.57         disp_HI_9545.97         e_vel_HI_8545.38
# flux_HI_8264.92         disp_[FeII]_9682.13     e_vel_[ClII]_8578.7
# disp_HI_8345.55         e_vel_HI_8244.32        e_EW_[FeII]_9226.6
# disp_[CrII]_8357.51     e_vel_HI_8246.27        e_EW_HI_9229.02
# disp_HI_8359.0          e_vel_HI_8248.35        e_EW_OI_9266.0
# disp_HI_8374.48         e_vel_HI_8250.6         e_EW_[FeII]_9267.54
# disp_HI_8392.4          e_vel_HI_8253.03        e_EW_[FeII]_9399.02
# disp_OI_8446.0          e_vel_HI_8255.65        e_EW_[FeII]_9470.93
# disp_HI_8467.25         e_vel_HI_8258.49        e_EW_[SIII]_9531.1
# disp_CaII_8498.02       e_vel_HI_8261.57        e_EW_HI_9545.97
# disp_HI_8502.48         e_vel_HI_8264.92        e_EW_[FeII]_9682.13
# disp_CaII_8542.09       e_vel_HI_8268.57
# disp_HI_8545.38         e_vel_HI_8272.56
# ----------------------------------
# |        C_ord                    |
# ----------------------------------
# id              Teff_rsp_27     Log_g_rsp_54    Fe_rsp_81
# Teff_rsp_0      Log_g_rsp_27    Fe_rsp_54       alpha_rsp_81
# ...
# sigma_kms_HeI_4471.48       sigma_kms_pe_9069.0         fr_[FeVI]_5145.8            X_sq_[NiII]_8300.99
# sigma_kms_[FeII]_4474.91    sigma_kms_pe_9531.1         X_sq_[FeII]_5158.0          fr_[NiII]_8300.99
# sigma_kms_[NiII]_4485.21    sigma_kms_pek_3726.03       fr_[FeII]_5158.0            X_sq_HI_8306.75
# sigma_kms_[MgI]_4562.48     sigma_kms_pek_3728.82       X_sq_[FeVII]_5158.9         fr_HI_8306.75
# sigma_kms_MgI]_4571.1       sigma_kms_pek_4101.77       fr_[FeVII]_5158.9           X_sq_[CrII]_8308.39
# sigma_kms_[FeII]_4632.27    sigma_kms_pek_4340.49       X_sq_[FeVI]_5176.0          fr_[CrII]_8308.39
# sigma_kms_[FeIII]_4658.1    sigma_kms_pek_4861.36       fr_[FeVI]_5176.0            X_sq_HI_8314.89
# sigma_kms_HeII_4685.68      sigma_kms_pek_4958.91       X_sq_[FeII]_5184.8          fr_HI_8314.89
# sigma_kms_[FeIII]_4701.62   sigma_kms_pek_5006.84       fr_[FeII]_5184.8            X_sq_HI_8324.06
# sigma_kms_[ArIV]_4711.33    sigma_kms_pek_6300.3        X_sq_[ArIII]_5191.82        fr_HI_8324.06
# sigma_kms_HeI_4713.14       sigma_kms_pek_6548.05       fr_[ArIII]_5191.82          X_sq_HI_8334.42
# sigma_kms_[NeIV]_4724.17    sigma_kms_pek_6562.85       X_sq_[NI]_5197.9            fr_HI_8334.42
# sigma_kms_[FeIII]_4733.93   sigma_kms_pek_6583.45       fr_[NI]_5197.9              X_sq_HI_8345.55
# sigma_kms_[ArIV]_4740.2     sigma_kms_pek_6716.44       X_sq_[NI]_5200.26           fr_HI_8345.55
# sigma_kms_[FeIII]_4754.83   sigma_kms_pek_6730.82       fr_[NI]_5200.26             X_sq_[CrII]_8357.51
# sigma_kms_[FeIII]_4769.6    sigma_kms_pek_9069.0        X_sq_[FeII]_5220.06         fr_[CrII]_8357.51
# sigma_kms_[FeII]_4774.74    sigma_kms_pek_9531.1        fr_[FeII]_5220.06           X_sq_HI_8359.0
# sigma_kms_[FeIII]_4777.88   X_sq_st                     X_sq_[FeII]_5261.61         fr_HI_8359.0
# sigma_kms_[FeIII]_4813.9    X_sq_st_np                  fr_[FeII]_5261.61           X_sq_HI_8374.48
# sigma_kms_[FeII]_4814.55    X_sq_st_pek                 X_sq_[FeII]_5268.88         fr_HI_8374.48
# sigma_kms_Hbeta_4861.36     X_sq_HI_3686.83             fr_[FeII]_5268.88           X_sq_HI_8392.4
# sigma_kms_[FeIII]_4881.11   fr_HI_3686.83               X_sq_[FeIII]_5270.3         fr_HI_8392.4
# sigma_kms_[FeII]_4889.63    X_sq_HI_3691.56             fr_[FeIII]_5270.3           X_sq_OI_8446.0
# sigma_kms_[FeVII]_4893.4    fr_HI_3691.56               X_sq_[FeII]_5273.38         fr_OI_8446.0
# sigma_kms_[FeII]_4905.35    X_sq_HI_3697.15             fr_[FeII]_5273.38           X_sq_HI_8467.25
# sigma_kms_HeI_4921.93       fr_HI_3697.15               X_sq_[FeVI]_5277.8          fr_HI_8467.25
# sigma_kms_[FeIII]_4924.5    X_sq_HI_3703.85             fr_[FeVI]_5277.8            X_sq_CaII_8498.02
# sigma_kms_[FeIII]_4930.5    fr_HI_3703.85               X_sq_[FeII]_5296.84         fr_CaII_8498.02
# sigma_kms_[FeVII]_4942.5    X_sq_HI_3711.97             fr_[FeII]_5296.84           X_sq_HI_8502.48
# sigma_kms_[OIII]_4958.91    fr_HI_3711.97               X_sq_[FeXIV]_5302.86        fr_HI_8502.48
# sigma_kms_[FeVI]_4972.5     X_sq_[OII]_3726.03          fr_[FeXIV]_5302.86          X_sq_CaII_8542.09
# sigma_kms_[FeII]_4973.39    fr_[OII]_3726.03            X_sq_[CaV]_5309.18          fr_CaII_8542.09
# sigma_kms_[FeIII]_4985.9    X_sq_[OII]_3728.82          fr_[CaV]_5309.18            X_sq_HI_8545.38
# sigma_kms_[OIII]_5006.84    fr_[OII]_3728.82            X_sq_[FeII]_5333.65         fr_HI_8545.38
# sigma_kms_HeI_5015.68       X_sq_HI_3734.37             fr_[FeII]_5333.65           X_sq_[ClII]_8578.7
# sigma_kms_[FeII]_5039.1     fr_HI_3734.37               X_sq_[FeVI]_5335.2          fr_[ClII]_8578.7
# sigma_kms_[FeII]_5072.4     X_sq_HI_3750.15             fr_[FeVI]_5335.2            X_sq_HI_8598.39
# sigma_kms_[FeII]_5107.95    fr_HI_3750.15               X_sq_[FeII]_5376.47         fr_HI_8598.39
# sigma_kms_[FeII]_5111.63    X_sq_[FeVII]_3758.9         fr_[FeII]_5376.47           X_sq_[FeII]_8616.96
# sigma_kms_[FeVI]_5145.8     fr_[FeVII]_3758.9           X_sq_HeII_5411.52           fr_[FeII]_8616.96
# sigma_kms_[FeII]_5158.0     X_sq_HI_3770.63             fr_HeII_5411.52             X_sq_CaII_8662.14
# sigma_kms_[FeVII]_5158.9    fr_HI_3770.63               X_sq_[FeII]_5412.64         fr_CaII_8662.14
# sigma_kms_[FeVI]_5176.0     X_sq_HI_3797.9              fr_[FeII]_5412.64           X_sq_HI_8665.02
# sigma_kms_[FeII]_5184.8     fr_HI_3797.9                X_sq_[FeVI]_5424.2          fr_HI_8665.02
# sigma_kms_[ArIII]_5191.82   X_sq_HeI_3819.61            fr_[FeVI]_5424.2            X_sq_[CI]_8727.13
# sigma_kms_[NI]_5197.9       fr_HeI_3819.61              X_sq_[FeVI]_5426.6          fr_[CI]_8727.13
# sigma_kms_[NI]_5200.26      X_sq_HI_3835.38             fr_[FeVI]_5426.6            X_sq_HI_8750.47
# sigma_kms_[FeII]_5220.06    fr_HI_3835.38               X_sq_[FeVI]_5484.8          fr_HI_8750.47
# sigma_kms_[FeII]_5261.61    X_sq_[NeIII]_3868.75        fr_[FeVI]_5484.8            X_sq_HI_8862.78
# sigma_kms_[FeII]_5268.88    fr_[NeIII]_3868.75          X_sq_[ClIII]_5517.71        fr_HI_8862.78
# sigma_kms_[FeIII]_5270.3    X_sq_HeI_3888.65            fr_[ClIII]_5517.71          X_sq_[FeII]_8891.88
# sigma_kms_[FeII]_5273.38    fr_HeI_3888.65              X_sq_[FeII]_5527.33         fr_[FeII]_8891.88
# sigma_kms_[FeVI]_5277.8     X_sq_HI_3889.05             fr_[FeII]_5527.33           X_sq_HI_9014.91
# sigma_kms_[FeII]_5296.84    fr_HI_3889.05               X_sq_[OI]_5577.34           fr_HI_9014.91
# sigma_kms_[FeXIV]_5302.86   X_sq_CaII_3933.66           fr_[OI]_5577.34             X_sq_[FeII]_9033.45
# sigma_kms_[CaV]_5309.18     fr_CaII_3933.66             X_sq_[FeVI]_5631.1          fr_[FeII]_9033.45
# sigma_kms_[FeII]_5333.65    X_sq_HeI_3964.73            fr_[FeVI]_5631.1            X_sq_[FeII]_9051.92
# sigma_kms_[FeVI]_5335.2     fr_HeI_3964.73              X_sq_[FeVI]_5677.0          fr_[FeII]_9051.92
# sigma_kms_[FeII]_5376.47    X_sq_[NeIII]_3967.46        fr_[FeVI]_5677.0            X_sq_[SIII]_9069.0
# sigma_kms_HeII_5411.52      fr_[NeIII]_3967.46          X_sq_[FeVII]_5720.7         fr_[SIII]_9069.0
# sigma_kms_[FeII]_5412.64    X_sq_CaII_3968.47           fr_[FeVII]_5720.7           X_sq_[ClII]_9123.6
# sigma_kms_[FeVI]_5424.2     fr_CaII_3968.47             X_sq_[NII]_5754.59          fr_[ClII]_9123.6
# sigma_kms_[FeVI]_5426.6     X_sq_Hepsilon_3970.07       fr_[NII]_5754.59            X_sq_[FeII]_9226.6
# sigma_kms_[FeVI]_5484.8     fr_Hepsilon_3970.07         X_sq_HeI_5876.0             fr_[FeII]_9226.6
# sigma_kms_[ClIII]_5517.71   X_sq_HeI_4026.19            fr_HeI_5876.0               X_sq_HI_9229.02
# sigma_kms_[FeII]_5527.33    fr_HeI_4026.19              X_sq_NaI_5889.95            fr_HI_9229.02
# sigma_kms_[OI]_5577.34      X_sq_[SII]_4068.6           fr_NaI_5889.95              X_sq_OI_9266.0
# sigma_kms_[FeVI]_5631.1     fr_[SII]_4068.6             X_sq_NaI_5895.92            fr_OI_9266.0
# sigma_kms_[FeVI]_5677.0     X_sq_[SII]_4076.35          fr_NaI_5895.92              X_sq_[FeII]_9267.54
# sigma_kms_[FeVII]_5720.7    fr_[SII]_4076.35            X_sq_[FeVII]_6087.0         fr_[FeII]_9267.54
# sigma_kms_[NII]_5754.59     X_sq_Hdelta_4101.77         fr_[FeVII]_6087.0           X_sq_[FeII]_9399.02
# sigma_kms_HeI_5876.0        fr_Hdelta_4101.77           X_sq_[OI]_6300.3            fr_[FeII]_9399.02
# sigma_kms_NaI_5889.95       X_sq_HeI_4120.81            fr_[OI]_6300.3              X_sq_[FeII]_9470.93
# sigma_kms_NaI_5895.92       fr_HeI_4120.81              X_sq_[SIII]_6312.06         fr_[FeII]_9470.93
# sigma_kms_[FeVII]_6087.0    X_sq_[FeII]_4177.21         fr_[SIII]_6312.06           X_sq_[SIII]_9531.1
# sigma_kms_[OI]_6300.3       fr_[FeII]_4177.21           X_sq_[OI]_6363.78           fr_[SIII]_9531.1
# sigma_kms_[SIII]_6312.06    X_sq_[FeV]_4227.2           fr_[OI]_6363.78             X_sq_HI_9545.97
# sigma_kms_[OI]_6363.78      fr_[FeV]_4227.2             X_sq_[FeX]_6374.51          fr_HI_9545.97
# sigma_kms_[FeX]_6374.51     X_sq_[FeII]_4243.98         fr_[FeX]_6374.51            X_sq_[FeII]_9682.13
# sigma_kms_[ArV]_6435.1      fr_[FeII]_4243.98           X_sq_[ArV]_6435.1           fr_[FeII]_9682.13
# sigma_kms_[NII]_6548.05     X_sq_CII_4267.0             fr_[ArV]_6435.1             X_sq_pe_3726.03
# sigma_kms_Halpha_6562.85    fr_CII_4267.0               X_sq_[NII]_6548.05          fr_pe_3726.03
# sigma_kms_[NII]_6583.45     X_sq_[FeII]_4287.4          fr_[NII]_6548.05            X_sq_pe_3728.82
# sigma_kms_HeI_6678.15       fr_[FeII]_4287.4            X_sq_Halpha_6562.85         fr_pe_3728.82
# sigma_kms_[SII]_6716.44     X_sq_Hgamma_4340.49         fr_Halpha_6562.85           X_sq_pe_4101.77
# sigma_kms_[SII]_6730.82     fr_Hgamma_4340.49           X_sq_[NII]_6583.45          fr_pe_4101.77
# sigma_kms_FeI_6855.18       X_sq_[FeII]_4358.1          fr_[NII]_6583.45            X_sq_pe_4340.49
# sigma_kms_[ArV]_7005.67     fr_[FeII]_4358.1            X_sq_HeI_6678.15            fr_pe_4340.49
# sigma_kms_HeI_7065.19       X_sq_[FeII]_4358.37         fr_HeI_6678.15              X_sq_pe_4861.36
# sigma_kms_[ArIII]_7135.8    fr_[FeII]_4358.37           X_sq_[SII]_6716.44          fr_pe_4861.36
# sigma_kms_[FeII]_7155.14    X_sq_[FeII]_4359.34         fr_[SII]_6716.44            X_sq_pe_4958.91
# sigma_kms_[FeII]_7171.98    fr_[FeII]_4359.34           X_sq_[SII]_6730.82          fr_pe_4958.91
# sigma_kms_CII_7236.0        X_sq_[OIII]_4363.21         fr_[SII]_6730.82            X_sq_pe_5006.84
# sigma_kms_HeI_7281.35       fr_[OIII]_4363.21           X_sq_FeI_6855.18            fr_pe_5006.84
# sigma_kms_[FeI]_7290.42     X_sq_[FeII]_4413.78         fr_FeI_6855.18              X_sq_pe_6300.3
# sigma_kms_[CaII]_7291.46    fr_[FeII]_4413.78           X_sq_[ArV]_7005.67          fr_pe_6300.3
# sigma_kms_[OII]_7318.92     X_sq_[FeII]_4414.45         fr_[ArV]_7005.67            X_sq_pe_6548.05
# sigma_kms_[CaII]_7323.88    fr_[FeII]_4414.45           X_sq_HeI_7065.19            fr_pe_6548.05
# sigma_kms_[OII]_7329.66     X_sq_[FeII]_4416.27         fr_HeI_7065.19              X_sq_pe_6562.85
# sigma_kms_[NiII]_7377.83    fr_[FeII]_4416.27           X_sq_[ArIII]_7135.8         fr_pe_6562.85
# sigma_kms_[FeII]_7388.16    X_sq_[FeII]_4452.11         fr_[ArIII]_7135.8           X_sq_pe_6583.45
# sigma_kms_[NiII]_7411.61    fr_[FeII]_4452.11           X_sq_[FeII]_7155.14         fr_pe_6583.45
# sigma_kms_[FeII]_7452.5     X_sq_[FeII]_4457.95         fr_[FeII]_7155.14           X_sq_pe_6716.44
# sigma_kms_[FeII]_7637.52    fr_[FeII]_4457.95           X_sq_[FeII]_7171.98         fr_pe_6716.44
# sigma_kms_[FeII]_7686.19    X_sq_[FeII]_4470.29         fr_[FeII]_7171.98           X_sq_pe_6730.82
# sigma_kms_[FeII]_7686.9     fr_[FeII]_4470.29           X_sq_CII_7236.0             fr_pe_6730.82
# sigma_kms_[ArIII]_7751.06   X_sq_HeI_4471.48            fr_CII_7236.0               X_sq_pe_9069.0
# sigma_kms_OI_7774.0         fr_HeI_4471.48              X_sq_HeI_7281.35            fr_pe_9069.0
# sigma_kms_[FeXI]_7891.8     X_sq_[FeII]_4474.91         fr_HeI_7281.35              X_sq_pe_9531.1
# sigma_kms_[CrII]_7999.85    fr_[FeII]_4474.91           X_sq_[FeI]_7290.42          fr_pe_9531.1
# sigma_kms_[CrII]_8125.22    X_sq_[NiII]_4485.21         fr_[FeI]_7290.42            X_sq_pek_3726.03
# sigma_kms_[CrII]_8229.55    fr_[NiII]_4485.21           X_sq_[CaII]_7291.46         fr_pek_3726.03
# sigma_kms_HeII_8236.77      X_sq_[MgI]_4562.48          fr_[CaII]_7291.46           X_sq_pek_3728.82
# sigma_kms_HI_8239.24        fr_[MgI]_4562.48            X_sq_[OII]_7318.92          fr_pek_3728.82
# sigma_kms_HI_8240.82        X_sq_MgI]_4571.1            fr_[OII]_7318.92            X_sq_pek_4101.77
# sigma_kms_HI_8242.51        fr_MgI]_4571.1              X_sq_[CaII]_7323.88         fr_pek_4101.77
# sigma_kms_HI_8244.32        X_sq_[FeII]_4632.27         fr_[CaII]_7323.88           X_sq_pek_4340.49
# sigma_kms_HI_8246.27        fr_[FeII]_4632.27           X_sq_[OII]_7329.66          fr_pek_4340.49
# sigma_kms_HI_8248.35        X_sq_[FeIII]_4658.1         fr_[OII]_7329.66            X_sq_pek_4861.36
# sigma_kms_HI_8250.6         fr_[FeIII]_4658.1           X_sq_[NiII]_7377.83         fr_pek_4861.36
# sigma_kms_HI_8253.03        X_sq_HeII_4685.68           fr_[NiII]_7377.83           X_sq_pek_4958.91
# sigma_kms_HI_8255.65        fr_HeII_4685.68             X_sq_[FeII]_7388.16         fr_pek_4958.91
# sigma_kms_HI_8258.49        X_sq_[FeIII]_4701.62        fr_[FeII]_7388.16           X_sq_pek_5006.84
# sigma_kms_HI_8261.57        fr_[FeIII]_4701.62          X_sq_[NiII]_7411.61         fr_pek_5006.84
# sigma_kms_HI_8264.92        X_sq_[ArIV]_4711.33         fr_[NiII]_7411.61           X_sq_pek_6300.3
# sigma_kms_HI_8268.57        fr_[ArIV]_4711.33           X_sq_[FeII]_7452.5          fr_pek_6300.3
# sigma_kms_HI_8272.56        X_sq_HeI_4713.14            fr_[FeII]_7452.5            X_sq_pek_6548.05
# sigma_kms_HI_8276.94        fr_HeI_4713.14              X_sq_[FeII]_7637.52         fr_pek_6548.05
# sigma_kms_HI_8281.75        X_sq_[NeIV]_4724.17         fr_[FeII]_7637.52           X_sq_pek_6562.85
# sigma_kms_HI_8287.06        fr_[NeIV]_4724.17           X_sq_[FeII]_7686.19         fr_pek_6562.85
# sigma_kms_HI_8292.94        X_sq_[FeIII]_4733.93        fr_[FeII]_7686.19           X_sq_pek_6583.45
# sigma_kms_HI_8299.47        fr_[FeIII]_4733.93          X_sq_[FeII]_7686.9          fr_pek_6583.45
# sigma_kms_[NiII]_8300.99    X_sq_[ArIV]_4740.2          fr_[FeII]_7686.9            X_sq_pek_6716.44
# sigma_kms_HI_8306.75        fr_[ArIV]_4740.2            X_sq_[ArIII]_7751.06        fr_pek_6716.44
# sigma_kms_[CrII]_8308.39    X_sq_[FeIII]_4754.83        fr_[ArIII]_7751.06          X_sq_pek_6730.82
# sigma_kms_HI_8314.89        fr_[FeIII]_4754.83          X_sq_OI_7774.0              fr_pek_6730.82
# sigma_kms_HI_8324.06        X_sq_[FeIII]_4769.6         fr_OI_7774.0                X_sq_pek_9069.0
# sigma_kms_HI_8334.42        fr_[FeIII]_4769.6           X_sq_[FeXI]_7891.8          fr_pek_9069.0
# sigma_kms_HI_8345.55        X_sq_[FeII]_4774.74         fr_[FeXI]_7891.8            X_sq_pek_9531.1
# sigma_kms_[CrII]_8357.51    fr_[FeII]_4774.74           X_sq_[CrII]_7999.85         fr_pek_9531.1
# sigma_kms_HI_8359.0         X_sq_[FeIII]_4777.88        fr_[CrII]_7999.85

# %% [markdown]
# # The 'Mosaic' table has two times the size of a single table

# %%
print(f'Length of the DAP table: {len(tab_DAP)}')
# Out:
# Length of the DAP table: 1754

# %% [markdown]
# ## A. Quick-look spatial visualization with RGB maps

# %% [markdown]
# ## 2. Define a helper to build RGB emission-line maps
#
# This function converts three selected DAP columns into an RGB representation on the sky.
# It is especially useful for quick visual exploration because it combines three physically different tracers into a single image.
#
# For nebular data, these composite maps are often the fastest way to identify ionization stratification:
# - a high-ionization line can be mapped to one color,
# - Hα or another recombination line to another,
# - and a low-ionization line to a third one.
#
# In the Helix paper, this kind of comparison is central to showing how the compact high-ionization core, the bright [O III] ring, and the low-ionization outer structures are spatially separated.

# %%
def map_plot_DAP_rgb(tab_DAP,\
                     rgb_key=('flux_pe_6583.45','flux_pe_6562.85','flux_pe_5006.84'), \
                     rgb_scale=(1.0,1.0,1.0),\
                 vmin=0, vmax=0, titles=('r','g','b'), filename='junk',\
                fsize=5, figs_dir='.',fig_type='png',\
                 gamma=1.0, sf=1.0, tab_pt=None,fs=18):

    rc.update({'font.size': fs*fsize/5,\
               'font.weight': 900,\
               'text.usetex': True,\
               'path.simplify'           :   True,\
               'xtick.labelsize' : fs*fsize/5,\
               'ytick.labelsize' : fs*fsize/5,\
               'axes.linewidth'  : 2.0,\
               'xtick.major.size'        :   6,\
               'ytick.major.size'        :   6,\
               'xtick.minor.size'        :   3,\
               'ytick.minor.size'        :   3,\
               'xtick.major.width'       :   1,\
               'ytick.major.width'       :   1,\
               'lines.markeredgewidth'   :   1,\
               'legend.numpoints'        :   1,\
               'xtick.minor.width'       :   1,\
               'ytick.minor.width'       :   1,\
               'legend.frameon'          :   False,\
               'legend.handletextpad'    :   0.3,\
               'font.family'    :   'serif',\
               'mathtext.fontset'        :   'stix',\
               'axes.facecolor' : "w",\
               })
    
    X= tab_DAP['ra'].value
    Y= tab_DAP['dec'].value
    R=tab_DAP[rgb_key[2]].value  
    G=tab_DAP[rgb_key[1]].value    
    B=tab_DAP[rgb_key[0]].value 
    R = R * rgb_scale[0]
    G = G * rgb_scale[1]
    B = B * rgb_scale[2]
    RGB = np.stack((R, G, B), axis=1)
    if (vmin==vmax):
        vmin=np.nanmin(RGB)
        vmax=np.nanmax(RGB)
    print(f'min/max:{vmin}/{vmax}')
    r = (R-vmin)/(vmax-vmin)
    g = (G-vmin)/(vmax-vmin)
    b = (B-vmin)/(vmax-vmin)

    r[r>1]=1
    r[r<0]=0
    b[b>1]=1
    b[b<0]=0
    r[r>1]=1
    r[r<0]=0    
    
    r = np.ma.filled(r, fill_value=0.0)
    g = np.ma.filled(g, fill_value=0.0)
    b = np.ma.filled(b, fill_value=0.0)

    r=r**gamma
    g=g**gamma
    b=b**gamma
    
#    print (r)
    r = np.ma.compressed(r)
    g = np.ma.compressed(g)
    b = np.ma.compressed(b)   


    #print(r,g,b)
    colors = np.stack((r, g, b), axis=1)
    colors[colors>1]=1
    colors[colors<0]=0
#    print(colors)
    fig,ax = plt.subplots(1,1,figsize=(fsize,fsize*0.95))
#    norm=mpl_colors.PowerNorm(vmin=0,vmax=1,gamma=gamma)
    scatter(X, Y, ax, color=colors, size=sf*35.6/3600)#, color=colors)
    ax.set_xlabel('Ra [deg]')#,fontsize=21)
    ax.set_ylabel('Dec [deg]')#,fontsize=21)
    xx = ax.get_xlim()
    yy = ax.get_ylim()
    ax.set_xlim(xx[1],xx[0])
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.06*(yy[1]-yy[0]),titles[0],fontsize=fs*(fsize/5),color='tomato')
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.12*(yy[1]-yy[0]),titles[1],fontsize=fs*(fsize/5),color='forestgreen')
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.18*(yy[1]-yy[0]),titles[2],fontsize=fs*(fsize/5),color='steelblue')

    if (tab_pt != None):
        for tap_pt_now in tab_pt:
            ax.text(tab_pt['ra'],tab_pt['dec'],tab_pt['id'])
#    ax.set_aspect('equal', adjustable='box')
    try:
        plt.show()
    except:
        plt_show=False
    fig.tight_layout()
    fig.savefig(f'{figs_dir}/{filename}.{fig_type}', facecolor='white')
    plt.close()
    return colors

def search_col(tab,key):
    a_keys=[]
    for keys in tab.columns:
        if (keys.find(key)>-1):
            print(keys)
            a_keys.append(keys)
    return a_keys

# %% [markdown]
# This is a quick check of the available columns matching `[OII]`.
# It is useful before selecting line names for the maps, because DAP products often contain several measurements of the same transition, depending on whether the analysis is parametric, non-parametric, or from different iterations.

# %%
# We can search for the columns in the DAP table using the search_col function
# In this particular case we search for the [OII] emission line, which is a doublet at 3727.09 and 3729.88 Angstroms
oii_cols = search_col(tab_DAP,'[OII]')
# You could experiment with other entries in the DAP table.
# Columns involving Halpha
Ha_cols = search_col(tab_DAP,'_6562')
# Columns involving stellar analysis
st_cols = search_col(tab_DAP,'_st')
# Out:
# flux_[OII]_3726.03
# flux_[OII]_3728.82
# vel_[OII]_3726.03
# vel_[OII]_3728.82
# disp_[OII]_3726.03
# disp_[OII]_3728.82
# EW_[OII]_3726.03
# EW_[OII]_3728.82
# e_flux_[OII]_3726.03
# e_flux_[OII]_3728.82
# e_vel_[OII]_3726.03
# e_vel_[OII]_3728.82
# e_disp_[OII]_3726.03
# e_disp_[OII]_3728.82
# e_EW_[OII]_3726.03
# e_EW_[OII]_3728.82
# flux_[OII]_7318.92
# flux_[OII]_7329.66
# vel_[OII]_7318.92
# vel_[OII]_7329.66
# disp_[OII]_7318.92
# disp_[OII]_7329.66
# EW_[OII]_7318.92
# EW_[OII]_7329.66
# e_flux_[OII]_7318.92
# e_flux_[OII]_7329.66
# e_vel_[OII]_7318.92
# e_vel_[OII]_7329.66
# e_disp_[OII]_7318.92
# e_disp_[OII]_7329.66
# e_EW_[OII]_7318.92
# e_EW_[OII]_7329.66
# sigma_kms_[OII]_3726.03
# sigma_kms_[OII]_3728.82
# sigma_kms_[OII]_7318.92
# sigma_kms_[OII]_7329.66
# X_sq_[OII]_3726.03
# fr_[OII]_3726.03
# X_sq_[OII]_3728.82
# fr_[OII]_3728.82
# X_sq_[OII]_7318.92
# fr_[OII]_7318.92
# X_sq_[OII]_7329.66
# fr_[OII]_7329.66
# flux_Halpha_6562.85
# vel_Halpha_6562.85
# disp_Halpha_6562.85
# EW_Halpha_6562.85
# e_flux_Halpha_6562.85
# e_vel_Halpha_6562.85
# e_disp_Halpha_6562.85
# e_EW_Halpha_6562.85
# flux_pe_6562.85
# e_flux_pe_6562.85
# disp_pe_6562.85
# e_disp_pe_6562.85
# vel_pe_6562.85
# e_vel_pe_6562.85
# flux_pek_6562.85
# e_flux_pek_6562.85
# disp_pek_6562.85
# e_disp_pek_6562.85
# vel_pek_6562.85
# e_vel_pek_6562.85
# sigma_kms_Halpha_6562.85
# sigma_kms_pe_6562.85
# sigma_kms_pek_6562.85
# X_sq_Halpha_6562.85
# fr_Halpha_6562.85
# X_sq_pe_6562.85
# fr_pe_6562.85
# X_sq_pek_6562.85
# fr_pek_6562.85
# Av_st
# e_Av_st
# z_st
# e_z_st
# disp_st
# e_disp_st
# flux_st
# redshift_st
# med_flux_st
# e_med_flux_st
# vel_st
# X_sq_st
# X_sq_st_np
# X_sq_st_pek

# %% [markdown]
# ## 3. RGB map using the first parametric analysis (`pe`)
#
# This RGB composite uses:
# - red: [N II] 6583
# - green: Hα
# - blue: [O III] 5007
#
# Because these columns come from the first parametric analysis, this view is useful mostly for comparison with later products.
# Physically, this combination is a classic way to visualize ionization structure:
# - [O III] emphasizes the inner high-excitation gas,
# - Hα traces the overall ionized nebula,
# - [N II] highlights the lower-ionization outer layers and dense structures near the ionization front.

# %%
# 637.416/110230.7468
colors=map_plot_DAP_rgb(tab_DAP, \
                 rgb_key=('flux_pek_6583.45','flux_pek_6562.85','flux_pek_5006.84'), \
                 rgb_scale = (1,1,1), \
                 vmin=-100, vmax=5000.0,\
                 titles=('[NII]',r'H$\alpha$','[OIII]'), filename='Helix',\
                 fsize=6, figs_dir='figs',gamma=0.25,fig_type='png',fs=16, sf=1.05)
# Out:
# [WARNING]: /tmp/ipykernel_176017/2202648745.py:61: RuntimeWarning: invalid value encountered in power
#   g=g**gamma
# min/max:-100/5000.0

# %% [markdown]
# ## 5. BPT diagnostic diagrams and ionization structure
#
# This cell shows three classical **BPT diagnostic diagrams**, comparing:
# - log([O III] λ5007 / Hβ) vs log([N II] λ6583 / Hα)
# - log([O III] λ5007 / Hβ) vs log([S II] 6717,31 / Hα)
# - log([O III] λ5007 / Hβ) vs log([O II] 3727 / Hβ)
#
# These diagrams use ratios of strong emission lines to probe the **physical conditions and ionization mechanisms** of the gas. In particular:
# - **[O III]/Hβ** traces the hardness of the ionizing radiation field and the ionization parameter,
# - **[N II]/Hα, [S II]/Hα, [O II]/Hβ** are sensitive to metallicity, density, and the structure of partially ionized zones. :contentReference[oaicite:0]{index=0}
#
# In galaxy studies, these diagrams are commonly used to distinguish between ionization sources (e.g., star formation vs AGN), since harder radiation fields enhance forbidden lines relative to recombination lines. :contentReference[oaicite:1]{index=1}
#
# In this notebook, each point corresponds to an individual **fiber**, and the color coding follows the RGB composite shown previously:
# - **blue → [O III] (high-ionization gas)**
# - **green → Hα (overall ionized gas distribution)**
# - **red → [N II] (low-ionization gas / ionization front regions)**
#
# This color mapping helps connect the position of each point in the diagram with its spatial location in the nebula.

# %%
rc.update({'font.size': 20,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 20,\
           'ytick.labelsize' : 20,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })


mask_Ha = (tab_DAP['flux_Halpha_6562.85']>5) & (tab_DAP['flux_Halpha_6562.85']>2.0*tab_DAP['e_flux_Halpha_6562.85'])



Ha=tab_DAP['flux_Halpha_6562.85']
Hb=tab_DAP['flux_Hbeta_4861.36']
OIII=tab_DAP['flux_[OIII]_5006.84']
NII=tab_DAP['flux_[NII]_6583.45']
SII=tab_DAP['flux_[SII]_6716.44']+tab_DAP['flux_[SII]_6730.82']
OI=tab_DAP['flux_[OI]_6300.3']
OII=tab_DAP['flux_[OII]_3726.03']+tab_DAP['flux_[OII]_3728.82']
#tab_DAP['flux_pe_3726.03']+tab_DAP['flux_pe_3728.82']

map_dist=np.arange(len(Ha))

eHa=tab_DAP['e_flux_Halpha_6562.85']
eHb=tab_DAP['e_flux_Hbeta_4861.36']
eOIII=tab_DAP['e_flux_[OIII]_5006.84']
eNII=tab_DAP['e_flux_[NII]_6583.45']
eSII=np.sqrt(tab_DAP['e_flux_[SII]_6716.44']**2+tab_DAP['e_flux_[SII]_6730.82']**2)
eOI=tab_DAP['flux_[OI]_6300.3']
eOII=np.sqrt(tab_DAP['e_flux_[OII]_3726.03']**2+tab_DAP['e_flux_[OII]_3728.82']**2)
#tab_DAP['e_flux_pe_3726.03']+tab_DAP['e_flux_pe_3728.82']

#tab_DAP['e_flux_pe_9531.1']

O3=np.log10(OIII)-np.log10(Hb)
N2=np.log10(NII)-np.log10(Ha)
S2=np.log10(SII/Ha)
O1=np.log10(OI/Ha)
O2=np.log10(OII)-np.log10(Hb)
lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
nx = 2.5 #np.max(tab_DAP[mask_Ha]['R_Re'])
#
#
#
fig, axes = plt.subplots(1,3,figsize=(14,4.5), sharey=True, squeeze=False)
x_min1=-1.39
x_max1=0.89
y_min1=-1.29
y_max1=0.99

x=np.linspace(5*x_min1,2*x_max1,100)
cut_y=-0.7+0.2-3.67*x
cut_y2=-1.7+0.5-3.67*x
cut_y3=0.61/(x-0.05)+1.3
cut_y4=0.61/(x-0.47)+1.19
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII_AGNs=1.89*(x)+0.76;
cut_y_OII=0.73/((x-0.3))+1.33;#+1.10;
cut_y_OII_AGNs=1.18*(x)+0.36;
cut_y_OIII_AGNs=1.14*(x)+0.36;
cm = plt.cm.get_cmap('viridis')
cax1=axes[0,0].scatter(N2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=30)
#                       c=map_dist[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=0, vmax=nx)
cax2=axes[0,1].scatter(S2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=30)
cax3=axes[0,2].scatter(O2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=30)

#axes[0,0].scatter(N2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,1].scatter(S2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,2].scatter(O1,O3,alpha=0.75, marker='*', s=100,c='green')

axes[0,0].plot(x[x<0],cut_y3[x<0],'-.',color='lightgrey')
axes[0,0].plot(x[x<0.5],cut_y4[x<0.5],'-',color='black')
axes[0,1].plot(x[x<0.2],cut_y_SII[x<0.2],'-',color='black')
axes[0,2].plot(x[x<0.3],cut_y_OII[x<0.3],'-',color='black')


#plt.rcParams.update({'font.size': 16})
axes[0,0].set_ylabel(r'log([Oiii]/H$\beta$)')
axes[0,0].set_xlabel(r'log([Nii]/H$\alpha$)')
axes[0,1].set_xlabel(r'log([Sii]/H$\alpha$)')
axes[0,2].set_xlabel(r'log([Oii]/H$\beta$)')
axes[0,0].set_xlim(x_min1,x_max1)
axes[0,1].set_xlim(x_min1-0.6,x_max1-0.2)
axes[0,2].set_xlim(x_min1-0.3,x_max1+0.4)
axes[0,0].set_ylim(y_min1+0.1,y_max1+0.1)





plt.tight_layout()
plt.subplots_adjust(wspace=0)

fig.savefig(f'figs/BPT_ORION.png', facecolor='white')
plt.show()

#cax1=axes[0,2].scatter(N2[mask_Ha],O3[mask_Ha],c=log_EW_Ha[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=-3, vmax=2.5)
#axes[0,2].plot(x[x<0],cut_y3[x<0],'r-.')
#axes[0,2].plot(x,cut_y4,'b-')
#cb1=add_colorbar(cax1)
#cb1.set_label(r'$log|EW(H\alpha)|$')
# Out:
# [WARNING]: /tmp/ipykernel_176017/809606605.py:56: RuntimeWarning: invalid value encountered in log10
#   O3=np.log10(OIII)-np.log10(Hb)
#
# [WARNING]: /tmp/ipykernel_176017/809606605.py:57: RuntimeWarning: invalid value encountered in log10
#   N2=np.log10(NII)-np.log10(Ha)
#
# [WARNING]: /tmp/ipykernel_176017/809606605.py:58: RuntimeWarning: invalid value encountered in log10
#   S2=np.log10(SII/Ha)
#
# [WARNING]: /tmp/ipykernel_176017/809606605.py:59: RuntimeWarning: invalid value encountered in log10
#   O1=np.log10(OI/Ha)
#
# [WARNING]: /tmp/ipykernel_176017/809606605.py:60: RuntimeWarning: invalid value encountered in log10
#   O2=np.log10(OII)-np.log10(Hb)
#
# [WARNING]: /tmp/ipykernel_176017/809606605.py:61: RuntimeWarning: divide by zero encountered in log10
#   lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
#
# [WARNING]: /tmp/ipykernel_176017/809606605.py:62: RuntimeWarning: divide by zero encountered in divide
#   e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
#
# [WARNING]: /tmp/ipykernel_176017/809606605.py:84: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %% [markdown]
# ## Classical BPT diagrams, now including the [O I]-based diagnostic
#
# This cell shows three classical emission-line diagnostic diagrams, using the same color coding adopted in the previous RGB maps:
# - **blue**: [O III] λ5007
# - **green**: Hα
# - **red**: [N II] λ6583
#
# The panels correspond to:
# - log([O III] λ5007 / Hβ) vs log([N II] λ6583 / Hα),
# - log([O III] λ5007 / Hβ) vs log([S II] λλ6717,6731 / Hα),
# - log([O III] λ5007 / Hβ) vs log([O I] λ6300 / Hα).
#
# These are the classical **BPT / Veilleux-Osterbrock** diagnostics, widely used to compare different ionization regimes through strong optical line ratios. In galaxy studies, they are often used to separate gas ionized by young stars, AGN radiation, or shocks, with the standard demarcation curves shown here as reference.
#
# In this notebook, however, each point corresponds to an individual **fiber** in a **resolved nebula**, not to an integrated galaxy or a single globally ionized structure. Therefore, the location of the points in these diagrams should **not** be interpreted in the same straightforward classification sense used for galaxies. Instead, the distribution reflects **local variations** in excitation, ionization parameter, density, temperature, and the presence of partially ionized zones across the nebula. Spatially resolved line-ratio diagrams are useful because they connect the morphology seen in the RGB maps with the physical conditions of the gas.
#
# For the Helix Nebula, this means that fibers associated with the inner high-excitation regions tend to occupy different parts of the diagrams than fibers located in the outer low-ionization ring, where [N II], [S II], and [O I] become enhanced. This behavior is consistent with the ionization stratification discussed in the Helix analysis.
#
# The third panel uses **[O I] λ6300**, which is particularly interesting because it traces partially ionized gas and transition regions, but it must be interpreted with extra caution: in the Helix DAP analysis this line was identified as one of the transitions that can be significantly affected by imperfect night-sky subtraction, and an a posteriori background correction was applied to it. Therefore, structure seen in the [O I]-based diagram may partly reflect real nebular conditions and partly residual sky contamination if the correction is not properly taken into account. :contentReference[oaicite:3]{index=3}

# %%
rc.update({'font.size': 20,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 20,\
           'ytick.labelsize' : 20,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })


#mask_Ha = (tab_DAP['flux_Halpha_6562.85']>100) & (tab_DAP['flux_Halpha_6562.85']>50.0*tab_DAP['e_flux_Halpha_6562.85'])



Ha=tab_DAP['flux_Halpha_6562.85']
Hb=tab_DAP['flux_Hbeta_4861.36']
OIII=tab_DAP['flux_[OIII]_5006.84']
NII=tab_DAP['flux_[NII]_6583.45']
SII=tab_DAP['flux_[SII]_6716.44']+tab_DAP['flux_[SII]_6730.82']
OI=tab_DAP['flux_[OI]_6300.3']
#tab_DAP['flux_pe_3726.03']+tab_DAP['flux_pe_3728.82']

map_dist=np.arange(len(Ha))

eHa=tab_DAP['e_flux_Halpha_6562.85']
eHb=tab_DAP['e_flux_Hbeta_4861.36']
eOIII=tab_DAP['e_flux_[OIII]_5006.84']
eNII=tab_DAP['e_flux_[NII]_6583.45']
eSII=np.sqrt(tab_DAP['e_flux_[SII]_6716.44']**2+tab_DAP['e_flux_[SII]_6730.82']**2)
eOI=tab_DAP['flux_[OI]_6300.3']
#tab_DAP['e_flux_pe_3726.03']+tab_DAP['e_flux_pe_3728.82']

#tab_DAP['e_flux_pe_9531.1']

O3=np.log10(OIII)-np.log10(Hb)
N2=np.log10(NII)-np.log10(Ha)
S2=np.log10(SII/Ha)
O1=np.log10(OI/Ha)
lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
nx = 2.5 #np.max(tab_DAP[mask_Ha]['R_Re'])
#
#
#
fig, axes = plt.subplots(1,3,figsize=(14,4.5), sharey=True, squeeze=False)
x_min1=-1.39
x_max1=0.89
y_min1=-1.29
y_max1=0.99

x=np.linspace(5*x_min1,2*x_max1,100)
cut_y=-0.7+0.2-3.67*x
cut_y2=-1.7+0.5-3.67*x
cut_y3=0.61/(x-0.05)+1.3
cut_y4=0.61/(x-0.47)+1.19
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII=0.61/(x-0.3)+1.3;
cut_y_SII_AGNs=1.89*(x)+0.76;
cut_y_OI=0.73/((x+0.59))+1.33;#+1.10;
cut_y_OI_AGNs=1.18*(x)+1.30;
cut_y_OIII_AGNs=1.14*(x)+0.36;
cm = plt.cm.get_cmap('viridis')
cax1=axes[0,0].scatter(N2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=30)
#                       c=map_dist[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=0, vmax=nx)
cax2=axes[0,1].scatter(S2[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=30)
cax3=axes[0,2].scatter(O1[mask_Ha],O3[mask_Ha],color=colors[mask_Ha],edgecolor='None',s=30)

#axes[0,0].scatter(N2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,1].scatter(S2,O3,alpha=0.75, marker='*', s=100,c='green')
#axes[0,2].scatter(O1,O3,alpha=0.75, marker='*', s=100,c='green')

axes[0,0].plot(x[x<-0.1],cut_y3[x<-0.1],'-.',color='lightgrey')
axes[0,0].plot(x[x<0.2],cut_y4[x<0.2],'-',color='black')
axes[0,1].plot(x[x<0.2],cut_y_SII[x<0.2],'-',color='black')
axes[0,2].plot(x[x<-0.6],cut_y_OI[x<-0.6],'-',color='black')


#plt.rcParams.update({'font.size': 16})
axes[0,0].set_ylabel(r'log([Oiii]/H$\beta$)')
axes[0,0].set_xlabel(r'log([Nii]/H$\alpha$)')
axes[0,1].set_xlabel(r'log([Sii]/H$\alpha$)')
axes[0,2].set_xlabel(r'log([Oi]/H$\alpha$)')
axes[0,0].set_xlim(x_min1-0.2,x_max1+0.1)
axes[0,1].set_xlim(x_min1-0.7,x_max1+0.1)
axes[0,2].set_xlim(x_min1-0.8,x_max1-0.4)
axes[0,0].set_ylim(y_min1,y_max1+0.1)
axes[0,1].set_ylim(y_min1,y_max1+0.1)
axes[0,2].set_ylim(y_min1,y_max1+0.1)






plt.tight_layout()
plt.subplots_adjust(wspace=0)

fig.savefig(f'figs/BPT_HELIX_OI.png', facecolor='white')
plt.show()

#cax1=axes[0,2].scatter(N2[mask_Ha],O3[mask_Ha],c=log_EW_Ha[mask_Ha], marker='o', s=30, alpha=0.35, cmap=cm, vmin=-3, vmax=2.5)
#axes[0,2].plot(x[x<0],cut_y3[x<0],'r-.')
#axes[0,2].plot(x,cut_y4,'b-')
#cb1=add_colorbar(cax1)
#cb1.set_label(r'$log|EW(H\alpha)|$')
# Out:
# [WARNING]: /tmp/ipykernel_176017/651037580.py:54: RuntimeWarning: invalid value encountered in log10
#   O3=np.log10(OIII)-np.log10(Hb)
#
# [WARNING]: /tmp/ipykernel_176017/651037580.py:55: RuntimeWarning: invalid value encountered in log10
#   N2=np.log10(NII)-np.log10(Ha)
#
# [WARNING]: /tmp/ipykernel_176017/651037580.py:56: RuntimeWarning: invalid value encountered in log10
#   S2=np.log10(SII/Ha)
#
# [WARNING]: /tmp/ipykernel_176017/651037580.py:57: RuntimeWarning: invalid value encountered in log10
#   O1=np.log10(OI/Ha)
#
# [WARNING]: /tmp/ipykernel_176017/651037580.py:58: RuntimeWarning: divide by zero encountered in log10
#   lEW_Ha = np.log10(np.abs(tab_DAP['EW_Halpha_6562.85']))
#
# [WARNING]: /tmp/ipykernel_176017/651037580.py:59: RuntimeWarning: divide by zero encountered in divide
#   e_lEW_Ha = 0.4*np.abs(tab_DAP['e_EW_Halpha_6562.85']/tab_DAP['EW_Halpha_6562.85'])
#
# [WARNING]: /tmp/ipykernel_176017/651037580.py:81: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %% [markdown]
# ## C. Generic map helpers for individual DAP quantities

# %% [markdown]
# ## 6. Define a generic helper to plot a single DAP quantity on the sky
#
# This function builds a scatter map of one selected DAP column using the fiber sky coordinates.
# It is the basic tool used later for line-flux maps, stellar-parameter maps, velocity maps, and similar products.
#
# Because LVM DAP products are fiber-based rather than image-based, most spatial visualization begins with this sort of function.

# %%
def map_plot_DAP(tab_DAP,line='flux_Halpha_6562.85', \
                 vmin=0, vmax=0, title=None, filename='junk',\
                 cmap='Spectral', fsize=5, figs_dir='.',fig_type='png',\
                 gamma=1.0, sf=1.0, tab_pt=None):

    rc.update({'font.size': 19,\
               'font.weight': 900,\
               'text.usetex': True,\
               'path.simplify'           :   True,\
               'xtick.labelsize' : 19,\
               'ytick.labelsize' : 19,\
               'axes.linewidth'  : 2.0,\
               'xtick.major.size'        :   6,\
               'ytick.major.size'        :   6,\
               'xtick.minor.size'        :   3,\
               'ytick.minor.size'        :   3,\
               'xtick.major.width'       :   1,\
               'ytick.major.width'       :   1,\
               'lines.markeredgewidth'   :   1,\
               'legend.numpoints'        :   1,\
               'xtick.minor.width'       :   1,\
               'ytick.minor.width'       :   1,\
               'legend.frameon'          :   False,\
               'legend.handletextpad'    :   0.3,\
               'font.family'    :   'serif',\
               'mathtext.fontset'        :   'stix',\
               'axes.facecolor' : "w",\
               })
    
    X=tab_DAP['ra']
    Y=tab_DAP['dec']
    C=tab_DAP[line]    
    if (title== None):
        title=line.replace("_"," ")
        title=line.replace("_"," ")
    if (vmin==vmax):
        vmin=0.00001*np.nanmax(C)
        vmax=np.nanmax(C)
    print(line,vmin,vmax)
    fig,ax = plt.subplots(1,1,figsize=(fsize,fsize/1.3))
    norm=mpl_colors.PowerNorm(vmin=vmin,vmax=vmax,gamma=gamma)
    scat=scatter(X, Y, ax, size=sf*35.6/3600, c=C, cmap=cmap, norm=norm)

    ax.set_xlabel('Ra [deg]')
    ax.set_ylabel('Dec [deg]')
    xx = ax.get_xlim()
    yy = ax.get_ylim()
    ax.set_xlim(xx[1],xx[0])
    props = dict(boxstyle='square', facecolor='white', alpha=0.5)
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.08*(yy[1]-yy[0]),title,color='black',\
            bbox=props)
    ax.text(xx[1]-0.52*(xx[1]-xx[0]),yy[0]+0.06*(yy[1]-yy[0]),r'10$^{-16}$ erg/s/cm$^2$',color='black',\
            bbox=props)
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(scat.sc, cax=cax, format='%.0e')
    if (tab_pt != None):
        for tap_pt_now in tab_pt:
            ax.text(tab_pt['ra'],tab_pt['dec'],tab_pt['id'])

    try:
        plt.show()
    except:
        plt_show=False
    fig.tight_layout()
    fig.savefig(f'{figs_dir}/{filename}.{fig_type}')
    plt.close()

# %% [markdown]
# This is a slightly more flexible version of the previous helper that plots into a user-provided axis.
# It is ideal for multi-panel figures and for publication layouts.
#
# Most of the science figures in the rest of the notebook are built with this function.

# %%
def map_plot_DAP_ax(tab_DAP,ax=None,fig=None,line='flux_Halpha_6562.85', \
                 vmin=0, vmax=0, title=None, filename='junk',\
                 cmap='Spectral', fsize=5, figs_dir='.',fig_type='png',\
                 gamma=1.0, sf=1.0, tab_pt=None,xlab=True,ylab=True, fs=1.0,f_scale=1e7):

    rc.update({'font.size': 19*fs,\
               'font.weight': 900,\
               'text.usetex': True,\
               'path.simplify'           :   True,\
               'xtick.labelsize' : 19*fs,\
               'ytick.labelsize' : 19*fs,\
               'axes.linewidth'  : 2.0,\
               'xtick.major.size'        :   6*fs,\
               'ytick.major.size'        :   6*fs,\
               'xtick.minor.size'        :   3*fs,\
               'ytick.minor.size'        :   3*fs,\
               'xtick.major.width'       :   1,\
               'ytick.major.width'       :   1,\
               'lines.markeredgewidth'   :   1,\
               'legend.numpoints'        :   1,\
               'xtick.minor.width'       :   1,\
               'ytick.minor.width'       :   1,\
               'legend.frameon'          :   False,\
               'legend.handletextpad'    :   0.3,\
               'font.family'    :   'serif',\
               'mathtext.fontset'        :   'stix',\
               'axes.facecolor' : "w",\
               })
    
    X=tab_DAP['ra']
    Y=tab_DAP['dec']
    C=tab_DAP[line]/f_scale    
    if (title== None):
        title=line.replace("_"," ")
        title=line.replace("_"," ")
    if (vmin==vmax):
        vmin=0.00001*np.nanmax(C)
        vmax=np.nanmax(C)

    if (gamma>0):
        norm=mpl_colors.PowerNorm(vmin=vmin,vmax=vmax,gamma=gamma)
        size_sc = sf*35.6/3600
        scat=ax.scatter(X, Y, s=10*sf, c=C, cmap=cmap, norm=norm, rasterized=True)
    else:

        scat=ax.scatter(X, Y, s=10*sf, c=C, cmap=cmap, vmin=vmin, vmax=vmax, rasterized=True)

    if (xlab == True):
        ax.set_xlabel('Ra [deg]',fontsize=19*fs)
    if (ylab == True):
        ax.set_ylabel('Dec [deg]',fontsize=19*fs)
    xx = ax.get_xlim()
    yy = ax.get_ylim()
    ax.set_xlim(xx[1],xx[0])
    props = dict(boxstyle='square', facecolor='white', alpha=0.5)
    ax.text(xx[1]-0.03*(xx[1]-xx[0]),yy[1]-0.08*fs*(yy[1]-yy[0]),rf'{title}',color='black',\
            bbox=props)

    return scat

# %% [markdown]
# ## Comparison of Hα flux products
#
# The left panel shows the spatial distribution of the Hα flux derived from the **non-parametric** DAP analysis, which is the most convenient product for mapping the nebular emission over the full field. The right panel compares the Hα flux measured with the non-parametric method against the value derived from the **second parametric fit** (`PEK`), which is optimized for strong lines after refinement of the stellar-continuum subtraction. Agreement between both measurements indicates that the line is robustly recovered, while deviations usually become more important in low-signal fibers or in regions affected by background residuals.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# --------------------------------------------------
# Left panel: Halpha flux map (NP measurement)
# --------------------------------------------------
line_np = 'flux_Halpha_6562.85'

C_np = tab_DAP[line_np] / 1e7
good_map = np.isfinite(C_np) & (C_np > 0)

if np.any(good_map):
    vmin_map = np.nanpercentile(C_np[good_map], 5)
    vmax_map = np.nanpercentile(C_np[good_map], 99)
else:
    vmin_map, vmax_map = 0, 1

scat = map_plot_DAP_ax(
    tab_DAP,
    ax=axes[0],
    line=line_np,
    vmin=vmin_map,
    vmax=vmax_map,
    title=r'H$\alpha$ flux (NP)',
    cmap='Spectral',
    gamma=0.7,
    sf=2,
    xlab=True,
    ylab=True,
    fs=0.9,
    f_scale=1e7
)

cb = fig.colorbar(scat, ax=axes[0], fraction=0.046, pad=0.04)
cb.set_label(r'Flux [$10^{-13}$ erg s$^{-1}$ cm$^{-2}$]')

# --------------------------------------------------
# Right panel: NP vs PEK comparison
# --------------------------------------------------
line_pek = 'flux_pek_6562.85'

Ha_np = tab_DAP[line_np]
Ha_pek = tab_DAP[line_pek]

mask = (
    np.isfinite(Ha_np) & np.isfinite(Ha_pek) &
    (Ha_np > 0) & (Ha_pek > 0)
)

axes[1].scatter(
    Ha_np[mask] / 1e7,
    Ha_pek[mask] / 1e7,
    s=20,
    alpha=0.7,
    edgecolor='none'
)

if np.any(mask):
    lo = min(np.nanmin(Ha_np[mask]), np.nanmin(Ha_pek[mask])) / 1e7
    hi = max(np.nanmax(Ha_np[mask]), np.nanmax(Ha_pek[mask])) / 1e7
    axes[1].plot([lo, hi], [lo, hi], '--', color='black', lw=1.5)

axes[1].set_xlabel(r'H$\alpha$ flux (NP) [$10^{-13}$ erg s$^{-1}$ cm$^{-2}$]')
axes[1].set_ylabel(r'H$\alpha$ flux (PEK) [$10^{-13}$ erg s$^{-1}$ cm$^{-2}$]')
axes[1].set_title(r'NP vs PEK H$\alpha$ flux')
axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlim(vmin_map, vmax_map * 1.5)
axes[1].set_ylim(vmin_map, vmax_map * 1.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## D. Kinematics and line-by-line spatial structure

# %% [markdown]
# ## 7. Hα kinematics: velocity and velocity dispersion
#
# This figure reproduces one of the core physical results of the Helix analysis:
# - the Hα velocity field,
# - and the Hα velocity-dispersion field.
#
# In the Helix paper, the velocity map shows a large-scale redshifted/blueshifted symmetry consistent with a slowly expanding, moderately inclined shell.
# The velocity-dispersion map is generally narrow, with somewhat broader profiles in the inner cavity and the brightest ring, consistent with thermal broadening plus modest unresolved turbulent motions.

# %%
fig, axes = plt.subplots(1,2,figsize=(12,5))
#cmap_now = 'Spectral_r'
#cmap_now = 'turbo'
cmap_now = 'coolwarm'
#np.zeros(len(tab_DAP),dtype=int)
filename=f'M33_{DRVER}_kin'
xlab = True
ylab = True
ax = axes[0]
#mask_Ha = (tab_DAP['flux_pek_6562.85']>600)
dec_c = np.nanmedian((tab_DAP['dec']*tab_DAP['flux_Halpha_6562.85'])[mask_Ha])/np.nanmedian(tab_DAP['flux_Halpha_6562.85'][mask_Ha])
ra_c = np.nanmedian((tab_DAP['ra']*tab_DAP['flux_Halpha_6562.85'])[mask_Ha])/np.nanmedian(tab_DAP['flux_Halpha_6562.85'][mask_Ha])
mask_cen = ((tab_DAP['dec']>(dec_c-0.025)) & (tab_DAP['dec']<(dec_c+0.025))) & ((tab_DAP['ra']>(ra_c-0.05)) & (tab_DAP['ra']<(ra_c+0.05)))        
mean_vel = np.nanmedian(tab_DAP['vel_pek_6562.85'][mask_cen])
#mean_vel = -100
tab_DAP_Ha = tab_DAP[mask_Ha]
print(f'Mean velocity in central region: {mean_vel:.2f} km/s')
tab_DAP['vel_off'] = tab_DAP['vel_pek_6562.85'] - mean_vel
tab_DAP_Ha = tab_DAP[mask_Ha]
scat=map_plot_DAP_ax(tab_DAP_Ha,ax=ax,fig=fig,line='vel_off', \
                 vmin=-120, vmax=120, title=r'v$_{H\alpha}$', filename=filename,\
             cmap=cmap_now, fsize=6.5, figs_dir='figs',gamma=0,fig_type='pdf',\
                         xlab=xlab,ylab=ylab,sf=1.2,fs=1.0,\
                        f_scale=1.0)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
fig.colorbar(scat, cax=cax, label='km/s')#,label=fr'{title}')#,fontsize=21)

ax = axes[1]
scat=map_plot_DAP_ax(tab_DAP_Ha,ax=ax,fig=fig,line='sigma_kms_pek_6562.85', \
                 vmin=0, vmax=59, title=r'$\sigma_{H\alpha}$', filename=filename,\
             cmap='Reds', fsize=6.5, figs_dir='figs',gamma=0,fig_type='pdf',\
                         xlab=xlab,ylab=ylab,sf=1.2,fs=1.0,\
                        f_scale=1.0)

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
fig.colorbar(scat, cax=cax, label='km/s')#,label=fr'{title}')#,fontsize=21)

#ax.set_ylabel('')


plt.tight_layout(w_pad=0.5)


fig.savefig(f'{DIR_FIG}/kin.pdf', facecolor='white')
# Out:
# Mean velocity in central region: 468.91 km/s

# %% [markdown]
# ## G. Explore the stellar-continuum side of the DAP products

# %% [markdown]
# ## 8. Select fibers with measurable stellar continuum
#
# This section turns from gas to the stellar side of the DAP.
# The Helix is not an ideal field for stellar-population work because the nebula dominates and only a few fibers contain stars with moderate signal-to-noise.
#
# The selection `SN_st > 5` is therefore a practical exploratory cut rather than a physically complete sample.

# %%
#
# Stars with SN>3
#
SN_st = tab_DAP['med_flux_st']/tab_DAP['e_med_flux_st']
mask_SN = SN_st > 10
tab_DAP['SN_st'] = SN_st
tab_DAP_st = tab_DAP[mask_SN]

# %% [markdown]
# This cell resets the plotting style for the stellar-parameter section.

# %%
rc.update({'font.size': 20,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 20,\
           'ytick.labelsize' : 20,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })

# %% [markdown]
# This scatter plot shows the distribution of the DAP-derived stellar metallicity proxy `[Fe/H]` and alpha-enhancement `[α/Fe]` for the selected stellar fibers. Keep in min that those are "average" properties from a combination of stars analyzed using the RSP methodology. For a proper PDF we provide with a methodology included below.
#
# For the Helix field, these points should be treated as field-star measurements.
# The Helix paper explicitly warns that the stellar results are not robust enough here to support physical conclusions about the nebula itself.

# %%
dist_c = np.sqrt((tab_DAP_st['ra']-ra_c)**2+(tab_DAP_st['dec']-dec_c)**2)
dist_c_st = np.sqrt((tab_DAP_st['ra']-ra_c)**2+(tab_DAP_st['dec']-dec_c)**2)
fig, ax = plt.subplots(1,1,figsize=(5,5/1.3))
ax.scatter(tab_DAP_st['Fe'],tab_DAP_st['alpha'],s=25,c=dist_c_st,alpha=0.5)
ax.set_xlabel('[Fe/H]')
ax.set_ylabel(r'[$\alpha$/Fe]')
# Out:
# Text(0, 0.5, '[$\\alpha$/Fe]')

# %% [markdown]
# This scatter plot shows the distribution in `Teff` versus `log g` for the selected stellar fibers.
# Again, the point is mainly diagnostic: it reveals what part of parameter space is sampled by the stars bright enough to be detected in the field.

# %%
fig, ax = plt.subplots(1,1,figsize=(5,5/1.3))
ax.scatter(tab_DAP_st['Teff'],tab_DAP_st['Log_g'],s=15,c=dist_c_st,alpha=0.5)
ax.set_xlabel('Teff')
ax.set_ylabel(r'log(g)')
# Out:
# Text(0, 0.5, 'log(g)')

# %%
fig, axes = plt.subplots(1,2,figsize=(12,5))
#cmap_now = 'Spectral_r'
#cmap_now = 'turbo'
cmap_now = 'coolwarm'
#np.zeros(len(tab_DAP),dtype=int)
filename=f'M33_{DRVER}_kin'
xlab = True
ylab = True
ax = axes[0]
dec_c = np.nanmedian((tab_DAP['dec']*tab_DAP['flux_Halpha_6562.85'])[mask_Ha])/np.nanmedian(tab_DAP['flux_Halpha_6562.85'][mask_Ha])
ra_c = np.nanmedian((tab_DAP['ra']*tab_DAP['flux_Halpha_6562.85'])[mask_Ha])/np.nanmedian(tab_DAP['flux_Halpha_6562.85'][mask_Ha])
mask_cen = ((tab_DAP['dec']>(dec_c-0.025)) & (tab_DAP['dec']<(dec_c+0.025))) & ((tab_DAP['ra']>(ra_c-0.05)) & (tab_DAP['ra']<(ra_c+0.05)))        
mean_vel = np.nanmedian(tab_DAP['vel_st'][mask_cen])
print(f'Mean velocity in central region: {mean_vel:.2f} km/s')
tab_DAP['vel_off_st'] = tab_DAP['vel_st'] - mean_vel
scat=map_plot_DAP_ax(tab_DAP,ax=ax,fig=fig,line='vel_off_st', \
                 vmin=-120, vmax=120, title=r'v$_{\star}$', filename=filename,\
             cmap=cmap_now, fsize=6.5, figs_dir='figs',gamma=0,fig_type='pdf',\
                         xlab=xlab,ylab=ylab,sf=1.2,fs=1.0,\
                        f_scale=1.0)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
fig.colorbar(scat, cax=cax, label='km/s')#,label=fr'{title}')#,fontsize=21)

ax = axes[1]
scat=map_plot_DAP_ax(tab_DAP,ax=ax,fig=fig,line='disp_st', \
                 vmin=0, vmax=59, title=r'$\sigma_{\star}$', filename=filename,\
             cmap='Reds', fsize=6.5, figs_dir='figs',gamma=0,fig_type='pdf',\
                         xlab=xlab,ylab=ylab,sf=1.2,fs=1.0,\
                        f_scale=1.0)

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
fig.colorbar(scat, cax=cax, label='km/s')#,label=fr'{title}')#,fontsize=21)

#ax.set_ylabel('')


plt.tight_layout(w_pad=0.5)


fig.savefig(f'{DIR_FIG}/kin.pdf', facecolor='white')
# Out:
# Mean velocity in central region: 600.60 km/s

# %%
hist = plt.hist(tab_DAP['vel_st'], bins=30, alpha=0.5, label='Stars')
